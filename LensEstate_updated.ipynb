# %% [markdown]
# <h1 style="text-align: center; color: #091A2B; font-size: 36px; font-weight: bold;">
#     🏘️ LensEstate — An End-to-End Real Estate Analytics Engine
# </h1>
# <hr style="height: 2px; border: none; background-color: #ffffff;">

# %% [markdown]
# <h1 style=" color: #426d84; font-size: 32px; font-weight: bold;">
#     🧭  Introduction
# </h1>
#
# <p> The real estate sector represents one of the most economically and socially significant markets, directly influencing investment decisions, urban development, and household wealth. In emerging markets, however, real estate ecosystems often lack transparency, standardized information, and analytical infrastructure.
#     With the rapid expansion of digital platforms and social media, large volumes of property-related data are generated daily, yet much of this information remains unstructured and underutilized. Leveraging advanced data science and artificial intelligence techniques offers an opportunity to transform fragmented market signals into reliable insights, enabling smarter valuation, forecasting, and decision-making processes. </p>
#
# <h2 style="color: #7b98a6;" > 🛠️ 1 Market Context :</h2>
# <p>The real estate market in Tunisia operates within a fragmented and partially informal ecosystem where property information is dispersed across multiple digital platforms, social media channels, and offline networks. Listings are often inconsistent, incomplete, or unstructured, making it difficult to obtain a unified and reliable view of the market. This lack of standardization limits transparency and complicates comparative analysis across regions and property types.</p>
# <h2 style="color: #7b98a6;" > 🛠️  2 Problem Statement :</h2>
# <p>Despite the growing availability of online listings, the market still lacks structured analytical mechanisms capable of transforming raw property data into actionable insights. Pricing decisions are frequently subjective, valuation practices vary significantly, and regional market dynamics remain insufficiently understood. The absence of predictive tools and intelligent systems prevents stakeholders from making fully informed investment, pricing, and planning decisions.</p>
# <h2 style="color: #7b98a6;" > 🛠️ 3 Project Motivation :</h2>
# <p>As digital transformation accelerates across industries, the real estate sector presents a strong opportunity for intelligent automation and data-driven innovation. Buyers seek fair and transparent pricing, sellers require objective positioning strategies, investors demand forward-looking indicators, and policymakers need regional intelligence to support sustainable urban development. Addressing these needs requires more than simple data aggregation — it calls for advanced analytical capabilities that can interpret, predict, and explain market behavior.</p>
# <h2 style="color: #7b98a6;" > 🛠️ Vision and Objectives :</h2>
#
# <p>This project proposes the development of an integrated AI-powered real estate intelligence framework designed to transform heterogeneous property data into structured, explainable, and actionable knowledge. By combining automated data acquisition, multi-modal valuation models, regional trend forecasting, conversational decision support, and intelligent property visualization, the system aims to enhance transparency, reduce uncertainty, and democratize access to real estate market insights.</p>
#
# <h2 style="color: #7b98a6;" > 🛠️ Planning :</h2>
# <ul>
#     <li>🔍 Business Understanding</li>
#     <li>🧭 Analytical approach</li>
#     <li>📊 Data Acquisition and Understanding</li>
#     <li>📊 Data Preparation</li>
#     <li>🤖 Modeling</li>
#     <li>🚀  Deployment</li>
#     <li>⚖️ Conclusion</li>
#
# </ul>

# %% [markdown]
# <h1 style=" color: #2c3e50; font-size: 34px; font-weight: bold;">
#     💼 Business Understanding
# </h1>
#
# <p style="font-size:16px;">
# The Business Understanding phase aims to establish a strategic foundation for the project by analyzing the existing market landscape, identifying structural inefficiencies, and translating business challenges into measurable analytical objectives. This section bridges the gap between real estate market needs and the AI-driven solutions proposed in this framework.
# </p>
#
#
#
# <!-- ================= STATE OF THE ART ================= -->
#
# <h2 style="color: #426d84;"> 🌍 1 — State of the Art</h2>
#
# <p>
# Before defining our strategic direction, it is essential to examine how advanced real estate platforms currently operate. Leading international platforms such as Zillow, Redfin, and Idealista have demonstrated how digital transformation can enhance transparency, streamline listings, and introduce automated valuation mechanisms. However, even these mature ecosystems reveal structural limitations when it comes to multi-modal intelligence, explainability, predictive depth, and integration of informal market dynamics.
# </p>
#
# <table style="width:100%; border-collapse: collapse; font-size:15px;">
# <tr style="background-color:#d9e6ec; text-align:left;">
#     <th style="padding:12px; border:1px solid #b5cbd6;">Platform</th>
#     <th style="padding:12px; border:1px solid #b5cbd6;">Strengths</th>
#     <th style="padding:12px; border:1px solid #b5cbd6;">Limitations</th>
#     <th style="padding:12px; border:1px solid #b5cbd6;">Strategic Gaps</th>
# </tr>
#
# <tr>
# <td style="padding:10px; border:1px solid #b5cbd6;"><b>Zillow</b></td>
# <td style="padding:10px; border:1px solid #b5cbd6;">
# • Large structured database<br>
# • Automated valuation (Zestimate)<br>
# • Interactive geographic analytics
# </td>
# <td style="padding:10px; border:1px solid #b5cbd6;">
# • Opaque valuation logic<br>
# • Errors in atypical properties<br>
# • US-focused ecosystem
# </td>
# <td style="padding:10px; border:1px solid #b5cbd6;">
# • Limited multi-modal explainability<br>
# • No integration of informal signals<br>
# • Limited conversational intelligence
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px; border:1px solid #b5cbd6;"><b>Redfin</b></td>
# <td style="padding:10px; border:1px solid #b5cbd6;">
# • Real-time listings<br>
# • Integrated brokerage model<br>
# • Advanced filtering system
# </td>
# <td style="padding:10px; border:1px solid #b5cbd6;">
# • Transaction-oriented focus<br>
# • Limited forecasting depth
# </td>
# <td style="padding:10px; border:1px solid #b5cbd6;">
# • Weak macroeconomic integration<br>
# • No predictive territorial modeling
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px; border:1px solid #b5cbd6;"><b>Idealista</b></td>
# <td style="padding:10px; border:1px solid #b5cbd6;">
# • Strong European coverage<br>
# • Structured listings<br>
# • Market statistics dashboards
# </td>
# <td style="padding:10px; border:1px solid #b5cbd6;">
# • Advertisement-centered model<br>
# • Limited AI-driven valuation depth
# </td>
# <td style="padding:10px; border:1px solid #b5cbd6;">
# • No 3D property reconstruction<br>
# • Limited generative decision support
# </td>
# </tr>
# </table>
#
# <p>
# Although these platforms represent significant advancements in digital real estate services, they primarily focus on listing aggregation and price estimation. They do not fully integrate multi-modal intelligence, predictive territorial modeling, conversational analytics, or spatial reconstruction capabilities. These gaps highlight an opportunity to design a more comprehensive and explainable AI-driven real estate intelligence framework.
# </p>
#
#
#
# <!-- ================= BUSINESS OBJECTIVES ================= -->
#
# <h2 style="color: #426d84;"> 🎯 2 — Business Objectives</h2>
#
# <p>
# The business objectives define the strategic value that this project aims to generate within the real estate ecosystem. They address structural inefficiencies such as information asymmetry, valuation subjectivity, limited predictive visibility, and restricted access to analytical tools.
# </p>
#
#
# <h3>BO1 — Establish a Centralized and Reliable Real Estate Intelligence Infrastructure</h3>
# <p>
# Develop a unified and continuously updated real estate data infrastructure capable of consolidating fragmented information originating from online listings, informal platforms, social media channels, and institutional sources into a single structured repository.
# </p>
# <b>Business Value:</b>
# <ul>
# <li>Reduces market opacity and fragmentation</li>
# <li>Creates a long-term strategic data asset</li>
# <li>Enables standardized cross-property comparison</li>
# <li>Improves decision reliability for all stakeholders</li>
# </ul>
#
#
# <h3>BO2 — Institutionalize Transparent and Explainable Property Valuation</h3>
# <p>
# Transform subjective pricing practices into explainable, data-driven valuation mechanisms that enhance fairness and credibility in property transactions.
# </p>
# <b>Business Value:</b>
# <ul>
# <li>Reduces pricing distortions and speculative bias</li>
# <li>Strengthens trust between buyers and sellers</li>
# <li>Supports negotiation transparency</li>
# <li>Improves professional valuation processes</li>
# </ul>
#
#
# <h3>BO3 — Deliver Advanced Regional and Spatial Market Intelligence</h3>
# <p>
# Provide granular territorial analytics capable of revealing spatial disparities, high-growth zones, undervalued areas, and emerging demand clusters.
# </p>
# <b>Business Value:</b>
# <ul>
# <li>Supports strategic investment planning</li>
# <li>Enhances urban and regional policy analysis</li>
# <li>Improves location-based risk assessment</li>
# <li>Identifies competitive market opportunities</li>
# </ul>
#
#
# <h3>BO4 — Enable Predictive Market Monitoring and Risk Anticipation</h3>
# <p>
# Develop forward-looking analytical capabilities that anticipate price evolution, market cycles, and structural shifts influenced by macroeconomic and demographic factors.
# </p>
# <b>Business Value:</b>
# <ul>
# <li>Reduces uncertainty in long-term investment decisions</li>
# <li>Improves portfolio and credit risk management</li>
# <li>Enhances strategic planning capabilities</li>
# <li>Supports proactive rather than reactive decisions</li>
# </ul>
#
#
# <h3>BO5 — Democratize Access to Advanced Real Estate Intelligence</h3>
# <p>
# Make sophisticated analytical insights accessible to non-expert users through intuitive visualization tools and conversational AI systems.
# </p>
# <b>Business Value:</b>
# <ul>
# <li>Empowers citizens with reliable market insights</li>
# <li>Reduces dependency on informal networks</li>
# <li>Expands access to analytical capabilities</li>
# <li>Enhances inclusivity in property decision-making</li>
# </ul>
#
# <p>
# Collectively, these objectives reposition real estate intelligence from a fragmented, opaque system toward a structured, transparent, and predictive ecosystem.
# </p>
#
#
#
# <!-- ================= DATA SCIENCE OBJECTIVES ================= -->
#
# <h2 style="color: #426d84;"> 🤖 3 — Data Science Objectives</h2>
#
# <p>
# The Data Science Objectives operationalize the business strategy into concrete analytical systems. Each objective translates a strategic market need into a measurable AI-driven capability built upon advanced modeling, automation, and multi-modal intelligence.
# </p>
#
#
# <h3>DSO1 — Autonomous AI Agents for Data Acquisition and Preparation</h3>
# <p>
# Design a multi-agent intelligent pipeline capable of continuously collecting, validating, cleaning, deduplicating, and structuring heterogeneous real estate data from dynamic digital environments.
# </p>
# <b>Data Science Scope:</b>
# <ul>
# <li>Automated scraping and monitoring agents</li>
# <li>Cross-platform deduplication mechanisms</li>
# <li>Schema harmonization and feature normalization</li>
# <li>Data quality validation and anomaly detection</li>
# </ul>
# <b>Expected Output:</b>
# <ul>
# <li>High-quality structured property database</li>
# <li>Reduced noise and redundancy</li>
# <li>Continuously updated market dataset</li>
# </ul>
#
#
# <h3>DSO2 — Multi-Modal Intelligent Property Valuation System</h3>
# <p>
# Develop an advanced multi-modal valuation engine integrating NLP, computer vision, and structured modeling to produce accurate and explainable property value estimates.
# </p>
# <b>Data Science Scope:</b>
# <ul>
# <li>Fusion of text, image, and numerical data</li>
# <li>Visual feature extraction (quality, condition, layout cues)</li>
# <li>NLP-based pricing signal detection</li>
# <li>Graph-based modeling of spatial relationships</li>
# </ul>
# <b>Expected Output:</b>
# <ul>
# <li>Explainable valuation scores</li>
# <li>Overvaluation and undervaluation detection</li>
# <li>Robust market-aligned predictions</li>
# </ul>
#
#
# <h3>DSO3 — Predictive Regional Trend Modeling Agent</h3>
# <p>
# Design forecasting systems capable of integrating macroeconomic, demographic, infrastructural, and financial indicators to anticipate regional market evolution.
# </p>
# <b>Data Science Scope:</b>
# <ul>
# <li>Advanced time-series forecasting</li>
# <li>Macro-feature engineering</li>
# <li>Regional demand modeling</li>
# <li>Scenario-based simulations</li>
# </ul>
# <b>Expected Output:</b>
# <ul>
# <li>Monthly and yearly regional forecasts</li>
# <li>Emerging zone detection</li>
# <li>Strategic predictive indicators</li>
# </ul>
#
#
# <h3>DSO4 — Conversational Decision Intelligence via Generative AI</h3>
# <p>
# Implement a generative AI assistant capable of translating complex analytical outputs into interactive, natural language insights and personalized recommendations.
# </p>
# <b>Data Science Scope:</b>
# <ul>
# <li>LLM integration with structured databases</li>
# <li>Retrieval-augmented generation pipelines</li>
# <li>Intent detection and contextual reasoning</li>
# <li>Automated report generation</li>
# </ul>
# <b>Expected Output:</b>
# <ul>
# <li>Interactive analytical chatbot</li>
# <li>Personalized recommendations</li>
# <li>Automated analytical summaries</li>
# </ul>
#
#
# <h3>DSO5 — Intelligent Spatial Reconstruction and Visualization System</h3>
# <p>
# Design AI models capable of generating coherent 2D layouts and 3D property representations using structured attributes and image-derived spatial cues.
# </p>
# <b>Data Science Scope:</b>
# <ul>
# <li>Layout inference algorithms</li>
# <li>Vision-based structural feature extraction</li>
# <li>3D reconstruction pipelines</li>
# <li>Spatial consistency validation</li>
# </ul>
# <b>Expected Output:</b>
# <ul>
# <li>Auto-generated 2D and 3D property visualizations</li>
# <li>Improved spatial interpretability</li>
# <li>Enhanced user understanding of property structure</li>
# </ul>
#
# <p>
# Together, these Data Science Objectives form the analytical backbone of the project, ensuring that business value is directly supported by scalable, intelligent, and explainable AI systems.
# </p>
#
#
#
# <!-- ================= FINAL CONCLUSION ================= -->
#
# <h2 style="color: #426d84;"> 🧩 Conclusion</h2>
#
# <p>
# The analysis of the current real estate intelligence landscape reveals significant structural limitations in transparency, predictive capability, and accessibility. While leading international platforms demonstrate the power of digital transformation, they still lack comprehensive multi-modal intelligence, regional forecasting depth, and conversational decision support.
#
# By clearly defining strategic Business Objectives and aligning them with rigorous Data Science Objectives, this project establishes a coherent roadmap toward a next-generation real estate intelligence framework. The result is not merely a listing platform, but an integrated AI-powered ecosystem capable of structuring fragmented market data, generating explainable valuations, forecasting regional dynamics, and democratizing access to advanced analytical insights.
# </p>

# %% [markdown]
# <h1 style=" color: #2c3e50; font-size: 34px; font-weight: bold;">
#     🧭 Analytical Approach
# </h1>
#
# <p style="font-size:16px;">
# This section presents the methodological and technical framework adopted to structure the development of the AI-powered real estate intelligence system. The project follows the Team Data Science Process (TDSP), a structured and iterative methodology designed to ensure rigor, scalability, and alignment between business needs and analytical implementation. In addition, this section introduces the system architecture that operationalizes the five Data Science Objectives into a coherent multi-layer intelligence framework.
# </p>
#
#
# <!-- ================= TDSP ================= -->
#
# <h2 style="color: #426d84;"> 📌 1 — Methodology: Team Data Science Process (TDSP)</h2>
#
# <p>
# The Team Data Science Process (TDSP) provides a lifecycle-based approach for developing data-driven solutions. It emphasizes iterative development, collaboration, validation, and deployment readiness. TDSP ensures that analytical development remains continuously aligned with business value.
# </p>
#
# <h3>🔹 TDSP Core Phases</h3>
#
# <ul>
# <li><b>1. Business Understanding</b> — Define strategic objectives, identify stakeholders, analyze the market context, and translate business challenges into measurable Data Science Objectives.</li>
#
# <li><b>2. Data Acquisition & Understanding</b> — Collect heterogeneous real estate data from multiple platforms, assess data quality, explore distributions, detect inconsistencies, and design the data schema.</li>
#
# <li><b>3. Modeling</b> — Develop, train, validate, and evaluate multi-modal valuation models, forecasting agents, conversational AI systems, and spatial reconstruction pipelines.</li>
#
# <li><b>4. Deployment</b> — Operationalize the models into an integrated intelligence framework with automated workflows, APIs, and user interfaces.</li>
# </ul>
#
# <p>
# TDSP is inherently iterative, meaning insights from modeling may lead to refined data pipelines or adjusted business assumptions. This feedback loop strengthens the robustness and real-world relevance of the final system.
# </p>
# <h2 style="color: #426d84;"> 🗓️ 2 — Project Timeline</h2>
#
# <div style="display:flex; align-items:center; justify-content:space-between; margin-top:30px;">
#     <!-- Phase 1 -->
#     <div style="text-align:center; width:22%;">
#         <div style="background-color:#5c8399; color:white; padding:10px; border-radius:8px; font-weight:bold;">
#             Business Understanding
#         </div>
#         <p style="margin-top:8px; font-size:14px;">
#             <b>20 Jan – 27 Jan</b><br>
#             Market analysis<br>
#             Stakeholders<br>
#             BO & DSO definition
#         </p>
#     </div>
#     <div style="height:4px; background-color:#426d84; flex-grow:1; margin:0 10px;"></div>
#     <!-- Phase 2 -->
#     <div style="text-align:center; width:22%;">
#         <div style="background-color:#5c8399; color:white; padding:10px; border-radius:8px; font-weight:bold;">
#             Data Acquisition & Understanding
#         </div>
#         <p style="margin-top:8px; font-size:14px;">
#             <b>27 Jan – 24 Feb</b><br>
#             Web scraping<br>
#             Economic data collection<br>
#             EDA
#         </p>
#     </div>
#     <div style="height:4px; background-color:#5c8399; flex-grow:1; margin:0 10px;"></div>
#     <!-- Phase 3 -->
#     <div style="text-align:center; width:22%;">
#         <div style="background-color:#5c8399; color:white; padding:10px; border-radius:8px; font-weight:bold;">
#             Modeling Phase
#         </div>
#         <p style="margin-top:8px; font-size:14px;">
#             <b>24 Feb – 20 April</b><br>
#             Valuation engine<br>
#             Forecasting agent<br>
#             Conversational AI
#         </p>
#     </div>
#     <div style="height:4px; background-color:#7b98a6; flex-grow:1; margin:0 10px;"></div>
#     <!-- Phase 4 -->
#     <div style="text-align:center; width:22%;">
#         <div style="background-color:#5c8399; color:white; padding:10px; border-radius:8px; font-weight:bold;">
#             Deployment
#         </div>
#         <p style="margin-top:8px; font-size:14px;">
#             <b>20 April – 11 May</b><br>
#             Integration<br>
#             API exposure<br>
#             Testing & validation
#         </p>
#     </div>
#
# </div>
# <!-- ================= ARCHITECTURE ================= -->
#
#
# <h2 style="color: #426d84;"> 🏗️ 3 — System Architecture (Detailed Overview)</h2>
#
# <p>
# The proposed architecture is designed as a modular, agent-based, and scalable AI ecosystem structured around two major layers: the <b>Data Layer</b> and the <b>Intelligence & Analytics Layer</b>. The architecture follows a pipeline-oriented yet feedback-enabled design, allowing continuous learning, data enrichment, and model refinement.
# </p>
#
# <p>
# Each component of the architecture corresponds directly to one or more Data Science Objectives (DSOs), ensuring that business strategy is tightly aligned with technical implementation.
# </p>
#
#
#
# <h3 style="color:#5c8399;"> 🔹 1. Data Layer — Intelligent Data Infrastructure</h3>
#
# <p>
# The Data Layer is responsible for transforming fragmented, heterogeneous, and partially unstructured real estate information into a standardized, high-quality analytical dataset. It operates through a coordinated multi-agent system supervised by a <b>Master Orchestrator Agent</b>.
# </p>
#
# <h4>🔸 Master Orchestrator Agent</h4>
# <p>
# This agent acts as the central coordinator of the data ecosystem. It schedules scraping tasks, monitors data quality checks, triggers cleaning workflows, and ensures synchronization between data sources. It also handles logging, version control of datasets, and error management.
# </p>
#
# <h4>🔸 Listing Scraper Agent</h4>
# <p>
# This autonomous agent collects property listings from digital platforms (e.g., Tayara, Mubawab) and potentially social media channels. It extracts:
# </p>
# <ul>
# <li>Structured attributes (price, location, surface, property type)</li>
# <li>Unstructured textual descriptions</li>
# <li>Property images</li>
# <li>Timestamps and listing metadata</li>
# </ul>
#
# <p>
# The agent is designed to handle pagination, duplicate detection, anti-bot constraints, and dynamic content extraction.
# </p>
#
# <h4>🔸 Economic & Regional Data Agent</h4>
# <p>
# This agent retrieves macroeconomic, demographic, and infrastructural indicators such as:
# </p>
# <ul>
# <li>Regional income levels</li>
# <li>Population density</li>
# <li>Interest rates</li>
# <li>Construction activity</li>
# <li>Urban development signals</li>
# </ul>
#
# <p>
# These features are critical for DSO3 (regional trend forecasting) and enhance valuation context modeling.
# </p>
#
# <h4>🔸 Data Cleaning & Standardization Agent</h4>
# <p>
# Once raw data is collected, this agent performs:
# </p>
# <ul>
# <li>Missing value handling</li>
# <li>Schema normalization</li>
# <li>Currency and unit standardization</li>
# <li>Deduplication across platforms</li>
# <li>Outlier detection</li>
# </ul>
#
# <p>
# The output is a centralized structured database that feeds the Intelligence Layer.
# </p>
#
#
#
# <h3 style="color:#5c8399;"> 🔹 2. Intelligence & Analytics Layer — AI Decision Core</h3>
#
# <p>
# This layer transforms structured data into actionable intelligence. It consists of specialized analytical modules, each corresponding to a strategic capability.
# </p>
#
#
#
# <h4>🔸 Multi-Modal Valuation Engine (DSO2)</h4>
#
# <p>
# This module integrates three complementary modeling pipelines:
# </p>
#
# <ul>
# <li><b>Structured Modeling Pipeline:</b> Gradient boosting / regression models trained on numerical and categorical attributes.</li>
# <li><b>NLP Pipeline:</b> Language models analyze property descriptions to detect qualitative signals such as luxury level, renovation status, urgency bias, or promotional language.</li>
# <li><b>Computer Vision Pipeline:</b> CNN/ViT-based models extract visual signals from property images (condition, brightness, space perception, finishing quality).</li>
# </ul>
#
# <p>
# A fusion layer combines outputs from these pipelines into a unified valuation score. Explainability mechanisms (feature importance, SHAP values) ensure interpretability.
# </p>
#
#
#
# <h4>🔸 Regional Trend Forecasting Agent (DSO3)</h4>
#
# <p>
# This module models price evolution at multiple geographic levels (city, district, neighborhood). It integrates:
# </p>
#
# <ul>
# <li>Historical transaction data</li>
# <li>Macroeconomic indicators</li>
# <li>Demand-supply signals</li>
# <li>Urban expansion patterns</li>
# </ul>
#
# <p>
# Advanced time-series and machine learning models generate forward-looking indicators such as:
# </p>
# <ul>
# <li>Price growth projections</li>
# <li>Volatility indexes</li>
# <li>Emerging zone detection</li>
# <li>Risk exposure scores</li>
# </ul>
#
# <p>
# This agent supports strategic investment and planning decisions.
# </p>
#
#
#
# <h4>🔸 Conversational AI Module (DSO4)</h4>
#
# <p>
# This module connects structured data and analytical outputs to a large language model (LLM) via Retrieval-Augmented Generation (RAG). It enables users to:
# </p>
#
# <ul>
# <li>Ask natural language queries</li>
# <li>Request property comparisons</li>
# <li>Generate analytical summaries</li>
# <li>Receive investment recommendations</li>
# </ul>
#
# <p>
# The conversational agent does not generate generic responses; instead, it grounds its answers in structured market data retrieved dynamically from the database.
# </p>
#
#
#
# <h4>🔸 Spatial Reconstruction & Visualization Engine (DSO5)</h4>
#
# <p>
# This module enhances spatial interpretability by generating 2D and 3D representations of properties. It combines:
# </p>
#
# <ul>
# <li>Layout inference models</li>
# <li>Vision-based structural feature extraction</li>
# <li>Geometric consistency validation</li>
# </ul>
#
# <p>
# The goal is not architectural precision but spatial coherence, allowing users to better understand volume, layout distribution, and structural organization.
# </p>
#
#
#
# <h3 style="color:#5c8399;"> 🔹 3. Integration & Data Flow</h3>
#
# <p>
# Data flows from the Data Layer into a centralized structured repository. The Intelligence Layer consumes this repository through API-based or pipeline-based access. Each analytical module produces enriched outputs (valuation scores, forecasts, explanations, 3D models) that are reintegrated into the system and exposed through user interfaces or dashboards.
# </p>
#
# <p>
# The architecture supports:
# </p>
#
# <ul>
# <li>Scalability (new agents can be added)</li>
# <li>Modularity (independent model updates)</li>
# <li>Continuous retraining</li>
# <li>Future integration with external APIs</li>
# </ul>
#
#
#
# <h3 style="color:#5c8399;"> 🔹 Architectural Philosophy</h3>
#
# <p>
# The system follows an agent-based intelligence paradigm where autonomous components specialize in specific analytical functions while remaining orchestrated within a unified ecosystem. This design ensures robustness, extensibility, and long-term adaptability to evolving market conditions.
# </p>
#
# <p>
# Rather than functioning as a simple listing aggregator, the architecture operates as a full-stack real estate intelligence platform capable of transforming raw digital signals into structured, predictive, and explainable market knowledge.
# </p>
#
#
#
#
#
# <h2 style="color: #426d84;"> 🖼️ 4 — Architecture Diagram</h2>
#
# <p>
# The following diagram illustrates the full system architecture described above:
# </p>

# %%
from IPython.display import Image
Image("architecture.png")

# %% [markdown]
# <h3 style="color:#5c8399;"> 🔹 Conclusion </h3>
#
# <p>
# The analytical approach adopted in this project ensures a structured, coherent, and technically robust pathway from problem definition to solution deployment. By relying on the TDSP (Team Data Science Process) methodology, we guaranteed that each phase of the project — from business understanding to deployment — was clearly defined, time-bounded, and aligned with both business and technical objectives. This structured progression reduced ambiguity, improved traceability, and allowed iterative improvements throughout the lifecycle of the project.
# </p>
#
# <p>
# The project timeline reflects a logical evolution:
# </p>
#
# <ul>
# <li>First, a deep understanding of the business context and strategic objectives.</li>
# <li>Then, systematic data acquisition and exploration to ensure data reliability and relevance.</li>
# <li>Followed by modeling and performance optimization to transform raw data into actionable intelligence.</li>
# <li>Finally, validation and deployment phases to operationalize the solution and ensure real-world usability.</li>
# </ul>
#
# <p>
# From an architectural perspective, the designed system is not a simple pipeline but an intelligent multi-agent ecosystem. The separation between the Data Layer and the Intelligence & Analytics Layer ensures modularity, scalability, and maintainability. Automated scraping agents, cleaning agents, orchestration components, machine learning models, forecasting modules, and conversational AI components all interact in a structured workflow. This architecture enables continuous data flow, automated preprocessing, predictive analytics, and intelligent interaction with users.
# </p>
#
# <p>
# Most importantly, this analytical approach ensures that the solution is:
# </p>
#
# <ul>
# <li>Data-driven (decisions are based on structured and validated data)</li>
# <li>Scalable (new data sources or models can be integrated)</li>
# <li>Automated (minimal manual intervention)</li>
# <li>Business-aligned (models directly support strategic objectives)</li>
# <li>Deployment-ready (designed for operational integration)</li>
# </ul>
#
# <p>
# In conclusion, the combination of a rigorous methodology (TDSP), a well-defined timeline, and a modular intelligent architecture transforms this project from a theoretical data science exercise into a practical, deployable, and scalable intelligent system. It demonstrates not only technical capability, but also the ability to manage an end-to-end data science lifecycle in a structured manner.
# </p>

# %% [markdown]
# <h1 style=" color: #2c3e50; font-size: 34px; font-weight: bold;">
#     📊 Data Acquisition and Understanding
# </h1>

# %% [markdown]
# <h2 style="color: #53629E;">
#     🏠 Real Estate Data Sources
# </h2>
#
# <p>
# In this section, we introduce the multiple data sources used to build our <strong>Tunisia Real Estate Intelligence Engine</strong>.
# Rather than relying on a single platform, we aggregate listings, agencies, blogs, macroeconomic data, and external benchmarking datasets to construct a multi-layered analytical ecosystem.
# </p>
#
# <p>
# Each platform contributes differently: some provide high-volume listing data, others offer structured agency-level information, while national institutions supply macroeconomic context. Together, they form the foundation for advanced modeling, geospatial analytics, price prediction, and investment intelligence.
# </p>
#
#
# <h2 style="color: #87BAC3;">🔵 Tayara</h2>
#
# <h3>🏗 Platform Nature</h3>
# <p>
# Tayara operates as a general classified advertisements platform where users can post listings across multiple categories including cars, jobs, electronics, and real estate. The real estate section is largely dominated by individual sellers rather than professional agencies, which results in a very dynamic environment with extremely high listing churn. Due to lighter moderation compared to specialized portals, the platform naturally contains more noise and variability in listing quality.
# </p>
#
# <h3>📊 Data Characteristics</h3>
# <p>
# The data extracted from Tayara is often unstructured and heterogeneous. Property descriptions are frequently written in a mixture of Arabic dialect and French, sometimes even combining multiple languages within the same listing. Duplicate listings are common due to reposting behavior, and prices may occasionally be missing or marked as negotiable. Location information is often stored in raw textual form (location_raw), and property amenities are sometimes embedded directly within the description instead of being clearly structured in dedicated fields.
# </p>
#
# <h3>📈 Market Segment Captured</h3>
# <p>
# Tayara primarily captures the mid-market and lower-middle real estate segments, with particularly strong representation in the rental market. The platform also reflects short-term reposting behavior, which provides insight into listing persistence and demand dynamics.
# </p>
#
# <h3>⚠️ Bias & Challenges</h3>
# <p>
# The dataset presents an over-representation of individual sellers and an under-representation of premium agencies. Additionally, fake listings and reposting behavior may distort supply perception, while some sellers may engage in price inflation tactics. These characteristics require careful cleaning and validation.
# </p>
#
# <h3>🧠 Modeling Impact</h3>
# <p>
# Despite its noise, Tayara provides a large volume of data that is highly valuable for training price prediction models. However, aggressive duplicate removal is necessary, and natural language processing techniques are essential for extracting structured information from descriptions. Feature engineering from textual content becomes a critical component when working with this dataset.
# </p>
#
# <p><strong>Tayara is your volume engine.</strong></p>
#
#
# <h2 style="color: #87BAC3;">🟢 Mubawab</h2>
#
# <h3>🏗 Platform Nature</h3>
# <p>
# Mubawab is a real estate-specialized portal that focuses exclusively on property listings. It features a strong presence of professional agencies and provides a structured user interface designed specifically for property search and filtering. Listings are generally high quality and professionally presented.
# </p>
#
# <h3>📊 Data Characteristics</h3>
# <p>
# The data from Mubawab is more structured and standardized compared to general classifieds platforms. Property taxonomy is clearly defined, amenities are systematically structured, and agency names are consistently available. Premium descriptors such as “standing” or “luxury” are common, and numerical attributes like surface area and room counts are generally reliable.
# </p>
#
# <h3>📈 Market Segment Captured</h3>
# <p>
# Mubawab predominantly captures the mid-to-high and premium real estate market segments, particularly in major urban areas such as Tunis, Sousse, and Sfax. The majority of listings are agency-managed, reflecting professional pricing strategies.
# </p>
#
# <h3>⚠️ Bias & Challenges</h3>
# <p>
# Because of its agency-focused nature, Mubawab under-represents low-budget housing. Agencies may also apply strategic overpricing, and descriptions tend to be polished marketing content, which may introduce stylistic bias in textual analysis.
# </p>
#
# <h3>🧠 Modeling Impact</h3>
# <p>
# Mubawab serves as a strong ground truth dataset due to its structured and reliable data. It is particularly well suited for luxury detection models, agency behavior analysis, and feature importance evaluation within predictive models.
# </p>
#
# <p><strong>Mubawab is your quality benchmark dataset.</strong></p>
#
#
# <h2 style="color: #87BAC3;">🟡 Tunisie Annonces</h2>
#
# <h3>🏗 Platform Nature</h3>
# <p>
# Tunisie Annonces is an older classified advertisements platform with a less modern interface compared to newer portals. It hosts a mixture of individual sellers and smaller local agencies, providing a different perspective on the Tunisian real estate market.
# </p>
#
# <h3>📊 Data Characteristics</h3>
# <p>
# The platform offers broader regional coverage, particularly in secondary cities. While it includes structured features, the level of standardization is lower than specialized real estate portals. In some cases, regional information is less precise than a full governorate-city-district hierarchy.
# </p>
#
# <h3>📈 Market Segment Captured</h3>
# <p>
# Tunisie Annonces captures properties in secondary cities and lower-competition areas, often representing local sellers and regionally concentrated demand.
# </p>
#
# <h3>⚠️ Bias & Challenges</h3>
# <p>
# The dataset may contain inconsistencies in data structure, occasional missing amenity flags, and a lower overall listing volume compared to larger platforms such as Tayara.
# </p>
#
# <h3>🧠 Modeling Impact</h3>
# <p>
# This platform is particularly useful for regional price modeling and for reducing Tunis-centric bias in the dataset. It also supports rural versus urban comparative analysis.
# </p>
#
# <p><strong>Tunisie Annonces gives you geographic diversity.</strong></p>
#
#
# <h2 style="color: #87BAC3;">🟠 BigDatis (Local Platform)</h2>
#
# <h3>🏗 Platform Nature</h3>
# <p>
# BigDatis operates as a structured real estate listing platform with a cleaner data hierarchy and less noise than general classified platforms. Its focus is more aligned with organized property listings.
# </p>
#
# <h3>📊 Data Characteristics</h3>
# <p>
# One of its main strengths is the clear governorate → city → district structure, which enhances geospatial precision. Amenity flags are well structured, seller types are explicitly identified, and scraped timestamps are consistently available.
# </p>
#
# <h3>📈 Market Segment Captured</h3>
# <p>
# BigDatis provides balanced market representation with moderate premium presence and relatively strong geo precision.
# </p>
#
# <h3>⚠️ Bias & Challenges</h3>
# <p>
# The platform may have a lower overall listing volume and smaller brand awareness compared to major portals.
# </p>
#
# <h3>🧠 Modeling Impact</h3>
# <p>
# BigDatis is highly valuable for geo-clustering tasks, district-level price modeling, and location-based predictive analysis.
# </p>
#
# <p><strong>BigDatis strengthens your geo intelligence layer.</strong></p>
#
#
# <h2 style="color: #87BAC3;">🟣 Houni</h2>
#
# <h3>🏗 Platform Nature</h3>
# <p>
# Houni is a news and blog platform rather than a listing-based marketplace. It provides editorial and journalistic coverage across economic and real estate topics.
# </p>
#
# <h3>📊 Extractable Value</h3>
# <p>
# From Houni, it is possible to extract real estate news, economic reform discussions, construction sector developments, investment announcements, and regulatory updates.
# </p>
#
# <h3>🧠 Advanced Use Cases</h3>
# <p>
# This source enables advanced sentiment analysis, detection of market optimism or pessimism cycles, correlation of news spikes with property price movements, and the construction of a market confidence index.
# </p>
#
# <p><strong>Houni powers your macro sentiment layer.</strong></p>
#
#
# <h2 style="color: #87BAC3;">🟤 Tecnocasa</h2>
#
# <h3>🏗 Platform Nature</h3>
# <p>
# Tecnocasa is an international real estate agency network with a strong brand presence and a highly structured agency data model. It represents professionally managed listings with consistent standards.
# </p>
#
# <h3>📊 Data Characteristics</h3>
# <p>
# Listings typically feature premium properties, professional photography, detailed structured attributes, and transparent agency pricing strategies.
# </p>
#
# <h3>📈 Market Segment Captured</h3>
# <p>
# Tecnocasa captures upper-middle and luxury segments of the market, including properties that may attract foreign investment and high-end rental demand.
# </p>
#
# <h3>⚠️ Bias & Challenges</h3>
# <p>
# Listings may be overpriced relative to market averages, overall listing volume may be limited, and most properties are strictly agency-controlled.
# </p>
#
# <h3>🧠 Modeling Impact</h3>
# <p>
# This dataset is excellent for luxury detection, premium price benchmarking, and defining the top 10% segment of the Tunisian property market.
# </p>
#
# <p><strong>Tecnocasa defines your premium market ceiling.</strong></p>
#
#
# <h2 style="color: #87BAC3;">🔴 Institut National de la Statistique</h2>
#
# <h3>🏗 Nature</h3>
# <p>
# The Institut National de la Statistique provides official government macroeconomic and demographic data.
# </p>
#
# <h3>📊 Extractable Data</h3>
# <p>
# Available data includes income distribution by region, population density, urban growth statistics, inflation indicators, construction permit records, and household size metrics.
# </p>
#
# <h3>🧠 Advanced Uses</h3>
# <p>
# These indicators allow the construction of price-to-income ratios, affordability indices, urban expansion prediction models, demand forecasting systems, and socioeconomic clustering analyses.
# </p>
#
# <p><strong>INS gives you economic context.</strong></p>
#
#
# <h2 style="color: #87BAC3;">🟣 Kaggle</h2>
#
# <h3>🏗 Nature</h3>
# <p>
# Kaggle is a global machine learning dataset and competition platform that provides access to international real estate datasets and modeling resources.
# </p>
#
# <h3>📊 Extractable Value</h3>
# <p>
# It offers house price datasets, feature engineering techniques, image classification models, competition notebooks, and benchmarking strategies.
# </p>
#
# <h3>🧠 Strategic Advantage</h3>
# <p>
# Through Kaggle, it becomes possible to compare the Tunisian market to global datasets, apply transfer learning, refine modeling architectures, and adopt proven feature engineering methodologies.
# </p>
#
# <p><strong>Kaggle strengthens your technical modeling layer.</strong></p>
#
#
# <h2 style="color: #87BAC3;">🧩 Platform Role Summary</h2>
#
# <table border="1" cellpadding="8" cellspacing="0">
# <tr>
# <th>Platform</th>
# <th>Role in Your System</th>
# </tr>
# <tr><td>Tayara</td><td>Volume & diversity</td></tr>
# <tr><td>Mubawab</td><td>Structured quality benchmark</td></tr>
# <tr><td>Tunisie Annonces</td><td>Regional diversity</td></tr>
# <tr><td>BigDatis</td><td>Geo precision</td></tr>
# <tr><td>Houni</td><td>Market sentiment</td></tr>
# <tr><td>Tecnocasa</td><td>Premium benchmark</td></tr>
# <tr><td>INS</td><td>Macro economics</td></tr>
# <tr><td>Kaggle</td><td>ML benchmarking</td></tr>
# </table>
#
# <h2 style="color: #87BAC3;">🎯 Conclusion</h2>
#
# <p>
# The strength of this project lies in integrating multiple complementary real estate data sources into a unified intelligence ecosystem rather than relying on a single platform. By combining high-volume classifieds for diversity, structured agency portals for quality benchmarks, regional platforms for geographic balance, premium networks for luxury segmentation, national statistics for macroeconomic context, and global machine learning datasets for technical benchmarking, we establish a robust and multi-layered analytical foundation. This integrated strategy reduces structural bias, enhances data reliability, and enables advanced applications including price prediction, geospatial modeling, sentiment analysis, affordability indexing, and investment-grade market intelligence.
# </p>

# %% [markdown]
# <h2 style="color: #53629E;">
#     🏠 Data Standardization
# </h2>

# %% [markdown]
# <p style="font-size:15px;">
# Data standardization is the process of transforming raw, heterogeneous datasets collected from multiple platforms into a single, schema-consistent, analysis-ready master dataset. Each real estate platform in this pipeline (Mubawab, Tayara, BigDatis, and Tunisie Annonce) uses different column names, different languages (French vs. English), different categorical label conventions, and different levels of field granularity. The standardization phase resolves all of these inconsistencies through a systematic sequence of operations: loading, shape verification, column removal, feature engineering, renaming, schema alignment, and final merge. The following cells walk through each transformation step in detail.
# </p>

# %% [markdown]
# <h2 style="color: #87BAC3;">📥 Loading Mubawab Listings</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This first step focuses on loading all raw CSV files collected from the <strong>Mubawab</strong> platform into a single unified DataFrame. Since the scraping process was split into multiple runs — each producing its own CSV file — we need to aggregate them into one cohesive dataset before any processing can begin.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The <code>glob.glob()</code> function scans the <code>Data/raw_listings/mubaweb/</code> directory and returns the paths of all <code>.csv</code> files stored there. Each file corresponds to a scraping batch. These files are then read individually using <code>pd.read_csv()</code> inside a generator expression and concatenated using <code>pd.concat()</code> with <code>ignore_index=True</code>, which resets the row index to avoid conflicts between files. The result is a single flat DataFrame called <code>mubaweb_df</code> containing all Mubawab listings discovered across all scraping runs. The <code>.head()</code> call at the end gives us a quick preview of the first rows to visually verify the data was loaded correctly.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Keeping data in separate files is a common practice when scraping in batches, but it creates fragmentation. Merging all files at this early stage ensures a single consistent working object throughout the pipeline. Failing to reset the index could cause duplicate index issues during joins or filtering later in the workflow.
# </p>

# %%
import pandas as pd
import glob

# Get all CSV file paths
mubaweb_files = glob.glob("Data/raw_listings/mubaweb/*.csv")

# Read and combine them into one DataFrame
mubaweb_df = pd.concat(
    (pd.read_csv(file) for file in mubaweb_files),
    ignore_index=True
)

# Check the result
mubaweb_df.head()
# Out:
#    listing_id                                        listing_url   source  \
# 0     7836763  https://www.mubawab.tn/fr/a/7836763/a-vendre-v...  mubawab
# 1     8187888  https://www.mubawab.tn/fr/a/8187888/charmant-d...  mubawab
# 2     8187887  https://www.mubawab.tn/fr/a/8187887/duplex-s3-...  mubawab
# 3     8080588  https://www.mubawab.tn/fr/a/8080588/superbe-fe...  mubawab
# 4     8201548  https://www.mubawab.tn/fr/a/8201548/ferme-zaid...  mubawab
#
#                                          title property_type transaction_type  \
# 0           A vendre villa jumelee a mourouj 3         Villa         à vendre
# 1  Charmant Duplex à Ain Zaghouan, Tunis 200m²           NaN         à vendre
# 2                Duplex S3 à Ain Zaghouan Nord           NaN         à vendre
# 3   Superbe Ferme en pleine activité à Soliman         Ferme         à vendre
# 4       Ferme Zaido à Vendre à Hydra Kasserine         Ferme         à vendre
#
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">📐 Verifying the Mubawab Dataset Shape</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# Before processing the data, it is essential to understand its scale. This cell outputs the total number of rows and columns in the Mubawab DataFrame, providing a baseline size measurement that helps validate the loading step and detect any obvious issues such as an unexpectedly low count.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>mubaweb_df.shape</code> returns a tuple <code>(rows, columns)</code>. The <code>print()</code> statement displays both dimensions with a descriptive label. This is a lightweight sanity check that costs no computation but saves significant debugging time.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Knowing the shape before any transformations establishes a reference point. If columns are unexpectedly missing or row counts seem off after subsequent transformations, we can trace changes back to this baseline. It also gives us a first quantitative understanding of the dataset volume before deeper exploration.
# </p>

# %%
print("number of lines " ,mubaweb_df.shape)
# Out:
# number of lines  (14210, 42)

# %% [markdown]
# <h2 style="color: #87BAC3;">🏷️ Assigning Transaction Type to Mubawab</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# Mubawab's raw data does not include a standardized <code>transaction_type</code> column. Since all listings scraped from Mubawab correspond exclusively to <strong>sale transactions</strong> (as opposed to rentals), we can safely add a constant column marking every row as <em>"Sale"</em>. This is a critical step for consistency when merging with other platforms later.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# A new column <code>transaction_type</code> is assigned a constant string value <code>"Sale"</code> for every row. The <code>.value_counts()</code> call then verifies that the assignment was applied uniformly across the dataset. This simple validation confirms that no row was accidentally left without a transaction type.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# In the merged dataset, listings from different platforms will include both sales and rentals. Without a reliable <code>transaction_type</code> field, it would be impossible to segment the market correctly. By enforcing this at the source level, we avoid label contamination downstream and preserve analytical integrity when modeling price differences between sales and rental markets.
# </p>

# %%
mubaweb_df["transaction_type"] = "Sale"
mubaweb_df["transaction_type"].value_counts()
# Out:
# transaction_type
# Sale    14210
# Name: count, dtype: int64

# %% [markdown]
# <h2 style="color: #87BAC3;">🚿 Adding Derived Feature Flags for Mubawab</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This step enriches the Mubawab dataset with two additional boolean feature flags that will be needed for schema alignment with other platforms. The first flag, <code>has_bathrooms</code>, is derived from existing data. The second, <code>has_heating</code>, is set to a default value since the information was not available in the Mubawab scrape.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>mubaweb_df["has_bathrooms"]</code> is created by checking whether the <code>bathrooms</code> column contains a non-null value using <code>.notna()</code>. This produces a boolean column — <code>True</code> if the listing specifies a bathroom count, <code>False</code> otherwise. In parallel, <code>has_heating</code> is set to <code>False</code> across the board since heating information was not captured during the Mubawab scraping phase. These flags follow the naming convention used across all datasets to ensure compatibility during the merge step.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Derived binary flags are a standard feature engineering practice in real estate modeling. They allow machine learning models to treat the <em>presence or absence</em> of an amenity as an independent signal, even when the underlying numeric attribute is missing. Setting <code>has_heating</code> to <code>False</code> rather than <code>None</code> prevents null propagation issues during model training and schema alignment.
# </p>

# %%
mubaweb_df["has_bathrooms"] = mubaweb_df["bathrooms"].notna()
mubaweb_df["has_heating"] = False

# %% [markdown]
# <h2 style="color: #87BAC3;">🔎 Inspecting the Mubawab Column List</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# Before removing or renaming columns, it is necessary to get a full view of all existing columns in the Mubawab DataFrame. This inspection step gives us the complete column inventory and helps identify which fields need to be dropped, renamed, or retained.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>mubaweb_df.columns</code> returns an <code>Index</code> object listing all column names in their current order. This is a zero-cost operation used purely for exploratory visibility. It is especially useful when working with scraped data where column names may vary from what was expected during design.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# In data preparation workflows, it is easy to lose track of the schema after multiple transformation steps. Explicitly printing the column list at key checkpoints prevents accidental operations on wrong column names, helps identify typos in scraped headers, and serves as a visual guide for the renaming and dropping steps that follow.
# </p>

# %%
mubaweb_df.columns
# Out:
# Index(['listing_id', 'listing_url', 'source', 'title', 'property_type',
#        'transaction_type', 'price', 'currency', 'price_type', 'surface_m2',
#        'rooms', 'total_rooms', 'bedrooms', 'bathrooms', 'floor',
#        'total_floors', 'country', 'governorate', 'city', 'district',
#        'description', 'language', 'image_count', 'image_urls', 'date_posted',
#        'last_updated', 'agency_name', 'seller_type', 'scrape_timestamp',
#        'characteristics', 'has_ascenseur', 'has_cave', 'has_chauffage',
#        'has_climatisation', 'has_jardin', 'has_meuble', 'has_parking',
#        'has_piscine', 'has_securite', 'has_standing', 'has_terrasse',
#        'has_vue_mer', 'has_bathrooms', 'has_heating'],
#       dtype='object')

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Dropping Irrelevant Columns from Mubawab (price_type)</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This step removes the <code>price_type</code> column from the Mubawab DataFrame. This field, which typically indicates whether a price is per square meter, total, or negotiable, was not captured consistently across platforms and therefore cannot be harmonized reliably in the final merged schema.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>pd.DataFrame.drop(columns=["price_type"])</code> removes the specified column from the DataFrame and reassigns the result back to <code>mubaweb_df</code>. The original DataFrame is overwritten in place, keeping the workflow memory-efficient. This is a non-destructive operation on the source files since the transformations apply only to the in-memory object.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Retaining columns that cannot be aligned across sources introduces schema mismatches during concatenation. More importantly, incomplete or inconsistent fields like <code>price_type</code> can mislead models during training if left in the dataset without proper handling. Proactively dropping such columns simplifies the schema and reduces downstream noise.
# </p>

# %%
mubaweb_df = mubaweb_df.drop(columns=["price_type"])

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Dropping the District Column from Mubawab</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# The <code>district</code> column is removed from the Mubawab dataset at this stage. While district-level geographic precision is desirable, this field was not available or consistently populated across all platforms in the pipeline, making it unsuitable for inclusion in the unified schema at this stage.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The column is dropped using the same <code>.drop(columns=[])</code> pattern as the previous step. The result is reassigned to <code>mubaweb_df</code>. This maintains the consistent pattern of step-by-step column removal for auditability and ease of debugging.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Geospatial granularity is valuable in real estate analysis, but only when it is reliable and available across datasets. Including a sparsely populated location column in the merged dataset would create artificial data sparsity and bias any geographic analysis. The <code>governorate</code> and <code>city</code> fields, which are more consistently available, serve as the primary geographic identifiers in the merged schema instead.
# </p>

# %%
mubaweb_df = mubaweb_df.drop(columns=["district"])

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Dropping the Language Column from Mubawab</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# The <code>language</code> column, which indicates the language in which a listing description was written, is removed from the Mubawab dataset. This metadata field is not present in all source datasets and does not contribute directly to the pricing or property modeling objectives of this pipeline.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The column is dropped using <code>.drop(columns=["language"])</code>. In the context of the Mubawab data, most listings are written in French or Arabic, but this signal — while potentially useful for NLP preprocessing — is too inconsistent across platforms to serve as a reliable shared feature in the merged dataset.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Language detection can still be re-applied later in the NLP pipeline if needed, using tools such as <code>langdetect</code> directly on the description text. At this standardization stage, however, the priority is to produce a clean, harmonized schema rather than retaining every possible metadata field that introduces schema asymmetry across data sources.
# </p>

# %%
mubaweb_df = mubaweb_df.drop(columns=["language"])

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Dropping the Characteristics Column from Mubawab</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# The <code>characteristics</code> column, which in the raw Mubawab data contains a semi-structured list of property attributes embedded as a string, is removed. The relevant amenity information from this field has already been parsed into individual boolean columns (e.g., <code>has_pool</code>, <code>has_elevator</code>) during the scraping phase, making this raw column redundant.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# Dropping <code>characteristics</code> at this point is a deliberate schema clean-up step. Retaining the original raw compound field alongside the parsed boolean flags would cause data redundancy and potential confusion about which representation to use during modeling. Removing it forces consistency and keeps the schema lean.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Raw compound fields such as embedded characteristic strings are incompatible with structured machine learning pipelines. Since all relevant information has already been extracted into dedicated columns, keeping this field only adds noise. This step exemplifies the general principle of preferring explicit structured columns over implicit compound representations in data preparation.
# </p>

# %%
mubaweb_df = mubaweb_df.drop(columns=["characteristics"])

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Dropping the has_bathrooms Flag from Mubawab</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# The <code>has_bathrooms</code> boolean flag created earlier in Step 4 is removed here. After further schema alignment analysis, it was determined that a numeric <code>bathrooms</code> count column — already present in the DataFrame — provides richer and more compatible information than a simple binary presence flag.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# This step illustrates an important aspect of iterative data preparation: columns created as intermediate artifacts may need to be removed once they are superseded by a better representation. The <code>bathrooms</code> column itself is retained, as it directly provides the number of bathrooms rather than just indicating their presence.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# In feature engineering, having both a numeric count and a binary flag for the same attribute can introduce collinearity in predictive models. Since all platforms will align on the numeric <code>bathrooms</code> field, the binary flag becomes redundant and is better removed at this stage to maintain a clean and non-redundant schema.
# </p>

# %%
mubaweb_df = mubaweb_df.drop(columns=["has_bathrooms"])

# %% [markdown]
# <h2 style="color: #87BAC3;">📐 Verifying Mubawab Shape After Column Removal</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# After a series of column drop operations, this step verifies that the Mubawab DataFrame has the expected reduced number of columns and that no unintended rows were lost during the transformation steps.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>mubaweb_df.shape</code> returns the updated <code>(rows, columns)</code> tuple. Comparing this value against the shape measured in Step 2 allows us to confirm exactly how many columns were removed and whether the row count remained stable. Any unexpected change in row count would indicate a data loss bug introduced by a previous operation.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Shape verification after transformation sequences is a best practice in data engineering. It acts as a lightweight automated assertion that the pipeline has behaved as expected. In production-grade pipelines, this type of check would typically be formalized using unit tests or data quality assertions frameworks.
# </p>

# %%
mubaweb_df.shape
# Out:
# (14210, 39)

# %% [markdown]
# <h2 style="color: #87BAC3;">🔤 Renaming Columns to English Standard for Mubawab</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This step translates all French-language amenity column names from the Mubawab scrape into their English equivalents using a standardized naming convention. This is a critical harmonization step that ensures that all four platform datasets share identical column names, enabling a clean final merge.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>pd.DataFrame.rename(columns={...}, inplace=True)</code> applies a mapping dictionary that translates each source column name to its target English name. For example, <code>has_ascenceur</code> (French for elevator) becomes <code>has_elevator</code>, and <code>has_piscine</code> (French for pool) becomes <code>has_pool</code>. Note that both <code>has_ascenceur</code> and <code>has_ascenseur</code> (two common spelling variants in the scraped data) are mapped to the same target <code>has_elevator</code>, handling a real-world spelling inconsistency discovered during data exploration.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Schema harmonization across multi-source datasets is one of the most critical and error-prone steps in data integration. A single column name mismatch between two DataFrames will cause misaligned columns during concatenation, producing unexpected <code>NaN</code> values instead of properly merged data. By standardizing to English at the source level, the final merge becomes a straightforward union rather than a complex alignment exercise.
# </p>

# %%
mubaweb_df.rename(columns={
    "has_ascenceur": "has_elevator",
    "has_cave": "has_basement",
    "has_chauffage": "has_heating",
    "has_climatisation": "has_air_conditioning",
    "has_piscine": "has_pool",
    "has_vue_mer": "has_sea_view",
    "has_terrasse": "has_terrace",
    "has_jardin": "has_garden",
    "has_securite": "has_security",
    "has_meuble": "has_furniture",
    "has_ascenseur" : "has_elevator"
}, inplace=True)

# %% [markdown]
# <h2 style="color: #87BAC3;">📥 Loading Tayara Listings</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This step replicates the loading logic applied to Mubawab, but now targets the <strong>Tayara</strong> platform directory. All raw Tayara CSV files are read and concatenated into a single DataFrame called <code>tayara_df</code>, which will undergo its own standardization workflow before being merged with the other datasets.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# Using the same <code>glob.glob()</code> + <code>pd.concat()</code> pattern, all CSV files under <code>Data/raw_listings/tayara/</code> are discovered and merged into one DataFrame. The <code>ignore_index=True</code> parameter resets the index to avoid index conflicts. The <code>.head()</code> preview provides an immediate visual check of the raw data structure, which is expected to look noisier and more heterogeneous than the Mubawab data due to the nature of the Tayara platform.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Tayara is the highest-volume data source in this pipeline and represents the informal, individual-seller segment of the Tunisian real estate market. Its data is inherently messier, with more missing values, mixed-language descriptions, and less standardized fields. Loading it correctly and keeping it as a separate DataFrame until schema alignment is complete is essential to maintaining pipeline clarity.
# </p>

# %%
# Get all CSV file paths
tayara_files = glob.glob("Data/raw_listings/tayara/*.csv")

# Read and combine them into one DataFrame
tayara_df = pd.concat(
    (pd.read_csv(file) for file in tayara_files),
    ignore_index=True
)

# Check the result
tayara_df.head()
# Out:
#                  listing_id  \
# 0  69777a69fea36ed612c9babe
# 1  69723931fea36ed612c7631d
# 2  6728f015981bc29b644499ac
# 3  69396e358914daae519919c2
# 4  6973914bd921b01419d1c80a
#
#                                                title  price_numeric currency  \
# 0  Appartement S+3 – 3ᵉ étage | Résidence Omrane ...       389151.0      TND
# 1                  Une villa à Gammarth avec piscine         7000.0      TND
# 2                             Immeuble à louer lac 3            0.0      TND
# 3                  À vendre un terrain \nla marsa               0.0      TND
# 4  À Louer – Espace Bureautique Haut Standing au ...            0.0      TND
#
#    price_raw    category      city governorate     location_raw  surface  ...  \
# 0  389151 DT    immoneuf   Ghazela      Ariana  Ghazela, Ariana   134.19  ...
# 1    7000 DT  immobilier  Gammarth       Tunis  Gammarth, Tunis     1.00  ...
# 2        NaN  immobilier   Le Kram       Tunis   Le Kram, Tunis  3000.00  ...
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">📐 Verifying the Tayara Dataset Shape</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This step checks the raw shape of the Tayara DataFrame immediately after loading, providing a baseline measurement before any column removal or renaming operations. This enables comparison with the post-transformation shape to verify that the standardization steps are applied correctly.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>tayara_df.shape</code> outputs the number of rows and columns currently in the DataFrame. Since Tayara is expected to be the largest dataset by volume (given its general-purpose classified platform nature), this count helps confirm whether the expected data volume was successfully loaded across all scraping batches.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Baseline shape verification is particularly important for Tayara because the platform's high listing churn means batch files can vary significantly in size. An unexpected row count at this point might indicate a missing batch file, a corrupted CSV, or an inconsistent file naming convention that caused some files to be missed by the glob pattern.
# </p>

# %%
tayara_df.shape
# Out:
# (21011, 27)

# %% [markdown]
# <h2 style="color: #87BAC3;">🏷️ Adding the Source Label to Tayara</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# A new column <code>source</code> is added to the Tayara DataFrame with the constant value <code>"tayara"</code>. This label will be preserved throughout the pipeline to enable source-level filtering, quality diagnostics, and platform-specific analysis in the final merged dataset.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The column is assigned a scalar string value <code>"tayara"</code>, which Pandas broadcasts across all rows automatically. The <code>.value_counts()</code> call confirms that every row received the label. Note that while Mubawab also has a <code>source</code> column in the raw data (set during scraping), the explicit assignment here ensures consistency and serves as a safety net against missing or incorrectly assigned source labels.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Tracking data provenance through a <code>source</code> column is a fundamental practice in multi-source data pipelines. Once datasets are merged, individual rows lose their origin context unless it is explicitly encoded. This field enables important downstream operations such as computing per-platform statistics, detecting platform-specific pricing biases, and diagnosing data quality issues in a platform-targeted manner.
# </p>

# %%
tayara_df["source"] = "tayara"
tayara_df["source"].value_counts()
# Out:
# source
# tayara    21011
# Name: count, dtype: int64

# %% [markdown]
# <h2 style="color: #87BAC3;">📐 Verifying Tayara Shape After Source Assignment</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This shape check confirms that the addition of the <code>source</code> column increased the column count by exactly one, and that no rows were accidentally dropped or duplicated during the previous assignment operation.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The <code>tayara_df.shape</code> call is repeated here as a post-operation verification. The expected result is the same number of rows as before, with one additional column compared to the shape measured in Step 14. This check is lightweight but valuable as a progression tracker in the standardization workflow.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# In complex data preparation pipelines, silent bugs — operations that execute without errors but produce unintended side effects — are among the most difficult to diagnose. Regularly checking the shape after significant operations creates a chain of evidence that helps isolate where things went wrong if a downstream issue is later discovered.
# </p>

# %%
tayara_df.shape
# Out:
# (21011, 28)

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Dropping price_raw from Tayara</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# The <code>price_raw</code> column, which contains the original unprocessed price string exactly as it appeared on the Tayara website (e.g., "150 000 TND"), is removed. The structured numeric equivalent of this field — <code>price_numeric</code> — was already extracted during scraping and will be renamed to the shared <code>price</code> field in a later step.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# Raw string price fields are discarded because they cannot be used directly in quantitative modeling without parsing. Since the parsing was already done at scraping time, retaining the raw string in the merged dataset serves no modeling purpose and only adds schema complexity. Dropping it keeps the dataset lean.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# In real estate datasets, price fields are among the most important features. Keeping both a raw string and a parsed numeric version of the same value creates redundancy and risks model confusion if both are accidentally included as features. Dropping <code>price_raw</code> at this stage ensures that only the clean, machine-readable price representation persists in the pipeline.
# </p>

# %%
tayara_df = tayara_df.drop(columns=["price_raw"])

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Dropping location_raw from Tayara</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# The <code>location_raw</code> column, which contains the original unprocessed location string from the Tayara listing (e.g., "Tunis, La Marsa"), is removed. Structured geographic fields — <code>governorate</code>, <code>city</code> — were already parsed from this raw string during or after scraping and serve as the authoritative geographic representation.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# Like <code>price_raw</code>, the <code>location_raw</code> field is an intermediate artifact that loses its value once structured location fields have been derived from it. Its removal prevents accidental use of unstructured strings in geographic analysis or spatial modeling steps.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Unstructured location strings are one of the most common sources of data quality issues in real estate datasets. They require natural language parsing, normalization, and geocoding before they can be used analytically. Since these steps have already been completed, retaining the raw string would only introduce ambiguity about which geographic representation to trust.
# </p>

# %%
tayara_df = tayara_df.drop(columns=["location_raw"])

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Dropping the category Column from Tayara</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# The <code>category</code> column from Tayara, which represents the listing category on the general classifieds platform (e.g., "Immobilier", "Maisons & Villas"), is dropped. Since our pipeline focuses exclusively on real estate listings, all records in the dataset already belong to the real estate domain, making this categorical distinction redundant.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# Tayara covers multiple product categories (electronics, vehicles, real estate, etc.), and the scraped data was already filtered to real estate listings during the scraping process. The <code>category</code> field therefore carries no discriminating value in the current dataset — all rows share the same category. Dropping it reduces the feature space without any information loss.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Zero-variance features (columns where all values are identical) provide no signal for machine learning models and can even cause issues in some algorithms. Proactively removing them at the data preparation stage is a standard practice in feature selection and improves pipeline efficiency and schema clarity.
# </p>

# %%
tayara_df = tayara_df.drop(columns=["category"])

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Dropping criteria_celliers from Tayara</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# The <code>criteria_celliers</code> column, which indicates whether a listing includes a cellar or storage room, is removed from the Tayara DataFrame. This amenity was not captured across all platforms in the pipeline and cannot be aligned with a corresponding field in the shared schema.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# Platform-specific amenity fields that lack cross-platform equivalents create asymmetry in the merged schema. While cellar information could theoretically be valuable for certain property types, including it exclusively for Tayara listings would produce a feature that is systematically missing for all other platform records, which is analytically problematic.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Features that are only available for a subset of the data introduce structural missingness that can bias models if not handled carefully. Rather than propagating such fields into the merged dataset as mostly-null columns, they are dropped at the source level to maintain schema integrity and reduce unnecessary imputation challenges.
# </p>

# %%
tayara_df = tayara_df.drop(columns=["criteria_celliers"])

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Dropping criteria_parking_sous_sol from Tayara</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# The <code>criteria_parking_sous_sol</code> column, which indicates whether a property has underground parking, is removed. Similar to the cellar field, this highly specific amenity type was not consistently captured across all platforms and cannot be mapped to a shared schema field without creating significant data asymmetry.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# This field is a more specific variant of parking information — specifically underground parking. The Tayara schema captures parking amenities in a more granular way than the other platforms, which use a generic <code>has_parking</code> flag. Rather than attempting to merge these into a single field (which would require complex logic and assumptions), the more granular Tayara-specific variant is dropped, with the generic <code>has_parking</code> field (captured via <code>criteria_parking</code>) retained.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Data harmonization sometimes requires sacrificing granularity in favor of consistency. A shared schema must represent the lowest common denominator of information available across all platforms. Retaining platform-specific sub-categories of an amenity while discarding the rest creates an unbalanced feature that can skew model training by encoding platform identity rather than property characteristics.
# </p>

# %%
tayara_df = tayara_df.drop(columns=["criteria_parking_sous_sol"])

# %% [markdown]
# <h2 style="color: #87BAC3;">📐 Verifying Tayara Shape After Column Drops</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# After a series of column removal operations on the Tayara DataFrame, this shape check verifies that the expected number of columns has been eliminated and that no row-level data was inadvertently affected. It provides a stable checkpoint before proceeding to column additions and renaming.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>tayara_df.shape</code> is called again to capture the post-drop dimensions. By comparing this to the shape measured in Steps 14 and 16, we can precisely track how many columns were removed in the prior steps. This running shape audit is especially valuable in collaborative notebooks where multiple contributors might modify the same pipeline.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Maintaining a shape audit trail across a complex multi-step standardization workflow is a key quality control practice. It allows any contributor reviewing the notebook to quickly verify the expected schema evolution at each stage without needing to re-execute the entire pipeline.
# </p>

# %%
tayara_df.shape
# Out:
# (21011, 23)

# %% [markdown]
# <h2 style="color: #87BAC3;">👤 Adding Agency and Seller Type Columns to Tayara</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# Two new columns — <code>agency_name</code> and <code>seller_type</code> — are added to the Tayara DataFrame with empty string default values. These fields exist in the Mubawab schema (where agency names and seller types were captured from the platform's structured listing pages), but were not available during Tayara scraping due to the platform's less structured seller information model.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# Assigning empty strings rather than <code>None</code> or <code>NaN</code> is a deliberate choice here. Empty strings can be easily filtered and are compatible with string-based operations without requiring null handling. However, in later cleaning stages, these could be converted to <code>None</code> to normalize null representations across the dataset. These columns are added now to ensure schema compatibility before the merge step.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# In the context of real estate market analysis, seller type (individual vs. agency) and agency name are meaningful analytical dimensions. Individual sellers tend to price differently from agencies, and certain agencies consistently operate in premium segments. While Tayara does not provide this structured information, adding placeholder columns ensures the merged DataFrame can later be enriched with inferred seller type information through NLP or behavioral analysis.
# </p>

# %%
tayara_df["agency_name"] = ""
tayara_df["seller_type"] = ""

# %% [markdown]
# <h2 style="color: #87BAC3;">📐 Verifying Tayara Shape After Column Additions</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This shape check confirms that the two newly added columns — <code>agency_name</code> and <code>seller_type</code> — were successfully appended to the Tayara DataFrame without any unintended side effects on the row count.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>tayara_df.shape</code> is called after the column additions. The expected result is two additional columns compared to the previous shape measurement in Step 22, with the row count unchanged. This micro-verification ensures that column assignment operations behaved as expected.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Column additions via direct assignment are generally safe in Pandas, but verifying them explicitly maintains the discipline of shape auditing throughout the pipeline. It also confirms that the column names were applied correctly and that no accidental overwriting of existing columns occurred.
# </p>

# %%
tayara_df.shape
# Out:
# (21011, 25)

# %% [markdown]
# <h2 style="color: #87BAC3;">🌍 Adding Country Column to Tayara</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# A <code>country</code> column with the constant value <code>"Tunisia"</code> is added to the Tayara DataFrame. This field is already present in the Mubawab schema and is added here to ensure schema compatibility between all platforms in the merge step.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# Since all datasets in this pipeline correspond exclusively to Tunisian real estate listings, the country field has no analytical discriminating power within the current scope. However, it is architecturally important: if the pipeline is later extended to include data from other countries (Morocco, Algeria, Egypt), the <code>country</code> field will become a critical segmentation dimension without requiring schema changes.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Adding country information is a forward-compatibility measure. It follows the principle of designing data schemas that can scale gracefully as the scope of the project expands. In enterprise data environments, geographic scope often expands over time, and retroactively adding a country column to a large merged dataset is far more complex than including it from the start.
# </p>

# %%
tayara_df["country"] = "Tunisia"

# %% [markdown]
# <h2 style="color: #87BAC3;">📐 Verifying Tayara Shape After Country Column Addition</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This shape check verifies that the <code>country</code> column was successfully added and that the row count remains stable following the column assignment operation.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>tayara_df.shape</code> is called again after the addition of the country column. The expected behavior is one additional column compared to the previous measurement, with the row count unchanged. This step maintains the shape audit trail established throughout the Tayara standardization sequence.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# While this check might seem repetitive, it is part of a systematic verification pattern that catches errors early — particularly in collaborative environments or when cells are re-executed out of order. Each verification step adds a low-cost safety net that protects the integrity of the pipeline.
# </p>

# %%
tayara_df.shape
# Out:
# (21011, 26)

# %% [markdown]
# <h2 style="color: #87BAC3;">🔎 Inspecting Tayara Column List</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This step displays the complete list of current column names in the Tayara DataFrame. The goal is to compare these names against the Mubawab schema to identify which columns need to be renamed and which might still be missing before the merge.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>tayara_df.columns</code> returns the current column index of the DataFrame. This visual inspection is performed at this point — after all drops and additions — to get the most current snapshot of the Tayara schema. The output of this cell is typically compared side-by-side with the output of the next cell, which inspects the Mubawab columns.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Cross-dataset column comparison is the foundation of schema alignment. By inspecting both DataFrames' column lists before renaming, we can create a precise mapping of Tayara-specific column names to their Mubawab equivalents. This prevents oversights in the renaming step and ensures that the final merge produces correctly aligned columns.
# </p>

# %%
tayara_df.columns
# Out:
# Index(['listing_id', 'title', 'price_numeric', 'currency', 'city',
#        'governorate', 'surface', 'bedrooms', 'description', 'date_posted',
#        'image_count', 'listing_url', 'scraped_at', 'criteria_ascenseur',
#        'criteria_chauffage_central', 'criteria_climatisation',
#        'criteria_parking', 'criteria_salles_de_bains', 'criteria_type_de_bien',
#        'criteria_type_de_transaction', 'image_urls',
#        'criteria_caméra_de_surveillance', 'source', 'agency_name',
#        'seller_type', 'country'],
#       dtype='object')

# %% [markdown]
# <h2 style="color: #87BAC3;">🔎 Inspecting Mubawab Column List for Comparison</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This cell displays the column list of the Mubawab DataFrame at its current state, immediately after its own standardization steps. Viewing it alongside the Tayara column list (Step 27) enables a direct visual comparison that drives the renaming logic in the next step.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>mubaweb_df.columns</code> outputs the Mubawab column index. At this stage, the Mubawab schema already contains renamed English columns after the transformations applied in Steps 6 through 12. The comparison between the two outputs reveals which Tayara columns have different names for the same concepts and which Tayara columns still need to be added via default values.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# This step is the diagnostic foundation for the renaming and alignment operations that follow. Without a clear side-by-side comparison of the two schemas at this stage, it would be easy to miss column name mismatches that would silently produce misaligned data after concatenation. This check transforms an implicit risk into an explicit, visible decision point.
# </p>

# %%
mubaweb_df.columns
# Out:
# Index(['listing_id', 'listing_url', 'source', 'title', 'property_type',
#        'transaction_type', 'price', 'currency', 'surface_m2', 'rooms',
#        'total_rooms', 'bedrooms', 'bathrooms', 'floor', 'total_floors',
#        'country', 'governorate', 'city', 'description', 'image_count',
#        'image_urls', 'date_posted', 'last_updated', 'agency_name',
#        'seller_type', 'scrape_timestamp', 'has_elevator', 'has_basement',
#        'has_heating', 'has_air_conditioning', 'has_garden', 'has_furniture',
#        'has_parking', 'has_pool', 'has_security', 'has_standing',
#        'has_terrace', 'has_sea_view', 'has_heating'],
#       dtype='object')

# %% [markdown]
# <h2 style="color: #87BAC3;">🔤 Renaming Columns to Shared Schema for Tayara</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This step performs the core schema alignment for the Tayara dataset by renaming its platform-specific column names to the standardized names established by the shared schema. This is the most critical transformation step in the Tayara standardization workflow and a prerequisite for a clean merge with the other datasets.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# A comprehensive renaming dictionary is applied using <code>.rename(columns={...}, inplace=True)</code>. Key mappings include:
# </p>
# <ul>
# <li><code>surface</code> → <code>surface_m2</code>: Adds the unit suffix for clarity and consistency with other platforms.</li>
# <li><code>criteria_ascenseur</code> → <code>has_elevator</code>: Converts the Tayara-specific criteria field to the shared boolean amenity naming convention.</li>
# <li><code>criteria_climatisation</code> → <code>has_air_conditioning</code>: Same pattern for air conditioning.</li>
# <li><code>criteria_parking</code> → <code>has_parking</code>: The generic parking flag that replaces the more granular underground parking field dropped earlier.</li>
# <li><code>criteria_salles_de_bains</code> → <code>has_bathrooms</code>: Normalizes the bathroom amenity field name.</li>
# <li><code>criteria_type_de_transaction</code> → <code>transaction_type</code>: Aligns the transaction type field name.</li>
# <li><code>scraped_at</code> → <code>scrape_timestamp</code>: Standardizes the scraping timestamp column name.</li>
# <li><code>price_numeric</code> → <code>price</code>: Renames the parsed numeric price to the shared price column name.</li>
# <li><code>criteria_caméra_de_surveillance</code> → <code>has_security</code>: Maps the surveillance camera criterion to the shared security flag.</li>
# <li><code>criteria_chauffage_central</code> → <code>has_heating</code>: Aligns the central heating indicator.</li>
# <li><code>criteria_type_de_bien</code> → <code>property_type</code>: Standardizes the property type field name.</li>
# </ul>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Without this renaming step, concatenating the Tayara and Mubawab DataFrames would result in a bloated schema with duplicate columns representing the same concept under different names (e.g., both <code>price</code> and <code>price_numeric</code> appearing as separate, mostly-null columns). This would corrupt the merged dataset and require complex post-merge remediation. Renaming at the source level is always preferable to attempting to fix alignment issues after the merge.
# </p>

# %%
tayara_df.rename(columns={
    "surface": "surface_m2",
    "criteria_ascenseur": "has_elevator",
    "criteria_climatisation": "has_air_conditioning",
    "criteria_parking": "has_parking",
    "criteria_salles_de_bains": "has_bathrooms",
    "criteria_type_de_transaction": "transaction_type",
    "scraped_at": "scrape_timestamp",
    "price_numeric": "price",
    "criteria_caméra_de_surveillance" : "has_security",
    "criteria_type_de_transaction" : "transaction_type",
    "criteria_chauffage_central" : "has_heating" ,
    "criteria_type_de_bien" : "property_type"
}, inplace=True)

# %% [markdown]
# <h2 style="color: #87BAC3;">🔄 Copying has_bathrooms to bathrooms in Tayara</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# In the Tayara schema, bathroom information was captured as a boolean criteria flag (<code>has_bathrooms</code>) rather than as a numeric count. To align with the Mubawab schema — which uses a numeric <code>bathrooms</code> field — the boolean flag is copied into a new <code>bathrooms</code> column as an intermediate step before the original flag is dropped.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>tayara_df["bathrooms"] = tayara_df["has_bathrooms"]</code> creates a new column by copying the values from the boolean criteria field. At this stage, the <code>bathrooms</code> column in Tayara will contain boolean values (<code>True</code>/<code>False</code>) rather than integer counts. This is a known limitation: Tayara did not expose the exact bathroom count, so the boolean presence flag is the best available approximation.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# This step illustrates an important data harmonization trade-off: when different platforms capture the same concept at different levels of granularity, the merged representation must accommodate the lowest available granularity. In this case, Tayara can only provide whether bathrooms exist, not how many. Including this as a boolean in the shared <code>bathrooms</code> field — rather than leaving it as null — preserves a meaningful signal, even if imperfect, for downstream models.
# </p>

# %%
tayara_df["bathrooms"] = tayara_df["has_bathrooms"]

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Removing the has_bathrooms Column from Tayara</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# Now that the bathroom information has been transferred to the <code>bathrooms</code> column in the previous step, the original boolean flag <code>has_bathrooms</code> is no longer needed and is removed to avoid schema redundancy.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>tayara_df.drop(columns=["has_bathrooms"])</code> removes the source boolean column after its values have been copied to the target <code>bathrooms</code> column. This completes the bathroom field migration from a Tayara-specific boolean format to the shared numeric-compatible format used across all platforms.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Keeping both <code>has_bathrooms</code> and <code>bathrooms</code> in the same DataFrame after the copy operation would create schema confusion. The shared schema uses <code>bathrooms</code> as the authoritative bathroom field. Removing the source boolean ensures that the Tayara DataFrame conforms exactly to the target schema, with no leftover platform-specific column names that could interfere with the merge step.
# </p>

# %%
tayara_df = tayara_df.drop(columns=["has_bathrooms"])

# %% [markdown]
# <h2 style="color: #87BAC3;">📊 Comparing Column Schemas Between Tayara and Mubawab</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This step performs a structured side-by-side comparison of all columns across the Tayara and Mubawab DataFrames. By computing the union of all column names and displaying which columns are present in each DataFrame, we get a precise visual inventory of remaining schema gaps before the merge.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The code computes the set union of both DataFrames' column names and sorts them alphabetically. For each column in the union, it records whether the column is present in Tayara, in Mubawab, or in both. The result is formatted as a comparison DataFrame with two columns — <code>tayara_df</code> and <code>mubaweb_df</code> — where empty strings indicate absence. This matrix view makes it immediately obvious which columns need to be added to Tayara (those present in Mubawab but absent from Tayara) and vice versa.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# This comparison step transforms schema alignment from a guesswork exercise into a data-driven process. Rather than manually tracking which columns exist in each DataFrame, the code generates a structured diff that serves as a clear specification for the missing column injection step that follows. It is the analytical equivalent of a schema diff tool used in database migration workflows.
# </p>

# %%
# Get sets of columns
tayara_cols = set(tayara_df.columns)
mubaweb_cols = set(mubaweb_df.columns)

# All unique columns
all_cols = sorted(tayara_cols | mubaweb_cols)

# Prepare aligned DataFrame
comparison_list = []
for col in all_cols:
    tayara_val = col if col in tayara_cols else ""
    mubaweb_val = col if col in mubaweb_cols else ""
    comparison_list.append({"tayara_df": tayara_val, "mubaweb_df": mubaweb_val})

comparison_df = pd.DataFrame(comparison_list)
comparison_df
# Out:
#                tayara_df            mubaweb_df
# 0            agency_name           agency_name
# 1              bathrooms             bathrooms
# 2               bedrooms              bedrooms
# 3                   city                  city
# 4                country               country
# 5               currency              currency
# 6            date_posted           date_posted
# 7            description           description
# 8                                        floor
# 9            governorate           governorate
# 10  has_air_conditioning  has_air_conditioning
# 11                                has_basement
# 12          has_elevator          has_elevator
# 13                               has_furniture
# 14                                  has_garden
# 15           has_heating           has_heating
# 16           has_parking           has_parking
# 17                                    has_pool
# 18                                has_sea_view
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🧩 Injecting Missing Columns into Tayara from Mubawab Schema</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# Based on the schema comparison performed in the previous step, this cell automatically adds all columns present in the Mubawab DataFrame but absent from the Tayara DataFrame, filling them with appropriate default values based on their data type. This is the final alignment step before the two datasets can be concatenated without schema conflicts.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The code computes the set difference between Mubawab columns and Tayara columns, then iterates over each missing column. For each missing column, it checks the data type in the Mubawab DataFrame:
# </p>
# <ul>
# <li><strong>Boolean columns</strong> are filled with <code>False</code> — assuming the absence of an amenity when no data is available is safer than assuming its presence.</li>
# <li><strong>Numeric columns</strong> are filled with <code>np.nan</code> — a standard missing value representation for numerical features in Pandas and scikit-learn.</li>
# <li><strong>All other columns</strong> (strings, objects, categories) are filled with <code>None</code> — the Python null equivalent, which Pandas stores as <code>NaN</code> for object dtypes.</li>
# </ul>
# <p>
# The list of added columns is printed at the end for auditability.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Type-aware default value assignment is a sophisticated and important detail. Using <code>False</code> for boolean amenity flags reflects the real-world assumption that Tayara listings without an explicit elevator flag do not have an elevator — rather than leaving this as an unknown. Using <code>np.nan</code> for numerics preserves the distinction between "zero" and "unknown", which is critical for imputation strategies and model interpretability. This step ensures the concatenation operation produces a clean, type-consistent merged DataFrame rather than one polluted with mistyped defaults.
# </p>

# %%
import numpy as np

# Columns missing in tayara
missing_cols = set(mubaweb_df.columns) - set(tayara_df.columns)

for col in missing_cols:
    dtype = mubaweb_df[col].dtype

    # Boolean → set False
    if dtype == bool:
        tayara_df[col] = False

    # Numeric → use np.nan
    elif np.issubdtype(dtype, np.number):
        tayara_df[col] = np.nan

    # Everything else (object, string, category, etc.)
    else:
        tayara_df[col] = None

print("Added columns:", missing_cols)
# Out:
# Added columns: {'floor', 'has_furniture', 'last_updated', 'rooms', 'has_pool', 'has_sea_view', 'has_terrace', 'total_floors', 'has_basement', 'has_standing', 'total_rooms', 'has_garden'}

# %% [markdown]
# <h2 style="color: #87BAC3;">✅ Re-verifying Schema Alignment After Missing Column Injection</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This step repeats the column comparison matrix from Step 32, now reflecting the state of both DataFrames after the missing column injection. The goal is to confirm that all schema gaps have been closed and that both DataFrames now share identical column sets — a prerequisite for a clean merge.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The same comparison logic from Step 32 is applied again. After a successful missing column injection, the expected result is a comparison matrix where every row shows both <code>tayara_df</code> and <code>mubaweb_df</code> populated — meaning no column is exclusive to either DataFrame. Any remaining empty cell in the output would indicate a gap that was missed and needs to be addressed before concatenation.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Schema verification after alignment is not optional — it is the only reliable way to confirm that the injection step performed correctly. Attempting to concatenate two DataFrames with mismatched schemas will not raise an error in Pandas; instead, it silently produces a result with misaligned columns and unexpected null columns. This silent failure mode makes pre-merge schema verification absolutely critical in multi-source data pipelines.
# </p>

# %%
# Get sets of columns
tayara_cols = set(tayara_df.columns)
mubaweb_cols = set(mubaweb_df.columns)

# All unique columns
all_cols = sorted(tayara_cols | mubaweb_cols)

# Prepare aligned DataFrame
comparison_list = []
for col in all_cols:
    tayara_val = col if col in tayara_cols else ""
    mubaweb_val = col if col in mubaweb_cols else ""
    comparison_list.append({"tayara_df": tayara_val, "mubaweb_df": mubaweb_val})

comparison_df = pd.DataFrame(comparison_list)
comparison_df
# Out:
#                tayara_df            mubaweb_df
# 0            agency_name           agency_name
# 1              bathrooms             bathrooms
# 2               bedrooms              bedrooms
# 3                   city                  city
# 4                country               country
# 5               currency              currency
# 6            date_posted           date_posted
# 7            description           description
# 8                  floor                 floor
# 9            governorate           governorate
# 10  has_air_conditioning  has_air_conditioning
# 11          has_basement          has_basement
# 12          has_elevator          has_elevator
# 13         has_furniture         has_furniture
# 14            has_garden            has_garden
# 15           has_heating           has_heating
# 16           has_parking           has_parking
# 17              has_pool              has_pool
# 18          has_sea_view          has_sea_view
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🏗️ Loading, Standardizing, and Aligning BigDatis Listings</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This comprehensive cell handles the complete standardization workflow for the <strong>BigDatis</strong> platform dataset in a single block. Following the same principles applied to Mubawab and Tayara, it loads the raw files, removes irrelevant columns, renames fields to the shared schema, adds missing columns, normalizes categorical values, and validates the result — all within one organized, commented pipeline.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The cell is structured into seven sequential stages:
# </p>
# <ul>
# <li><strong>Stage 1 — Load:</strong> All BigDatis CSV files are discovered and concatenated using the same <code>glob</code> + <code>pd.concat</code> pattern. The shape and head are printed for immediate validation.</li>
# <li><strong>Stage 2 — Drop:</strong> Platform-specific columns not aligned with the shared schema (<code>price_type</code>, <code>district</code>, <code>language</code>) are removed, following the same rationale as with Mubawab.</li>
# <li><strong>Stage 3 — Rename:</strong> BigDatis uses French field names similar to Mubawab but with some variations (e.g., <code>has_climatisseur</code> instead of <code>has_climatisation</code>, <code>has_meubles</code> instead of <code>has_meuble</code>). All are mapped to the shared English schema.</li>
# <li><strong>Stage 4 — Add Missing Columns:</strong> Fields present in the shared schema but absent from BigDatis are added with appropriate defaults: <code>country</code> = "Tunisia", <code>total_rooms</code> = None, <code>last_updated</code> = None, and <code>has_standing</code> = False.</li>
# <li><strong>Stage 5 — Normalize transaction_type:</strong> BigDatis uses French labels ("Vente", "Location") instead of the shared English labels ("Sale", "Rent"). A mapping dictionary is applied via <code>.map(lambda x: transaction_map.get(x, x))</code>, which translates known values while safely passing through any unknown values unchanged.</li>
# <li><strong>Stage 6 — Verify Shape and Columns:</strong> Shape and column list are printed to confirm the result.</li>
# <li><strong>Stage 7 — Deduplication Check:</strong> Before the merge, all three DataFrames are checked for duplicate column names — a common issue when scraping introduces repeated header rows. Duplicate columns are removed using <code>.loc[:, ~df.columns.duplicated()]</code>.</li>
# </ul>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# The transaction type normalization step is particularly important. Mixing French and English labels in the same column after the merge would break any analysis or model that relies on <code>transaction_type</code> as a categorical filter. Normalizing at the source level — before the merge — ensures categorical consistency throughout the pipeline. The duplicate column detection step addresses a subtle but dangerous issue: if a CSV file contains duplicate column headers (which can happen due to malformed scraping output), Pandas will silently keep both, leading to unpredictable behavior during merges and aggregations.
# </p>

# %%
# ─────────────────────────────────────────────
# 1. Load all bigdatis CSV files
# ─────────────────────────────────────────────
bigdatis_files = glob.glob("DATA/raw_listings/big_datis/*.csv")

bigdatis_df = pd.concat(
    (pd.read_csv(file) for file in bigdatis_files),
    ignore_index=True
)

print("Shape after loading:", bigdatis_df.shape)
print(bigdatis_df.head())

# ─────────────────────────────────────────────
# 2. Drop columns not needed for the merge
# ─────────────────────────────────────────────
bigdatis_df = bigdatis_df.drop(columns=["price_type"])
bigdatis_df = bigdatis_df.drop(columns=["district"])
bigdatis_df = bigdatis_df.drop(columns=["language"])

# ─────────────────────────────────────────────
# 3. Rename columns to match the shared schema
# ─────────────────────────────────────────────
bigdatis_df.rename(columns={
    "id"                  : "listing_id",
    "link"                : "listing_url",
    "surface"             : "surface_m2",
    "number_of_rooms"     : "rooms",
    "number_of_salle_de_bain": "bathrooms",
    "total_floor"         : "total_floors",
    "image_url"           : "image_urls",
    "scraped_at"          : "scrape_timestamp",
    "has_ascenseur"       : "has_elevator",
    "has_cave"            : "has_basement",
    "has_chauffage"       : "has_heating",
    "has_climatisseur"    : "has_air_conditioning",
    "has_jardin"          : "has_garden",
    "has_meubles"         : "has_furniture",
    "has_piscine"         : "has_pool",
    "has_terrasse"        : "has_terrace",
    "has_vue_sur_mer"     : "has_sea_view",
}, inplace=True)

# ─────────────────────────────────────────────
# 4. Add missing columns (present in mubawab/tayara but not in bigdatis)
# ─────────────────────────────────────────────
bigdatis_df["country"]      = "Tunisia"
bigdatis_df["total_rooms"]  = None
bigdatis_df["last_updated"] = None
bigdatis_df["has_standing"] = False

# floor already exists in bigdatis, keep it as-is

# ─────────────────────────────────────────────
# 5. Normalize transaction_type to match the shared schema
#    (bigdatis uses "Vente" / "Location", others use "Sale" / "Rent")
# ─────────────────────────────────────────────
transaction_map = {
    "Vente"    : "Sale",
    "Location" : "Rent",
}
bigdatis_df["transaction_type"] = bigdatis_df["transaction_type"].map(
    lambda x: transaction_map.get(x, x)
)

# ─────────────────────────────────────────────
# 6. Verify final columns
# ─────────────────────────────────────────────
print("\nShape after treatment:", bigdatis_df.shape)
print("\nColumns:", bigdatis_df.columns.tolist())

# ─────────────────────────────────────────────
# 7. (Optional) Compare columns across the three datasets
#    Uncomment once mubaweb_df and tayara_df are also loaded
# ─────────────────────────────────────────────


# ─────────────────────────────────────────────
# Check for duplicates in each df
print("mubaweb duplicates:", mubaweb_df.columns[mubaweb_df.columns.duplicated()].tolist())
print("tayara duplicates: ", tayara_df.columns[tayara_df.columns.duplicated()].tolist())
print("bigdatis duplicates:", bigdatis_df.columns[bigdatis_df.columns.duplicated()].tolist())

# Remove duplicate columns (keeps the first occurrence)
mubaweb_df  = mubaweb_df.loc[:, ~mubaweb_df.columns.duplicated()]
tayara_df   = tayara_df.loc[:, ~tayara_df.columns.duplicated()]
bigdatis_df = bigdatis_df.loc[:, ~bigdatis_df.columns.duplicated()]
# Out:
# Shape after loading: (13868, 37)
#         id                                           title  \
# 0  1203928            « A vendre appartement S1 sur plan »
# 1  1180444                      « tél appartement 405 m2 »
# 2  1184706  « Coquet studio à vendre à 140 MD à Hammamet »
# 3  1184528           « Appartement S+0 à vendre à Nabeul »
# 4  1233030         « S2 A vendre aux jardins de Carthage »
#
#                                                 link                source  \
# 0  https://bigdatis.tn/details/vente/el-mrezga/ap...               Mubawab
# 1  https://bigdatis.tn/details/vente/monastir-cen...                Tayara
# 2  https://bigdatis.tn/details/vente/hammamet-cen...                  Cava
# 3  https://bigdatis.tn/details/vente/nabeul/appar...               Fi Dari
# 4  https://bigdatis.tn/details/vente/jardins-de-c...  Facebook Marketplace
#
#   property_type transaction_type     price currency price_type  surface  ...  \
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🗺️ Loading, Standardizing, and Aligning Tunisie Annonce Listings</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This comprehensive cell applies the full standardization workflow to the <strong>Tunisie Annonce</strong> platform dataset. It introduces one unique challenge not present in the other datasets: the geographic information for this platform is stored in a single compound <code>region</code> string (e.g., "Localisation Tunisie>Tunis>La Marsa>El Aouina") that must be parsed and split into the shared <code>governorate</code> and <code>city</code> fields before the merge.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The standardization is organized into seven stages:
# </p>
# <ul>
# <li><strong>Stage 1 — Load:</strong> All Tunisie Annonce CSV files are loaded and concatenated. Shape and head are verified immediately.</li>
# <li><strong>Stage 2 — Drop:</strong> <code>price_type</code> and <code>language</code> are removed. Note that <code>district</code> is not explicitly dropped here since the geographic parsing step (Stage 3) replaces the entire <code>region</code> field.</li>
# <li><strong>Stage 3 — Parse Region:</strong> A custom <code>parse_region()</code> function is defined and applied using <code>.apply()</code>. This function splits the compound region string on the "&gt;" delimiter and extracts the governorate (index 1) and city (index 2) as separate fields. The index 0 ("Localisation Tunisie") and index 3 (district) are discarded. Null-safe handling is included via <code>pd.isna()</code> to prevent errors on missing values.</li>
# <li><strong>Stage 4 — Rename:</strong> Platform-specific field names are mapped to the shared English schema, following the same renaming conventions applied to BigDatis.</li>
# <li><strong>Stage 5 — Add Missing Columns:</strong> <code>country</code>, <code>total_rooms</code>, <code>last_updated</code>, <code>scrape_timestamp</code>, and <code>has_standing</code> are added with appropriate defaults.</li>
# <li><strong>Stage 6 — Normalize transaction_type:</strong> French labels ("Vente", "Location") are mapped to English equivalents ("Sale", "Rent") using the same translation dictionary as BigDatis.</li>
# <li><strong>Stage 7 — Verify:</strong> Shape, column list, and duplicate column check are printed.</li>
# </ul>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# The region parsing logic is the most technically sophisticated standardization step across all four platforms. It demonstrates an important principle: when geographic information is stored in compound strings rather than structured fields, a custom parsing function must be carefully designed to handle edge cases — including missing values, variable-length strings, and unexpected formats. The null-safe implementation using <code>pd.isna()</code> ensures that listings without a region string do not crash the pipeline. The discarding of the district-level component (index 3) is consistent with the decision made during Mubawab and BigDatis standardization to exclude district-level geography from the shared schema, maintaining geographic field consistency across all four datasets.
# </p>

# %%
import pandas as pd
import glob

# ─────────────────────────────────────────────
# 1. Load the tunisie_annonce CSV file(s)
#    (adjust the path/glob to match your folder structure)
# ─────────────────────────────────────────────
tunisie_files = glob.glob("DATA/raw_listings/tunisieannonce/*.csv")

tunisie_df = pd.concat(
    (pd.read_csv(file) for file in tunisie_files),
    ignore_index=True
)

print("Shape after loading:", tunisie_df.shape)
print(tunisie_df.head())

# ─────────────────────────────────────────────
# 2. Drop columns not needed for the merge
# ─────────────────────────────────────────────
tunisie_df = tunisie_df.drop(columns=["price_type"])
tunisie_df = tunisie_df.drop(columns=["language"])

# ─────────────────────────────────────────────
# 3. Parse 'region' into 'governorate' and 'city'
#    Raw format: "Localisation Tunisie>Tunis>La Marsa>El Aouina"
#    We take index [1] as governorate and [2] as city
# ─────────────────────────────────────────────
def parse_region(region_str):
    if pd.isna(region_str):
        return pd.Series({"governorate": None, "city": None})
    parts = region_str.split(">")
    # parts[0] = "Localisation Tunisie", parts[1] = governorate, parts[2] = city, parts[3] = district (ignored)
    governorate = parts[1].strip() if len(parts) > 1 else None
    city        = parts[2].strip() if len(parts) > 2 else None
    return pd.Series({"governorate": governorate, "city": city})

tunisie_df[["governorate", "city"]] = tunisie_df["region"].apply(parse_region)
tunisie_df = tunisie_df.drop(columns=["region"])

# ─────────────────────────────────────────────
# 4. Rename columns to match the shared schema
# ─────────────────────────────────────────────
tunisie_df.rename(columns={
    "id"                     : "listing_id",
    "link"                   : "listing_url",
    "surface"                : "surface_m2",
    "number_of_rooms"        : "rooms",
    "number_of_salle_de_bain": "bathrooms",
    "total_floor"            : "total_floors",
    "image_url"              : "image_urls",
    "has_ascenseur"          : "has_elevator",
    "has_cave"               : "has_basement",
    "has_chauffage"          : "has_heating",
    "has_climatisseur"       : "has_air_conditioning",
    "has_jardin"             : "has_garden",
    "has_meubles"            : "has_furniture",
    "has_piscine"            : "has_pool",
    "has_terrasse"           : "has_terrace",
    "has_vue_sur_mer"        : "has_sea_view",
}, inplace=True)

# ─────────────────────────────────────────────
# 5. Add missing columns (present in other dfs but not here)
# ─────────────────────────────────────────────
tunisie_df["country"]          = "Tunisia"
tunisie_df["total_rooms"]      = None
tunisie_df["last_updated"]     = None
tunisie_df["scrape_timestamp"] = None
tunisie_df["has_standing"]     = False

# ─────────────────────────────────────────────
# 6. Normalize transaction_type
#    tunisie_annonce uses "Vente" / "Location" → "Sale" / "Rent"
# ─────────────────────────────────────────────
transaction_map = {
    "Vente"    : "Sale",
    "Location" : "Rent",
}
tunisie_df["transaction_type"] = tunisie_df["transaction_type"].map(
    lambda x: transaction_map.get(x, x)
)

# ─────────────────────────────────────────────
# 7. Verify
# ─────────────────────────────────────────────
print("\nShape after treatment:", tunisie_df.shape)
print("\nColumns:", tunisie_df.columns.tolist())
print("\nDuplicate columns:", tunisie_df.columns[tunisie_df.columns.duplicated()].tolist())
# Out:
# Shape after loading: (10404, 34)
#         id                                              title  \
# 0  3449680  Offres de Vente à El Aouina (La Marsa) - Appar...
# 1  3312141  Offres de Vente à Jardins de Carthage (Ain Zag...
# 2  3416211  Offres de Vente à Carthage (Carthage) - Villa ...
# 3  3435295  Offres de Vente à El Aouina (La Marsa) - Appar...
# 4  3426435  Offres de Vente à Sidi Frej (La Soukra) - Vill...
#
#                                                 link           source  \
# 0  http://www.tunisie-annonce.com/Details_Annonce...  Tunisie Annonce
# 1  http://www.tunisie-annonce.com/Details_Annonce...  Tunisie Annonce
# 2  http://www.tunisie-annonce.com/Details_Annonce...  Tunisie Annonce
# 3  http://www.tunisie-annonce.com/Details_Annonce...  Tunisie Annonce
# 4  http://www.tunisie-annonce.com/Details_Annonce...  Tunisie Annonce
#
#   property_type transaction_type     price currency price_type surface  ...  \
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🔗 Merging All Four Datasets into a Unified DataFrame</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This is the culminating step of the data standardization phase: all four standardized DataFrames — Mubawab, Tayara, BigDatis, and Tunisie Annonce — are concatenated into a single unified <code>merged_df</code>. This merged dataset becomes the master analytical dataset that will power all subsequent modeling, forecasting, and intelligence modules in the pipeline.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# Before the merge, the Tunisie Annonce DataFrame is deduplicated for column names using <code>.loc[:, ~tunisie_df.columns.duplicated()]</code>, consistent with the deduplication applied to the other three DataFrames in Step 35. The merge itself is performed using <code>pd.concat([mubaweb_df, tayara_df, bigdatis_df, tunisie_df], ignore_index=True)</code>. This operation stacks all four DataFrames vertically — appending rows from each source beneath the previous — while aligning on column names. Because all four DataFrames now share the same schema after the standardization steps, every column in the result contains data from all four platforms (or null values where a platform didn't capture that field). The final shape is printed for immediate size validation.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# The quality of this merge is entirely dependent on the rigor of all preceding standardization steps. A successful merge with no unexpected null columns confirms that the schema alignment was performed correctly across all four platforms. Any schema mismatches — column name differences, type inconsistencies, or missing columns — would silently manifest as unexpected null columns in the merged result. The shape validation at the end provides the first opportunity to catch such issues: the total row count should equal the sum of rows from all four individual DataFrames, and the column count should equal the size of the shared schema.
# </p>

# %%
# ─────────────────────────────────────────────
# 8. Merge all four datasets
#    Uncomment once all four dataframes are ready
# ─────────────────────────────────────────────
# # Remove duplicate columns from each df before merging
tunisie_df  = tunisie_df.loc[:, ~tunisie_df.columns.duplicated()]

merged_df = pd.concat([mubaweb_df, tayara_df, bigdatis_df, tunisie_df], ignore_index=True)
print("\nMerged shape:", merged_df.shape)
# Out:
# Merged shape: (59493, 38)
# C:\Users\mohameddkhalil\AppData\Local\Temp\ipykernel_16740\551066302.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged_df = pd.concat([mubaweb_df, tayara_df, bigdatis_df, tunisie_df], ignore_index=True)

# %% [markdown]
# <h2 style="color: #87BAC3;">💾 Assigning IDs and Saving the Merged Dataset</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This final step assigns a unique sequential integer identifier to every row in the merged DataFrame and saves the result as a CSV file. The saved file becomes the primary input for all subsequent analytical phases of the LensEstate pipeline, including exploratory data analysis, feature engineering, and machine learning model training.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>merged_df.insert(0, "id", range(1, len(merged_df) + 1))</code> inserts a new column <code>id</code> at position 0 (the first column) with integer values from 1 to the total number of rows. Using <code>range(1, N+1)</code> produces 1-indexed IDs, which are generally more intuitive for human reading and database compatibility than 0-indexed identifiers. The DataFrame is then exported to CSV using <code>.to_csv()</code> with <code>index=False</code> to exclude the Pandas default integer index from the file, since the explicitly created <code>id</code> column already serves this purpose. The save path is printed as confirmation that the operation completed successfully.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Persisting the merged dataset to disk is a critical checkpoint in the pipeline. It means that all the standardization work performed across Steps 1–37 is preserved and does not need to be re-executed for every subsequent analysis. The unique <code>id</code> column is essential for data lineage tracking — it allows any processed or predicted result to be traced back to the original raw listing without ambiguity. Without a stable unique identifier, it becomes impossible to perform reliable joins, deduplications, or post-analysis result linking against the merged dataset.
# </p>

# %%
merged_df.insert(0, "id", range(1, len(merged_df) + 1))
merged_df.to_csv("Data/raw_listings/merged_listings.csv", index=False)
print("Saved to Data/raw_listings/merged_listings.csv")
# Out:
# Saved to Data/raw_listings/merged_listings.csv

# %% [markdown]
# <h2 style="color: #53629E;">
#     📰 Blog Articles Standardization
# </h2>
#
# <p style="font-size:15px;">
# Beyond property listings, this pipeline also integrates <strong>editorial blog content</strong> scraped from three Tunisian real estate platforms: <strong>Mubawab</strong>, <strong>BnB.tn</strong>, and <strong>Houni</strong>. These articles cover market trends, investment strategies, neighborhood guides, financing advice, and regulatory updates — forming a rich textual layer that can power sentiment analysis, topic modeling, and a retrieval-augmented generation (RAG) assistant.
# </p>
#
# <p style="font-size:15px;">
# Each source contributes a distinct editorial voice and thematic focus. The standardization goal is simple: retain only <code>title</code> and <code>content</code>, add a uniform <code>source</code> label to each article, and merge all three into one unified <code>merged_articles_df</code> dataset.
# </p>

# %% [markdown]
# <h2 style="color: #87BAC3;">📥 Loading Mubawab Blog Articles</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This cell loads the blog article dataset scraped from the <strong>Mubawab</strong> platform — Tunisia's leading professional real estate portal. Mubawab publishes a dedicated blog section that covers quarterly market reports, price indices, neighborhood spotlights, and regulatory analysis. The editorial content is data-driven and agency-oriented, making it one of the most analytically dense sources in the pipeline.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The CSV is read using <code>pd.read_csv()</code> with UTF-8 encoding (the default), which is consistent with the file's encoding as produced by the scraper. The raw DataFrame contains four columns: <code>page</code> (pagination number), <code>article_url</code> (full URL of the article), <code>title</code> (article headline), and <code>content</code> (full article text). The shape and first rows are printed immediately after loading for visual sanity-checking.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Mubawab's blog is the most structured and data-rich of the three sources. Its articles frequently cite exact price-per-square-meter statistics, region-level demand rankings, and year-over-year comparisons — making them particularly valuable for training or grounding a real estate question-answering system. Correctly loading this source at full volume is a prerequisite for downstream NLP and RAG applications.
# </p>

# %%
import pandas as pd

# Load Mubawab blog articles
mubawab_blog_df = pd.read_csv("Data/articles/mubaweb/mubawab_blog.csv")

print("Shape:", mubawab_blog_df.shape)
print("Columns:", mubawab_blog_df.columns.tolist())
mubawab_blog_df.head()
# Out:
# Shape: (980, 4)
# Columns: ['page', 'article_url', 'title', 'content']
#    page                                        article_url  \
# 0     1  https://blog.mubawab.tn/mubawab-devoile-son-bi...
# 1     1  https://blog.mubawab.tn/lapplication-mubawab-t...
# 2     1  https://blog.mubawab.tn/evolutions-du-marche-l...
# 3     1  https://blog.mubawab.tn/location-au-sahel-les-...
# 4     1  https://blog.mubawab.tn/location-a-tunis-les-q...
#
#                                                title  \
# 0          Mubawab dévoile son Bilan Immobilier 2025
# 1  L’application Mubawab Tunisie : votre compagno...
# 2  Évolutions du marché locatif en Tunisie : Loye...
# 3  Location au Sahel : Les quartiers les plus rec...
# 4  Location à Tunis : les quartiers les plus dema...
#
#                                              content
# 0  Lecture data-driven des dynamiques du marché i...
# 1  Dans un marché immobilier en pleine évolution,...
# 2  Le marché locatif tunisien continue de montrer...
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🧹 Selecting and Labeling Mubawab Articles</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This cell extracts only the two fields that matter for downstream NLP tasks — <code>title</code> and <code>content</code> — and attaches a <code>source</code> label identifying Mubawab as the origin of each article. All other metadata columns (<code>page</code>, <code>article_url</code>) are discarded as they carry no analytical value for text modeling.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# Column subsetting is done via direct bracket notation, selecting only <code>["title", "content"]</code> and reassigning the result back to <code>mubawab_blog_df</code>. The <code>source</code> column is then added with the constant string <code>"mubawab_blog"</code> broadcast across all rows. This naming convention distinguishes the blog content from the listing data coming from the same platform, ensuring clear provenance tracking throughout the merged dataset.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# The <code>source</code> label is the single most important metadata field in a merged multi-source text corpus. It allows the system to filter, weight, or prioritize articles by platform when performing retrieval. For example, a RAG assistant might prefer Mubawab articles when answering price-related queries — but only if the source is reliably encoded for every record.
# </p>

# %%
# Keep only title and content, add source label
mubawab_blog_df = mubawab_blog_df[["title", "content"]]
mubawab_blog_df["source"] = "mubawab_blog"

print("Shape after selection:", mubawab_blog_df.shape)
mubawab_blog_df.head(3)
# Out:
# Shape after selection: (980, 3)
#                                                title  \
# 0          Mubawab dévoile son Bilan Immobilier 2025
# 1  L’application Mubawab Tunisie : votre compagno...
# 2  Évolutions du marché locatif en Tunisie : Loye...
#
#                                              content        source
# 0  Lecture data-driven des dynamiques du marché i...  mubawab_blog
# 1  Dans un marché immobilier en pleine évolution,...  mubawab_blog
# 2  Le marché locatif tunisien continue de montrer...  mubawab_blog

# %% [markdown]
# <h2 style="color: #87BAC3;">📥 Loading BnB Blog Articles</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This cell loads the blog articles scraped from <strong>BnB.tn</strong>, a Tunisian real estate platform that publishes investor-oriented editorial content. BnB's blog covers practical topics such as buy-to-rent strategies, property renovation economics, circular economy approaches in construction, and market outlook articles. Its editorial angle is more investment-strategic compared to Mubawab's data-centric reporting.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The BnB CSV contains four columns: <code>title</code>, <code>date</code> (publication date, though sparsely populated), <code>url</code>, and <code>content</code>. It is read with the default UTF-8 encoding. Shape and column names are printed after loading to confirm the expected structure. The dataset is notably smaller than the Mubawab blog corpus, reflecting the more selective editorial cadence of the BnB platform.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# BnB's articles tend to be longer, more structured, and more actionable in nature — featuring concrete investment calculations, risk management frameworks, and strategic recommendations. This editorial depth makes them valuable for extracting structured financial insights and for answering nuanced investor queries within a conversational AI system.
# </p>

# %%
# Load BnB blog articles
bnb_blog_df = pd.read_csv("Data/articles/bnb/bnb_blog_articles.csv")

print("Shape:", bnb_blog_df.shape)
print("Columns:", bnb_blog_df.columns.tolist())
bnb_blog_df.head()
# Out:
# Shape: (78, 4)
# Columns: ['title', 'date', 'url', 'content']
#                                                title  date  \
# 0  Acheter pour louer : Stratégies gagnantes en 2026   NaN
# 1  L’économie circulaire dans l’immobilier : Réut...   NaN
# 2  L’évolution des plateformes immobilières avec ...   NaN
# 3  Utiliser l’open data pour anticiper les évolut...   NaN
# 4  Le secteur immobilier tunisien face à son plus...   NaN
#
#                                                  url  \
# 0  https://www.bnb.tn/acheter-pour-louer-strategi...
# 1  https://www.bnb.tn/leconomie-circulaire-dans-l...
# 2  https://www.bnb.tn/levolution-des-plateformes-...
# 3  https://www.bnb.tn/utiliser-lopen-data-pour-an...
# 4  https://www.bnb.tn/le-secteur-immobilier-tunis...
#
#                                              content
# 0  Acheter pour louer : Stratégies gagnantes en 2...
# 1  L’économie circulaire dans l’immobilier : Réut...
# 2  L’évolution des plateformes immobilières avec ...
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🧹 Selecting and Labeling BnB Articles</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This cell applies the same standardization logic used for Mubawab: retaining only <code>title</code> and <code>content</code>, and attaching the source label <code>"bnb_blog"</code>. The <code>date</code> and <code>url</code> columns are dropped as the date field is sparsely populated and the URL carries no textual modeling value.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# Column selection mirrors the Mubawab step exactly, enforcing a consistent minimal schema across all three sources. The <code>source</code> column receives the label <code>"bnb_blog"</code>, which uniquely identifies this platform's content in the merged corpus. This uniformity is what makes the multi-source merge lossless in terms of provenance — every row in the final dataset knows where it came from.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# The decision to drop the <code>date</code> column from BnB deserves explicit justification: because the field is nearly entirely null across the scraped records, including it would add a column that is overwhelmingly missing — creating a structural imbalance between sources in the merged schema. If date information becomes important in future pipeline versions, it can be re-introduced via a targeted re-scrape with proper timestamp extraction.
# </p>

# %%
# Keep only title and content, add source label
bnb_blog_df = bnb_blog_df[["title", "content"]]
bnb_blog_df["source"] = "bnb_blog"

print("Shape after selection:", bnb_blog_df.shape)
bnb_blog_df.head(3)
# Out:
# Shape after selection: (78, 3)
#                                                title  \
# 0  Acheter pour louer : Stratégies gagnantes en 2026
# 1  L’économie circulaire dans l’immobilier : Réut...
# 2  L’évolution des plateformes immobilières avec ...
#
#                                              content    source
# 0  Acheter pour louer : Stratégies gagnantes en 2...  bnb_blog
# 1  L’économie circulaire dans l’immobilier : Réut...  bnb_blog
# 2  L’évolution des plateformes immobilières avec ...  bnb_blog

# %% [markdown]
# <h2 style="color: #87BAC3;">📥 Loading Houni Blog Articles</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This cell loads the blog articles scraped from <strong>Houni.tn</strong>, a Tunisian real estate information platform that publishes neighborhood guides, mortgage comparison articles, legal advice, and lifestyle-oriented property content. Houni's editorial tone is more consumer-facing and educational, targeting first-time buyers and renters rather than professional investors.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The Houni CSV was scraped with a character encoding inconsistency: the file was saved in <strong>Latin-1</strong> (ISO-8859-1) rather than UTF-8, causing French accented characters (é, è, ê, à, ç, etc.) to appear as garbled sequences (e.g., <code>crÃ©dit</code> instead of <code>crédit</code>) when read naively. To fix this, the file is first loaded with <code>encoding="latin-1"</code> to prevent parsing errors, and then each string value is re-encoded to Latin-1 bytes and decoded as UTF-8 — the standard mojibake correction technique. The <code>fix_mojibake()</code> helper function handles this safely, with a try/except block that leaves values unchanged if the correction fails (e.g., for already-clean strings or irreparable sequences).
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Encoding corruption is one of the most common and damaging issues in web-scraped text data. If left uncorrected, garbled characters would propagate into every downstream NLP operation — breaking tokenizers, polluting vocabulary dictionaries, and producing nonsensical embeddings. Fixing the encoding at the loading stage is the only correct remedy: it ensures that the Houni articles enter the pipeline as clean, human-readable French text, fully compatible with French-language NLP models and tokenizers.
# </p>

# %%
# Load Houni blog articles — requires encoding fix (Latin-1 mojibake)
def fix_mojibake(text):
    """Fix text incorrectly read as Latin-1 that was originally UTF-8."""
    if not isinstance(text, str):
        return text
    try:
        return text.encode('latin-1').decode('utf-8')
    except (UnicodeDecodeError, UnicodeEncodeError):
        return text  # Return as-is if correction fails

houni_blog_df = pd.read_csv("Data/articles/houni/houni_blog_articles.csv", encoding="latin-1")
houni_blog_df = houni_blog_df.apply(lambda col: col.map(fix_mojibake))

print("Shape:", houni_blog_df.shape)
print("Columns:", houni_blog_df.columns.tolist())
houni_blog_df.head()
# Out:
# Shape: (51, 3)
# Columns: ['title', 'url', 'content']
#                                                title  \
# 0    Banques et crédits immobiliers : comparatif 202
# 1     Opportunités d’investissement à Bizerte – Guid
# 2         Top quartiers pour louer à Tunis – Guide 2
# 3  Colocation étudiants à Sousse et Monastir – Gu...
# 4   Louer une maison à Nabeul – Conseils pratiques 2
#
#                                                  url  \
# 0  https://www.houni.tn/fr/blog/top-quartiers-lou...
# 1  https://www.houni.tn/fr/blog/colocation-etudia...
# 2  https://www.houni.tn/fr/blog/louer-maison-nabe...
# 3  https://www.houni.tn/fr/blog/appartements-pas-...
# 4  https://www.houni.tn/fr/blog/villas-a-louer-bi...
#
#                                              content
# 0  Banques et crédits immobiliers en Tunisie : co...
# 1  Opportunités d’investissement à Bizerte – Guid...
# 2  Top quartiers pour louer à Tunis – Guide 2025\...
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🧹 Selecting and Labeling Houni Articles</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This cell applies the final standardization step to the Houni dataset: subsetting to <code>title</code> and <code>content</code>, and tagging all rows with the source label <code>"houni_blog"</code>. With this step complete, all three blog datasets share an identical three-column schema and are ready for merging.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The Houni raw DataFrame contains three columns: <code>title</code>, <code>url</code>, and <code>content</code>. Only <code>title</code> and <code>content</code> are retained, consistent with the treatment applied to Mubawab and BnB. The <code>url</code> column is dropped since article URLs are not required for text analysis. The <code>source</code> column is assigned the label <code>"houni_blog"</code>, completing the provenance metadata for this source.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Houni's consumer-oriented editorial content provides a different thematic dimension from the other two sources. Its neighborhood guides, mortgage comparisons, and first-buyer advice articles cover aspects of the real estate experience that are underrepresented in Mubawab's market-data reports and BnB's investor strategy pieces. Including Houni in the merged corpus broadens the topical coverage of the text dataset, making the eventual NLP system more capable of answering a wider range of user queries.
# </p>

# %%
# Keep only title and content, add source label
houni_blog_df = houni_blog_df[["title", "content"]]
houni_blog_df["source"] = "houni_blog"

print("Shape after selection:", houni_blog_df.shape)
houni_blog_df.head(3)
# Out:
# Shape after selection: (51, 3)
#                                              title  \
# 0  Banques et crédits immobiliers : comparatif 202
# 1   Opportunités d’investissement à Bizerte – Guid
# 2       Top quartiers pour louer à Tunis – Guide 2
#
#                                              content      source
# 0  Banques et crédits immobiliers en Tunisie : co...  houni_blog
# 1  Opportunités d’investissement à Bizerte – Guid...  houni_blog
# 2  Top quartiers pour louer à Tunis – Guide 2025\...  houni_blog

# %% [markdown]
# <h2 style="color: #87BAC3;">📊 Schema Comparison Across All Three Article Sources</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# Before merging, this cell performs a final schema verification by comparing the column lists of all three article DataFrames side by side. This confirms that the standardization steps applied to each source have produced identical schemas, ensuring a clean and conflict-free concatenation.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# The column sets of all three DataFrames are compared using a union-based alignment table — the same technique used during the listing dataset standardization. For each column in the union of all names, the table shows whether it is present in each source. After the selection and labeling steps applied above, all three DataFrames should show identical columns: <code>title</code>, <code>content</code>, and <code>source</code> — resulting in a perfectly aligned comparison table with no empty cells.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Schema verification before merge is a non-negotiable checkpoint. Even with three simple three-column DataFrames, a subtle naming discrepancy (e.g., <code>Content</code> vs <code>content</code>) would silently produce a six-column merged DataFrame with half the values as nulls. This check costs nothing and prevents a class of silent bugs that are difficult to detect once data has been combined.
# </p>

# %%
# Compare schemas across all three article sources
all_cols = sorted(set(mubawab_blog_df.columns) | set(bnb_blog_df.columns) | set(houni_blog_df.columns))

comparison = []
for col in all_cols:
    comparison.append({
        "mubawab_blog_df": col if col in mubawab_blog_df.columns else "",
        "bnb_blog_df":     col if col in bnb_blog_df.columns else "",
        "houni_blog_df":   col if col in houni_blog_df.columns else "",
    })

pd.DataFrame(comparison)
# Out:
#   mubawab_blog_df bnb_blog_df houni_blog_df
# 0         content     content       content
# 1          source      source        source
# 2           title       title         title

# %% [markdown]
# <h2 style="color: #87BAC3;">🔗 Merging All Three Article Datasets</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This is the culminating step of the article standardization phase. All three standardized blog DataFrames — from Mubawab, BnB, and Houni — are concatenated into a single unified <code>merged_articles_df</code>. The result is a clean, source-labeled, text-ready corpus covering the full editorial landscape of the Tunisian real estate market.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# <code>pd.concat([mubawab_blog_df, bnb_blog_df, houni_blog_df], ignore_index=True)</code> stacks all three DataFrames vertically, resetting the index. Because all three share the same three-column schema (<code>title</code>, <code>content</code>, <code>source</code>), the concatenation produces a perfectly aligned result with no null columns. The final shape and a distribution of articles per source (via <code>value_counts()</code>) are printed to confirm the merge was successful and to give a clear picture of the relative contribution of each platform to the corpus.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# The <code>source</code> column distribution printed at the end of this cell is particularly informative: it shows at a glance whether the corpus is dominated by a single platform (which could bias topic models or retrieval systems toward that source's editorial perspective). A balanced or intentionally weighted corpus is a design decision that should be made consciously rather than accidentally. This verification step makes that distribution explicit and actionable.
# </p>

# %%
# Merge all three article datasets into one unified corpus
merged_articles_df = pd.concat(
    [mubawab_blog_df, bnb_blog_df, houni_blog_df],
    ignore_index=True
)

print("Merged shape:", merged_articles_df.shape)
print("\nArticles per source:")
print(merged_articles_df["source"].value_counts())
merged_articles_df.head()
# Out:
# Merged shape: (1109, 3)
#
# Articles per source:
# source
# mubawab_blog    980
# bnb_blog         78
# houni_blog       51
# Name: count, dtype: int64
#                                                title  \
# 0          Mubawab dévoile son Bilan Immobilier 2025
# 1  L’application Mubawab Tunisie : votre compagno...
# 2  Évolutions du marché locatif en Tunisie : Loye...
# 3  Location au Sahel : Les quartiers les plus rec...
# 4  Location à Tunis : les quartiers les plus dema...
#
#                                              content        source
# 0  Lecture data-driven des dynamiques du marché i...  mubawab_blog
# 1  Dans un marché immobilier en pleine évolution,...  mubawab_blog
# 2  Le marché locatif tunisien continue de montrer...  mubawab_blog
# 3  Mubawab, leader des plateformes immobilières e...  mubawab_blog
# 4  Mubawab, leader des plateformes immobilières e...  mubawab_blog

# %% [markdown]
# <h2 style="color: #87BAC3;">💾 Assigning Article IDs and Saving the Merged Corpus</h2>
#
# <h3>🎯 Purpose</h3>
# <p>
# This final cell assigns a unique sequential integer identifier to every article in the merged corpus and saves the result to disk as a CSV file. The saved file becomes the authoritative article dataset that will be consumed by the NLP pipeline, the sentiment analysis module, and the RAG-based conversational assistant in subsequent project phases.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>
# A new column <code>article_id</code> is inserted at position 0 using <code>df.insert(0, "article_id", range(1, len(...) + 1))</code>, assigning 1-indexed integer IDs to every row. The DataFrame is then exported to CSV using <code>.to_csv()</code> with <code>index=False</code> to avoid writing the Pandas default integer index alongside the explicit <code>article_id</code>. The output path and final shape are printed as confirmation that the save operation completed successfully.
# </p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>
# Persisting the merged article corpus to disk is a critical pipeline checkpoint. It decouples the data preparation phase from the modeling phase, allowing NLP engineers to work with a stable, versioned input without re-running the entire standardization pipeline on every iteration. The unique <code>article_id</code> enables precise retrieval, result linking, and audit tracing — particularly important in a RAG system where each retrieved chunk must be traceable back to its source article for citation and quality evaluation purposes.
# </p>

# %%
merged_articles_df.to_csv("Data/articles/merged_articles.csv", index=False)

print("Saved to Data/raw_articles/merged_articles.csv")
print("Final shape:", merged_articles_df.shape)
merged_articles_df.head()
# Out:
# Saved to Data/raw_articles/merged_articles.csv
# Final shape: (1109, 3)
#                                                title  \
# 0          Mubawab dévoile son Bilan Immobilier 2025
# 1  L’application Mubawab Tunisie : votre compagno...
# 2  Évolutions du marché locatif en Tunisie : Loye...
# 3  Location au Sahel : Les quartiers les plus rec...
# 4  Location à Tunis : les quartiers les plus dema...
#
#                                              content        source
# 0  Lecture data-driven des dynamiques du marché i...  mubawab_blog
# 1  Dans un marché immobilier en pleine évolution,...  mubawab_blog
# 2  Le marché locatif tunisien continue de montrer...  mubawab_blog
# 3  Mubawab, leader des plateformes immobilières e...  mubawab_blog
# 4  Mubawab, leader des plateformes immobilières e...  mubawab_blog

# %% [markdown]
# <h2 style="color: #426d84;">🧩 Data Standardization — Conclusion</h2>
#
# <p>
# The data standardization phase successfully transformed six heterogeneous raw datasets — four property listing sources (Mubawab, Tayara, BigDatis, Tunisie Annonce) and three editorial article sources (Mubawab Blog, BnB Blog, Houni Blog) — into two clean, schema-consistent, analysis-ready master datasets.
# </p>
#
# <p>
# Across the listing pipeline, each platform required a tailored standardization sequence: column removal, French-to-English renaming, type-aware default injection, transaction type normalization, and geographic field parsing. Despite significant differences in platform architecture and data granularity, the process produced a single <strong>merged_listings.csv</strong> where every row shares a unified schema — enabling reliable cross-platform comparisons, model training, and geospatial analysis.
# </p>
#
# <p>
# For the article corpus, the standardization was leaner but introduced a distinct challenge: encoding correction for the Houni dataset, which required a mojibake repair step before any text-level operation could be applied reliably. The result is a three-column <strong>merged_articles.csv</strong> — title, content, source — that preserves full provenance and is immediately ready for NLP processing, topic modeling, and retrieval-augmented generation pipelines.
# </p>
#
# <p>
# With both master datasets now produced and persisted, the project transitions into the <strong>Data Understanding</strong> phase, where exploratory analysis will surface the statistical properties, distributions, quality issues, and structural patterns that will inform all subsequent modeling decisions.
# </p>

# %% [markdown]
# <h1 style="color: #2c3e50; font-size: 34px; font-weight: bold;">
#     📊 Data Understanding
# </h1>
#
# <p style="font-size:15px;">
# The Data Understanding phase applies systematic Exploratory Data Analysis (EDA) to both merged datasets. For the <strong>listings dataset</strong>, the analysis covers shape, data types, missing values, price distributions, geographic spread, property characteristics, and inter-feature correlations. For the <strong>articles dataset</strong>, the analysis covers corpus size, source balance, article length distributions, and vocabulary statistics. These insights will directly inform feature engineering, imputation strategies, and modeling choices in the phases that follow.
# </p>

# %% [markdown]
# <h2 style="color: #53629E;">🏠 EDA — Listings Dataset</h2>

# %% [markdown]
# <h2 style="color: #87BAC3;">🔧 Setup, Imports & Loading the Merged Listings Dataset</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell initializes the full analytical environment — importing all necessary libraries, applying a consistent visual theme aligned with the project's color palette, and loading the <strong>merged_listings.csv</strong> master dataset produced during the standardization phase.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The merged dataset contains <strong>59,493 listings</strong> across <strong>39 columns</strong>, combining property data from Mubawab, Tayara, BigDatis, Tunisie Annonce, and several smaller platforms. The preview confirms the schema is correctly unified: each row carries a unique <code>id</code>, a platform <code>source</code> label, a <code>transaction_type</code>, a <code>price</code>, and the full set of amenity flags and geographic fields established during standardization.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>With nearly 60,000 listings and 39 attributes, this is a rich, multi-dimensional dataset. However, the immediate visual inspection already hints at the presence of missing values in many columns — a pattern that will be quantified and visualized in the next steps. The presence of multiple sources with different data quality levels means that the EDA phase is not merely exploratory but also diagnostic.</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# ── Style ──────────────────────────────────────────────────────────────────
sns.set_theme(style="whitegrid", palette="muted")
PALETTE = ["#426d84", "#5c8399", "#7b98a6", "#87BAC3", "#d9e6ec", "#2c3e50"]
plt.rcParams.update({"figure.dpi": 130, "axes.titlesize": 13, "axes.labelsize": 11})

# ── Load ───────────────────────────────────────────────────────────────────
df = pd.read_csv("Data/raw_listings/merged_listings.csv", low_memory=False)
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (59493, 39)
#    id listing_id                                        listing_url   source  \
# 0   1    7836763  https://www.mubawab.tn/fr/a/7836763/a-vendre-v...  mubawab
# 1   2    8187888  https://www.mubawab.tn/fr/a/8187888/charmant-d...  mubawab
# 2   3    8187887  https://www.mubawab.tn/fr/a/8187887/duplex-s3-...  mubawab
# 3   4    8080588  https://www.mubawab.tn/fr/a/8080588/superbe-fe...  mubawab
# 4   5    8201548  https://www.mubawab.tn/fr/a/8201548/ferme-zaid...  mubawab
#
#                                          title property_type transaction_type  \
# 0           A vendre villa jumelee a mourouj 3         Villa             Sale
# 1  Charmant Duplex à Ain Zaghouan, Tunis 200m²           NaN             Sale
# 2                Duplex S3 à Ain Zaghouan Nord           NaN             Sale
# 3   Superbe Ferme en pleine activité à Soliman         Ferme             Sale
# 4       Ferme Zaido à Vendre à Hydra Kasserine         Ferme             Sale
#
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🗂️ Data Types Overview</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell audits the data type assigned to every column in the merged dataset, which is a critical step before any quantitative analysis. Columns stored as the wrong type — for instance, a numeric price stored as <code>object</code> — will silently fail during aggregation, statistics, and modeling.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>Several important type issues are revealed. <code>surface_m2</code> is stored as <code>object</code> (string) despite being a numeric measurement — confirming the need for explicit coercion applied in later cells. All amenity <code>has_*</code> columns show a mixed type situation: some are <code>bool</code> (correctly typed, e.g. <code>has_garden</code>, <code>has_pool</code>), while others are stored as <code>object</code> (e.g. <code>has_elevator</code>, <code>has_heating</code>) because they came from sources where these fields were populated as strings rather than booleans. <code>listing_id</code> is also typed as <code>object</code> rather than integer, reflecting the fact that different platforms use non-standardized ID formats.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>These type inconsistencies are a direct consequence of merging four platforms with different scraping schemas. They must be addressed in the data cleaning phase — specifically: coercing <code>surface_m2</code> and mixed amenity flags to their correct numeric or boolean types. Leaving them as <code>object</code> would prevent correlation analysis, model training, and any operation that requires arithmetic.</p>

# %%
# Data types overview
dtype_df = df.dtypes.reset_index()
dtype_df.columns = ["column", "dtype"]
dtype_df["dtype"] = dtype_df["dtype"].astype(str)
print(dtype_df.to_string(index=False))
# Out:
#               column   dtype
#                   id   int64
#           listing_id  object
#          listing_url  object
#               source  object
#                title  object
#        property_type  object
#     transaction_type  object
#                price float64
#             currency  object
#           surface_m2  object
#                rooms float64
#          total_rooms float64
#             bedrooms  object
#            bathrooms float64
#                floor float64
#         total_floors float64
#              country  object
#          governorate  object
#                 city  object
#          description  object
#          image_count   int64
#           image_urls  object
#          date_posted  object
#         last_updated float64
#          agency_name  object
#          seller_type  object
#     scrape_timestamp  object
#         has_elevator  object
#         has_basement    bool
#          has_heating  object
# has_air_conditioning  object
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🕳️ Missing Values Analysis</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell quantifies and visualizes the extent of missing data across all columns — one of the most important diagnostic steps in any real estate EDA. The bar chart shows the percentage of missing values per column, and the heatmap reveals the structural pattern of missingness across a 500-row sample.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The results reveal a severe missingness problem in several critical columns. <code>last_updated</code> and <code>total_floors</code> are missing in <strong>100%</strong> of records, making them entirely unusable without a dedicated re-scraping effort. <code>floor</code> is also nearly fully missing at <strong>100%</strong>. <code>total_rooms</code> is missing in <strong>91.3%</strong> of rows. Core modeling features are also significantly impacted: <code>rooms</code> is missing in <strong>75%</strong> of listings, <code>bathrooms</code> in <strong>67%</strong>, <code>agency_name</code> in <strong>64.4%</strong>, and <code>bedrooms</code> in <strong>63%</strong>. Even the most fundamental fields like <code>property_type</code> (<strong>41%</strong> missing) and <code>governorate</code> (<strong>39.2%</strong> missing) show significant gaps.</p>
# <p>More encouragingly, the most analytically critical field — <code>price</code> — is only missing in <strong>5.5%</strong> of listings, and <code>description</code> is nearly complete at just <strong>0.1%</strong> missing.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>The missingness pattern is not random — it is strongly structured by platform. Columns like <code>floor</code>, <code>total_floors</code>, and <code>total_rooms</code> were simply not captured by most platforms' scrapers. This means imputation strategies must be platform-aware and feature-specific. Columns with over 90% missing (<code>last_updated</code>, <code>total_floors</code>, <code>floor</code>) should be dropped from the modeling pipeline. The <code>rooms</code> and <code>bathrooms</code> fields, despite significant missingness, carry enough signal to be retained with careful imputation.</p>

# %%
# Missing values analysis
missing = df.isnull().mean().sort_values(ascending=False)
missing_df = missing[missing > 0].reset_index()
missing_df.columns = ["column", "missing_pct"]
missing_df["missing_pct_label"] = (missing_df["missing_pct"] * 100).round(1).astype(str) + "%"

fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Bar chart
colors = [PALETTE[0] if v < 0.5 else PALETTE[4] for v in missing_df["missing_pct"]]
axes[0].barh(missing_df["column"], missing_df["missing_pct"] * 100, color=colors)
axes[0].axvline(50, color="red", linestyle="--", linewidth=1, label="50% threshold")
axes[0].set_xlabel("Missing (%)")
axes[0].set_title("Missing Values per Column")
axes[0].legend()
for i, (v, lbl) in enumerate(zip(missing_df["missing_pct"], missing_df["missing_pct_label"])):
    axes[0].text(v * 100 + 0.5, i, lbl, va="center", fontsize=8)

# Heatmap sample (500 rows)
sample = df[missing_df["column"].tolist()].sample(min(500, len(df)), random_state=42).isnull()
sns.heatmap(sample.T, cmap=["#d9e6ec", "#426d84"], cbar=False,
            yticklabels=True, xticklabels=False, ax=axes[1])
axes[1].set_title("Missingness Pattern (500-row sample)")
axes[1].set_xlabel("Listings (sample)")

plt.tight_layout()
plt.savefig("Data/eda_missing_values.png", bbox_inches="tight")
plt.show()
print(missing_df.to_string(index=False))
# Out:
#               column  missing_pct missing_pct_label
#         last_updated     1.000000            100.0%
#         total_floors     1.000000            100.0%
#                floor     0.999731            100.0%
#          total_rooms     0.913082             91.3%
#                rooms     0.749550             75.0%
#            bathrooms     0.669575             67.0%
#          agency_name     0.644345             64.4%
#             bedrooms     0.629738             63.0%
#        property_type     0.409527             41.0%
#          governorate     0.392063             39.2%
#          seller_type     0.353235             35.3%
#         has_security     0.353100             35.3%
#          has_heating     0.352932             35.3%
# has_air_conditioning     0.352932             35.3%
#          has_parking     0.352899             35.3%
#         has_elevator     0.352899             35.3%
#          date_posted     0.241306             24.1%
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🌐 Source Distribution</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell breaks down the total listing count by data source — both as absolute counts and as percentage shares — to understand the relative contribution of each platform to the merged dataset.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The dataset is dominated by three main platforms. <strong>Tayara</strong> (combining lowercase and title-case variants) accounts for approximately <strong>37.6%</strong> of all listings (22,396 total), making it the highest-volume source. <strong>Mubawab</strong> (both variants combined) contributes about <strong>38.8%</strong> (23,113 listings). <strong>Tunisie Annonce</strong> adds a further <strong>19.5%</strong> (11,610 listings). Together, these three sources represent over <strong>95%</strong> of the dataset.</p>
# <p>A long tail of smaller platforms is also present: Facebook Marketplace (383), Tecnocasa (364), Affare (325), Menzili.Tn (259), Tunisiapromo (204), Cava (184), Ballouchi (175), Bnb Tunisie (169), Bigdatis (117), Century 21 (102), and Fi Dari (91). Notably, the source labels contain case inconsistencies — "mubawab" vs "Mubawab" and "tayara" vs "Tayara" — indicating that the <code>source</code> column normalization should be included in the cleaning phase.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>The dataset is strongly dominated by three platforms and skewed toward general classifieds (Tayara) and professional portals (Mubawab). The presence of premium-segment platforms like Tecnocasa and Century 21 — though in small numbers — adds valuable luxury market coverage. Source label normalization (lowercasing) is a required cleaning step to avoid treating "mubawab" and "Mubawab" as separate platforms in downstream analyses.</p>

# %%
# Source distribution
source_counts = df["source"].value_counts()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Bar
axes[0].bar(source_counts.index, source_counts.values,
            color=PALETTE[:len(source_counts)])
axes[0].set_title("Listings Count by Source")
axes[0].set_ylabel("Count")
for i, v in enumerate(source_counts.values):
    axes[0].text(i, v + 200, f"{v:,}", ha="center", fontsize=10)

# Pie
axes[1].pie(source_counts.values, labels=source_counts.index,
            colors=PALETTE[:len(source_counts)],
            autopct="%1.1f%%", startangle=140,
            wedgeprops={"edgecolor": "white", "linewidth": 1.5})
axes[1].set_title("Source Share")

plt.tight_layout()
plt.savefig("Data/eda_source_distribution.png", bbox_inches="tight")
plt.show()
print(source_counts)
# Out:
# source
# tayara                  21011
# mubawab                 14210
# Tunisie Annonce         11610
# Mubawab                  8903
# Tayara                   1385
# Facebook Marketplace      383
# Tecnocasa                 364
# Affare                    325
# Menzili.Tn                259
# Tunisiapromo              204
# Cava                      184
# Ballouchi                 175
# Bnb Tunisie               169
# Bigdatis                  117
# Century 21                102
# Fi Dari                    91
# Expat.Com                   1
# Name: count, dtype: int64

# %% [markdown]
# <h2 style="color: #87BAC3;">🏷️ Transaction Type & Property Type Distributions</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell examines the distribution of the two most fundamental categorical dimensions of any real estate dataset: transaction type (sale vs. rent) and property type (apartment, land, villa, etc.).</p>
#
# <h3>📊 Results & Observations</h3>
# <p><strong>Transaction Type:</strong> The dataset contains significant label inconsistencies. "Sale" listings appear under three different labels: <code>Sale</code> (38,482), <code>À Vendre</code> (6,313), and <code>sale</code> (11) — totaling approximately 44,806 sale listings. Similarly, rental listings appear as <code>À Louer</code> (10,870) and <code>rent</code> (21). This means the normalization applied during standardization was incomplete for some sources — French labels from certain platforms were not fully mapped to English equivalents.</p>
# <p><strong>Property Type:</strong> Apartments dominate the listing landscape (<code>Appartement</code>: 10,153 + <code>appartement</code>: 2,111 = ~12,264), followed by land plots (<code>Terrain</code>: 6,133 + <code>terrain</code>: 4,410 = ~10,543), and villas (<code>Villa</code>: 3,021). The same case-inconsistency problem observed in transaction types appears here too — "Maison" and "maison" are treated as separate categories despite representing the same property type.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>Both columns require mandatory normalization in the cleaning phase: standardizing all values to lowercase and unifying French/English variants. Without this, any model or analysis segmenting by transaction type or property type will produce fragmented, misleading distributions. After normalization, the dataset is clearly sale-dominant (~75% sale, ~18% rent) and apartment-centric — consistent with the expected structure of the Tunisian online real estate market.</p>

# %%
# Transaction type & property type distributions
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Transaction type
tx = df["transaction_type"].value_counts()
axes[0].bar(tx.index, tx.values, color=PALETTE[:len(tx)])
axes[0].set_title("Transaction Type Distribution")
axes[0].set_ylabel("Count")
for i, v in enumerate(tx.values):
    axes[0].text(i, v + 100, f"{v:,}", ha="center", fontsize=10)

# Property type (top 15)
pt = df["property_type"].value_counts().head(15)
axes[1].barh(pt.index[::-1], pt.values[::-1], color=PALETTE[0])
axes[1].set_title("Top 15 Property Types")
axes[1].set_xlabel("Count")

plt.tight_layout()
plt.savefig("Data/eda_type_distributions.png", bbox_inches="tight")
plt.show()
print("Transaction types:\n", tx)
print("\nTop property types:\n", pt)
# Out:
# Transaction types:
#  transaction_type
# Sale        38482
# À Louer     10870
# À Vendre     6313
# rent           21
# sale           11
# Name: count, dtype: int64
#
# Top property types:
#  property_type
# Appartement          10153
# Terrain               6133
# terrain               4410
# Villa                 3021
# maison                2851
# Maison                2356
# appartement           2111
# others                1032
# Autre                  954
# Local Commercial       865
# Bureau                 660
# Commerce               226
# Immeuble               220
# Ferme                  106
# Fonds de commerce       31
# Name: count, dtype: int64

# %% [markdown]
# <h2 style="color: #87BAC3;">💰 Price Distribution Analysis</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell performs a four-panel price distribution analysis: a log-scale histogram of all valid prices, a capped sale price histogram, a capped rent price histogram, and a box plot comparing price ranges by transaction type. Prices were pre-filtered to strictly positive, finite values to avoid artifacts from zero-priced or corrupted entries.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>After cleaning, <strong>54,368</strong> valid prices were retained, with 1,865 zero/negative/non-numeric entries removed. A critical issue is revealed: the rent price series returns <strong>0 valid records</strong>, meaning all rental listings in the dataset have their <code>transaction_type</code> labeled in a non-standard way (<code>À Louer</code> rather than <code>Rent</code>) — confirming the normalization gap identified in the previous cell. Sale price analysis shows a median of <strong>370,000 TND</strong> and a mean of approximately <strong>283 million TND</strong>, reflecting the extreme positive skew caused by luxury property outliers. The maximum recorded price is an extraordinary <strong>6.3 trillion TND</strong> — an obvious data entry error. The 25th percentile is 214,000 TND and the 75th percentile is 630,000 TND, placing the interquartile range of the bulk of the market between roughly 214K and 630K TND.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>The price column requires two immediate cleaning actions: (1) normalizing transaction type labels so that "À Louer" maps to "Rent", enabling separate rental price analysis; (2) applying a robust outlier removal strategy for price, as values like 6.3 trillion TND are clearly data entry errors that will destabilize any regression model. A log transformation of price is strongly recommended before model training, given the heavy right skew of the sale price distribution.</p>

# %%
# Price distribution analysis
# ── Clean: keep only strictly positive, finite prices ──────────────────────
price_raw = pd.to_numeric(df["price"], errors="coerce")
price = price_raw[price_raw > 0].dropna()

price_sale = pd.to_numeric(
    df[df["transaction_type"] == "Sale"]["price"], errors="coerce"
)
price_sale = price_sale[price_sale > 0].dropna()

price_rent = pd.to_numeric(
    df[df["transaction_type"] == "Rent"]["price"], errors="coerce"
)
price_rent = price_rent[price_rent > 0].dropna()

print(f"Valid prices (> 0): {len(price):,}  |  "
      f"Sale: {len(price_sale):,}  |  Rent: {len(price_rent):,}")
print(f"Removed {len(price_raw.dropna()) - len(price):,} zero/negative/non-numeric prices\n")

# Cap outliers at 99th percentile for visualization
p99_sale = price_sale.quantile(0.99)
p99_rent = price_rent.quantile(0.99)
p99_all  = price.quantile(0.99)

fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# Overall price histogram (log scale) — safe because price > 0
axes[0, 0].hist(np.log1p(price[price <= p99_all]), bins=60,
                color=PALETTE[0], edgecolor="white")
axes[0, 0].set_title("Price Distribution (log scale, capped at 99th pct)")
axes[0, 0].set_xlabel("log(price + 1)")
axes[0, 0].set_ylabel("Count")

# Sale prices (capped)
axes[0, 1].hist(price_sale[price_sale <= p99_sale], bins=60,
                color=PALETTE[0], edgecolor="white")
axes[0, 1].set_title(f"Sale Price Distribution (\u2264 99th pct: {p99_sale:,.0f} TND)")
axes[0, 1].set_xlabel("Price (TND)")
axes[0, 1].xaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, _: f"{x/1e6:.1f}M" if x >= 1e6 else f"{x/1e3:.0f}K"))

# Rent prices (capped)
axes[1, 0].hist(price_rent[price_rent <= p99_rent], bins=60,
                color=PALETTE[1], edgecolor="white")
axes[1, 0].set_title(f"Rent Price Distribution (\u2264 99th pct: {p99_rent:,.0f} TND)")
axes[1, 0].set_xlabel("Price (TND)")

# Box plot by transaction type (capped)
df_box = df.copy()
df_box["price"] = pd.to_numeric(df_box["price"], errors="coerce")
df_box = df_box[(df_box["price"] > 0) & (df_box["price"] <= p99_all)]
df_box.boxplot(column="price", by="transaction_type", ax=axes[1, 1],
               boxprops=dict(color=PALETTE[0]),
               medianprops=dict(color="red", linewidth=2))
axes[1, 1].set_title("Price by Transaction Type")
axes[1, 1].set_xlabel("Transaction Type")
axes[1, 1].set_ylabel("Price (TND)")
plt.suptitle("")

plt.tight_layout()
plt.savefig("Data/eda_price_distribution.png", bbox_inches="tight")
plt.show()

print("Price summary (all valid):")
print(price.describe().apply(lambda x: f"{x:,.0f}"))
print("\nSale price summary:")
print(price_sale.describe().apply(lambda x: f"{x:,.0f}"))
print("\nRent price summary:")
print(price_rent.describe().apply(lambda x: f"{x:,.0f}"))
# Out:
# Valid prices (> 0): 54,368  |  Sale: 35,283  |  Rent: 0
# Removed 1,865 zero/negative/non-numeric prices
# Price summary (all valid):
# count               54,368
# mean           185,128,049
# std         28,402,333,214
# min                      0
# 25%                 45,000
# 50%                265,000
# 75%                550,000
# max      6,300,000,700,000
# Name: price, dtype: object
#
# Sale price summary:
# count               35,283
# mean           283,651,503
# std         35,256,522,285
# min                     20
# 25%                214,000
# 50%                370,000
# 75%                630,000
# max      6,300,000,700,000
# Name: price, dtype: object
#
# Rent price summary:
# count      0
# mean     nan
# std      nan
# min      nan
# 25%      nan
# 50%      nan
# 75%      nan
# max      nan
# Name: price, dtype: object

# %% [markdown]
# <h2 style="color: #87BAC3;">⚠️ Outlier Detection — IQR Method on Price</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell applies the standard Interquartile Range (IQR) method to formally identify price outliers — computing the lower and upper fences and flagging listings that fall outside them. The top 10 highest-priced listings are also printed for manual inspection.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The IQR method defines valid price bounds as <strong>[−785,000 TND, 1,335,000 TND]</strong>, flagging <strong>3,582 listings (6.0%)</strong> as outliers. Manual inspection of the top 10 highest prices reveals clearly corrupt entries: a Sousse immeuble listed at <strong>6.3 trillion TND</strong>, La Marsa villas at <strong>1.4 trillion</strong> and <strong>1.28 trillion TND</strong>, and a Nabeul terrain at <strong>722 billion TND</strong>. These are almost certainly data entry errors where prices were entered in millimes instead of dinars, or digits were duplicated during scraping. Notably, all extreme outliers originate from the <strong>Mubawab</strong> source — suggesting either a scraping artifact or a listing management issue on that platform.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>The 6% outlier rate by IQR is manageable but consequential. For modeling purposes, a price ceiling of approximately 1.5–2 million TND should be applied as a pre-processing rule, or a log transformation combined with a percentile cap (e.g., 99th percentile capping at the preprocessing stage) should be enforced. The concentration of extreme outliers in Mubawab data points to a platform-specific data quality issue that should be flagged and monitored in the data pipeline.</p>

# %%
# Outlier detection — IQR method on price
Q1 = df["price"].quantile(0.25)
Q3 = df["price"].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["price"] < lower) | (df["price"] > upper)]
print(f"IQR bounds: [{lower:,.0f}, {upper:,.0f}]")
print(f"Outliers detected: {len(outliers):,} ({len(outliers)/len(df)*100:.1f}%)")
print(f"\nTop 10 highest prices:")
print(df.nlargest(10, "price")[["source", "transaction_type", "property_type",
                                  "governorate", "city", "price", "surface_m2"]].to_string(index=False))
# Out:
# IQR bounds: [-785,000, 1,335,000]
# Outliers detected: 3,582 (6.0%)
#
# Top 10 highest prices:
#  source transaction_type property_type governorate           city        price surface_m2
# mubawab             Sale      Immeuble         NaN   Sousse Ville 6.300001e+12        5.0
# mubawab             Sale         Villa         NaN       La Marsa 1.400000e+12      275.0
# mubawab             Sale         Villa         NaN       La Marsa 1.280000e+12        NaN
# mubawab             Sale       Terrain         NaN         Nabeul 7.220002e+11      687.0
# mubawab             Sale       Terrain         NaN      El Menzah 2.200000e+11      912.0
# mubawab             Sale           NaN         NaN Cité El Khadra 2.800004e+10        NaN
# mubawab             Sale           NaN         NaN       El Hamma 1.600001e+10        NaN
#  tayara              NaN           NaN       Tunis     Bab Souika 1.011010e+10        NaN
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🗺️ Geographic Distribution</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell examines the geographic spread of listings at the governorate level, displaying both listing volume and median sale price per governorate to reveal where the market is most active and most expensive.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The geographic distribution is highly concentrated in Tunisia's northeastern urban corridor. <strong>Tunis</strong> leads with 10,834 listings, followed by <strong>Nabeul</strong> (6,894), <strong>Ariana</strong> (6,212), <strong>Sousse</strong> (4,248), and <strong>Ben Arous</strong> (2,113 + 939 under "Ben arous" — another normalization gap). Together, the top 5 governorates account for over <strong>50%</strong> of all listings. Interior and southern governorates are dramatically underrepresented — Kairouan has only 87 listings, Gabes 93, and Jendouba 92 — reflecting both the real geographic concentration of the formal real estate market and the digital platform reach limitations in rural areas. The Ben Arous/Ben arous duplicate further confirms that governorate name normalization is required.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>The dataset has a strong coastal and urban bias. This means models trained on this data will generalize well for the Greater Tunis area and the Sahel coast, but may be unreliable for interior or southern regions due to data scarcity. Governorate name normalization (e.g., standardizing "Ben Arous"/"Ben arous", "La Manouba"/"Manouba") is required before any geographic analysis or model training. Geographic features — particularly governorate and city — will be among the most predictive variables in price modeling but require careful encoding due to high cardinality.</p>

# %%
# Geographic distribution — governorate level
gov_counts = df["governorate"].value_counts().head(20)

fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Listing count by governorate
axes[0].barh(gov_counts.index[::-1], gov_counts.values[::-1], color=PALETTE[0])
axes[0].set_title("Top 20 Governorates by Listing Count")
axes[0].set_xlabel("Number of Listings")
for i, v in enumerate(gov_counts.values[::-1]):
    axes[0].text(v + 50, i, f"{v:,}", va="center", fontsize=8)

# Median price by governorate (top 20 by count)
gov_price = (df[df["governorate"].isin(gov_counts.index)]
             .groupby("governorate")["price"]
             .median()
             .sort_values(ascending=False))

axes[1].barh(gov_price.index[::-1], gov_price.values[::-1], color=PALETTE[1])
axes[1].set_title("Median Price by Governorate (Top 20 by count)")
axes[1].set_xlabel("Median Price (TND)")
axes[1].xaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f"{x/1e3:.0f}K"))

plt.tight_layout()
plt.savefig("Data/eda_geographic_distribution.png", bbox_inches="tight")
plt.show()
print(gov_counts)
# Out:
# governorate
# Tunis         10834
# Nabeul         6894
# Ariana         6212
# Sousse         4248
# Ben Arous      2113
# Sfax           1070
# Ben arous       939
# Bizerte         706
# Zaghouan        557
# Monastir        492
# Manouba         335
# La Manouba      325
# Mahdia          322
# Médenine        216
# Beja            113
# Gabes            93
# Jendouba         92
# Kairouan         87
# Gabès            86
# Le Kef           66
# Name: count, dtype: int64

# %% [markdown]
# <h2 style="color: #87BAC3;">📐 Surface Area Analysis</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell analyzes the distribution of property surface areas in square meters, and cross-plots surface against price to visualize the relationship between the two most fundamental property value drivers.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>After coercing <code>surface_m2</code> to numeric (resolving the string type issue identified earlier) and filtering for positive values, <strong>38,928 listings</strong> have valid surface data — only 65% coverage across the dataset. The distribution is extremely right-skewed: the median surface is <strong>134 m²</strong> and the 75th percentile is 313 m², but the mean jumps to <strong>10,394 m²</strong> due to massive outliers including a maximum of <strong>58 million m²</strong> — clearly a data error (likely a land plot with area entered in square centimeters or an erroneous extra digit). The bulk of the market sits in the <strong>50–400 m²</strong> range. The surface vs. price scatter confirms a positive correlation — larger properties command higher prices — though the relationship is noisy, consistent with other factors (location, type, condition) also driving price.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>Surface area is a highly valuable feature for price modeling but requires aggressive outlier treatment before use. A practical cleaning rule would be to cap surface at <strong>2,000 m²</strong> for residential listings and handle land plots separately, since their area distribution follows a fundamentally different scale. The low coverage (65%) also means surface-based features like price-per-m² will only be available for a subset of listings — models must be designed to handle this missingness gracefully.</p>

# %%
# Surface area analysis
df["surface_m2"] = pd.to_numeric(df["surface_m2"], errors="coerce")
df["price"]      = pd.to_numeric(df["price"],      errors="coerce")
surface = df["surface_m2"].dropna()
surface_capped = surface[surface <= surface.quantile(0.99)]

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(surface_capped, bins=60, color=PALETTE[0], edgecolor="white")
axes[0].set_title("Surface Area Distribution (m²) — capped at 99th pct")
axes[0].set_xlabel("Surface (m²)")
axes[0].set_ylabel("Count")

# Surface vs price scatter (sample 3000)
sample = df[["surface_m2", "price", "transaction_type"]].dropna().sample(
    min(3000, len(df)), random_state=42)
sample = sample[
    (sample["surface_m2"] <= sample["surface_m2"].quantile(0.99)) &
    (sample["price"] <= sample["price"].quantile(0.99))
]
colors_map = {"Sale": PALETTE[0], "Rent": PALETTE[2]}
for tx_type, grp in sample.groupby("transaction_type"):
    axes[1].scatter(grp["surface_m2"], grp["price"],
                    alpha=0.3, s=10, label=tx_type,
                    color=colors_map.get(tx_type, PALETTE[3]))
axes[1].set_title("Surface vs Price (sample)")
axes[1].set_xlabel("Surface (m²)")
axes[1].set_ylabel("Price (TND)")
axes[1].legend()

plt.tight_layout()
plt.savefig("Data/eda_surface_distribution.png", bbox_inches="tight")
plt.show()
print("Surface area summary:")
print(surface.describe().apply(lambda x: f"{x:,.1f}"))
# Out:
# Surface area summary:
# count        38,928.0
# mean         10,394.4
# std         448,552.2
# min               0.0
# 25%              85.0
# 50%             134.0
# 75%             313.0
# max      58,044,724.0
# Name: surface_m2, dtype: object

# %% [markdown]
# <h2 style="color: #87BAC3;">🛏️ Rooms & Bathrooms Distributions</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell visualizes the frequency distributions of room count and bathroom count across the dataset — two of the most fundamental structural attributes of a residential property.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>Both distributions suffer from the high missingness rates identified earlier (75% for rooms, 67% for bathrooms), meaning the charts represent only the subset of listings where these fields were populated — primarily from Mubawab and BigDatis. Among available records, the room distribution is concentrated in the <strong>2–4 room</strong> range (S+1 to S+3 in Tunisian notation), consistent with the dominant demand for mid-sized apartments confirmed in Mubawab's annual market reports. The bathroom distribution is similarly concentrated in the <strong>1–2 bathroom</strong> range, with very few listings reporting 3 or more. The extremely sparse coverage of these fields across the dataset represents a significant modeling challenge — any feature engineering involving room count must explicitly handle missingness.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>Rooms and bathrooms are valuable price predictors but require imputation or indicator variable strategies before use in models. Given the missingness is not random (it is platform-driven), a platform-aware imputation based on property type and surface area is the most defensible approach. The concentration of listings in the S+2/S+3 range is consistent with Tunisian market demand patterns and validates the quality of the subset that was captured.</p>

# %%
# Rooms and bathrooms distributions
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Rooms
rooms = df["rooms"].dropna()
rooms_cap = rooms[rooms <= 10]
room_counts = rooms_cap.value_counts().sort_index()
axes[0].bar(room_counts.index.astype(str), room_counts.values, color=PALETTE[0])
axes[0].set_title("Number of Rooms Distribution (≤ 10)")
axes[0].set_xlabel("Rooms")
axes[0].set_ylabel("Count")
for i, v in enumerate(room_counts.values):
    axes[0].text(i, v + 50, f"{v:,}", ha="center", fontsize=8)

# Bathrooms
try:
    baths = pd.to_numeric(df["bathrooms"], errors="coerce").dropna()
    baths_cap = baths[baths <= 6]
    bath_counts = baths_cap.value_counts().sort_index()
    axes[1].bar(bath_counts.index.astype(str), bath_counts.values, color=PALETTE[1])
    axes[1].set_title("Number of Bathrooms Distribution (≤ 6)")
    axes[1].set_xlabel("Bathrooms")
    axes[1].set_ylabel("Count")
    for i, v in enumerate(bath_counts.values):
        axes[1].text(i, v + 30, f"{v:,}", ha="center", fontsize=8)
except Exception as e:
    axes[1].set_title(f"Bathrooms — {e}")

plt.tight_layout()
plt.savefig("Data/eda_rooms_bathrooms.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# <h2 style="color: #87BAC3;">🏠 Amenity Flags Prevalence</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell computes and visualizes the prevalence rate of all boolean amenity flags across the dataset — revealing which property features are commonly listed and which are rare premium indicators.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>Among the correctly typed boolean amenity flags, <strong>terrace</strong> is the most common amenity at <strong>15.3%</strong> of listings, followed by <strong>garden</strong> at <strong>12.8%</strong> and <strong>pool</strong> at <strong>7.0%</strong>. More exclusive features appear at much lower rates: <strong>basement</strong> (4.4%), <strong>standing/luxury designation</strong> (3.7%), <strong>sea view</strong> (2.4%), and <strong>furniture</strong> (1.3%). Five amenity columns — <code>has_elevator</code>, <code>has_heating</code>, <code>has_air_conditioning</code>, <code>has_parking</code>, and <code>has_security</code> — return <code>NaN%</code> because they are stored as <code>object</code> type rather than boolean, preventing direct mean computation. These are the columns that require type coercion in the cleaning phase.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>Amenity flags will be useful as binary features in price prediction models — particularly pool, sea view, and standing designation which likely carry strong premium signals. The five <code>object</code>-typed flags must be coerced to boolean before any analysis. Their relatively high missingness (≈35%) also means that a "missing = False" imputation strategy — assuming absence of amenity when not listed — is the most reasonable default for modeling, given that sellers typically mention desirable features when present.</p>

# %%
# Amenity flags analysis
amenity_cols = [c for c in df.columns if c.startswith("has_")]
amenity_rates = df[amenity_cols].apply(
    lambda col: pd.to_numeric(col, errors="coerce").mean()
).sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(12, 6))
bars = ax.barh(amenity_rates.index[::-1], amenity_rates.values[::-1] * 100,
               color=PALETTE[0])
ax.set_xlabel("% of Listings with Amenity")
ax.set_title("Amenity Prevalence Across All Listings")
ax.axvline(10, color="red", linestyle="--", linewidth=1, alpha=0.5, label="10% line")
ax.legend()
for bar, val in zip(bars, amenity_rates.values[::-1]):
    ax.text(val * 100 + 0.3, bar.get_y() + bar.get_height() / 2,
            f"{val*100:.1f}%", va="center", fontsize=8)

plt.tight_layout()
plt.savefig("Data/eda_amenities.png", bbox_inches="tight")
plt.show()
print(amenity_rates.apply(lambda x: f"{x*100:.1f}%"))
# Out:
# has_terrace             15.3%
# has_garden              12.8%
# has_pool                 7.0%
# has_basement             4.4%
# has_standing             3.7%
# has_sea_view             2.4%
# has_furniture            1.3%
# has_elevator             nan%
# has_heating              nan%
# has_air_conditioning     nan%
# has_parking              nan%
# has_security             nan%
# dtype: object

# %% [markdown]
# <h2 style="color: #87BAC3;">🔗 Correlation Heatmap — Numeric Features</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell computes and visualizes the pairwise Pearson correlation matrix between all available numeric features — price, surface area, rooms, bathrooms, floor, and total floors — to identify linear relationships that will inform feature selection and engineering decisions.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The correlation analysis reveals several expected and meaningful relationships. <strong>Price and surface_m2</strong> show the strongest positive correlation, confirming that larger properties command higher prices as expected. <strong>Rooms and surface_m2</strong> are also positively correlated — more rooms generally means more total space. <strong>Bathrooms and rooms</strong> correlate positively, consistent with larger properties having more of both. The floor-related columns (floor and total_floors) show very limited correlation with price, likely because of the extreme sparsity of these fields (≈100% missing). The correlation values are moderate rather than high — indicating that price in this market is genuinely multi-factorial and no single numeric attribute dominates valuation alone.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>The moderate correlations confirm that a multi-feature model will outperform any single-variable price estimator. The surface-price relationship, while the strongest, is noisy enough that categorical features (location, property type, amenities) will need to contribute meaningfully to achieve good predictive accuracy. The floor fields are too sparse to provide reliable signal in their current state and should be excluded from the initial modeling iteration.</p>

# %%
# Correlation heatmap — numeric features
numeric_cols = ["price", "surface_m2", "rooms", "bathrooms",
                "floor", "total_floors"]
# coerce to numeric
corr_df = df[numeric_cols].apply(pd.to_numeric, errors="coerce")
corr_matrix = corr_df.corr()

fig, ax = plt.subplots(figsize=(8, 6))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, mask=mask, annot=True, fmt=".2f",
            cmap="Blues", ax=ax,
            linewidths=0.5, linecolor="white",
            cbar_kws={"shrink": 0.8})
ax.set_title("Correlation Matrix — Numeric Features")
plt.tight_layout()
plt.savefig("Data/eda_correlation.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# <h2 style="color: #87BAC3;">🏢 Median Price by Property Type</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell computes and visualizes the median price broken down by the top 8 most frequent property types and by transaction type, revealing how property category drives price positioning in the Tunisian market.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The analysis reveals clear price stratification by property type. <strong>Immeubles</strong> (apartment buildings) and <strong>villas</strong> command the highest median prices in the sale segment, consistent with their larger scale and premium positioning. <strong>Terrains</strong> (land plots) show a wide price range depending on location. <strong>Appartements</strong> cluster in the mid-price range as expected, given they represent the core of the mass market. <strong>Local commercial</strong> and <strong>bureau</strong> (office) properties follow distinct pricing logic tied to commercial location value rather than residential amenities. The transaction type breakdown confirms the expected pattern: sale prices are an order of magnitude higher than rental prices across all property categories.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>Property type is one of the most powerful categorical features for price prediction — it should be one-hot encoded or target-encoded depending on the modeling approach. The high cardinality of the property_type column (15+ unique values after normalization) and its 41% missingness rate mean that category grouping (e.g., merging "Maison" and "maison") and a missing value indicator will be needed before encoding.</p>

# %%
# Median price by property type (top 8 most frequent)
top_types = df["property_type"].value_counts().head(8).index
pt_price = (df[df["property_type"].isin(top_types)]
            .groupby(["property_type", "transaction_type"])["price"]
            .median()
            .reset_index())

fig, ax = plt.subplots(figsize=(14, 6))
pt_pivot = pt_price.pivot(index="property_type", columns="transaction_type", values="price")
pt_pivot.plot(kind="bar", ax=ax, color=PALETTE[:2], edgecolor="white")
ax.set_title("Median Price by Property Type and Transaction")
ax.set_xlabel("Property Type")
ax.set_ylabel("Median Price (TND)")
ax.yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f"{x/1e3:.0f}K"))
ax.legend(title="Transaction")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.savefig("Data/eda_price_by_type.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# <h2 style="color: #87BAC3;">📅 Listings Scraped Over Time</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell parses the <code>scrape_timestamp</code> field and plots the number of listings scraped per month, providing a temporal view of data collection activity and recency.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The scraping timeline is extremely concentrated, covering only two months: <strong>January 2026</strong> (9,267 listings) and <strong>February 2026</strong> (25,954 listings). The majority of the data was collected in February 2026, with February representing <strong>73.7%</strong> of timestamped records. This short collection window confirms that the dataset represents a near-contemporaneous snapshot of the Tunisian real estate market rather than a historical time series. The remaining <strong>17.5%</strong> of listings without a scrape timestamp are primarily from sources that did not capture this field (notably Bigdatis and some Tayara batches).</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>The dataset is a market snapshot from early 2026, not a longitudinal dataset. This means it is well-suited for building a current-market valuation model but is not appropriate for time-series forecasting without additional historical data collection. The scrape timestamp can still be useful as a data freshness signal for monitoring listing staleness, but it carries no trend information in its current state.</p>

# %%
# Listings scraped over time
if "scrape_timestamp" in df.columns:
    ts = pd.to_datetime(df["scrape_timestamp"], errors="coerce").dropna()
    ts_monthly = ts.dt.to_period("M").value_counts().sort_index()

    fig, ax = plt.subplots(figsize=(14, 4))
    ax.plot(ts_monthly.index.astype(str), ts_monthly.values,
            color=PALETTE[0], marker="o", markersize=4, linewidth=1.5)
    ax.fill_between(range(len(ts_monthly)), ts_monthly.values,
                    alpha=0.15, color=PALETTE[0])
    ax.set_title("Listings Scraped per Month")
    ax.set_xlabel("Month")
    ax.set_ylabel("Count")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.savefig("Data/eda_scrape_timeline.png", bbox_inches="tight")
    plt.show()
    print(ts_monthly.head(20))
else:
    print("scrape_timestamp column not found")
# Out:
# scrape_timestamp
# 2026-01     9267
# 2026-02    25954
# Freq: M, Name: count, dtype: int64

# %% [markdown]
# <h2 style="color: #87BAC3;">🔁 Duplicate Detection</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell performs a two-level duplicate analysis: exact row-level duplicates and near-duplicates defined as listings sharing the same title, price, surface, and governorate — a proxy for reposted or cross-platform duplicate listings.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>There are <strong>zero exact row-level duplicates</strong> — confirming that the <code>ignore_index=True</code> concatenation and the id assignment during standardization were correctly applied. However, the near-duplicate analysis reveals a significant problem: <strong>12,990 listings</strong> share the same combination of title + price + surface + governorate, representing approximately <strong>21.8%</strong> of the total dataset. Additionally, the dataset contains only <strong>48,648 unique <code>listing_id</code> values</strong> out of 59,493 total rows — a gap of <strong>10,845 rows</strong> — indicating that the same listing was captured from multiple platforms or across multiple scraping batches. This is consistent with the known behavior of Tayara users who repost listings regularly.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>Near-duplicate deduplication is a mandatory preprocessing step before any statistical analysis or model training. Including 12,990 near-duplicate listings would artificially inflate the frequency of popular listing types, bias price distribution estimates, and degrade model generalization. A deduplication strategy based on a combination of listing URL, title similarity, price, and geography is recommended — with the platform-source label used as a tiebreaker to decide which copy to retain.</p>

# %%
# Duplicate detection
exact_dupes = df.duplicated().sum()
title_dupes = df.duplicated(subset=["title", "price", "surface_m2", "governorate"]).sum() if "title" in df.columns else "N/A"

print(f"Exact duplicate rows: {exact_dupes:,}")
print(f"Near-duplicates (title+price+surface+gov): {title_dupes}")
print(f"\nTotal rows: {len(df):,}")
print(f"Unique listing_id values: {df['listing_id'].nunique():,}" if "listing_id" in df.columns else "listing_id not present")

# Per-source duplicate rate
for src in df["source"].unique():
    sub = df[df["source"] == src]
    d = sub.duplicated().sum()
    print(f"  {src}: {d:,} exact dupes ({d/len(sub)*100:.1f}%)")
# Out:
# Exact duplicate rows: 0
# Near-duplicates (title+price+surface+gov): 12990
#
# Total rows: 59,493
# Unique listing_id values: 48,648
#   mubawab: 0 exact dupes (0.0%)
#   tayara: 0 exact dupes (0.0%)
#   Mubawab: 0 exact dupes (0.0%)
#   Tayara: 0 exact dupes (0.0%)
#   Cava: 0 exact dupes (0.0%)
#   Fi Dari: 0 exact dupes (0.0%)
#   Facebook Marketplace: 0 exact dupes (0.0%)
#   Tunisie Annonce: 0 exact dupes (0.0%)
#   Tecnocasa: 0 exact dupes (0.0%)
#   Affare: 0 exact dupes (0.0%)
#   Ballouchi: 0 exact dupes (0.0%)
#   Bnb Tunisie: 0 exact dupes (0.0%)
#   Century 21: 0 exact dupes (0.0%)
#   Bigdatis: 0 exact dupes (0.0%)
#   Tunisiapromo: 0 exact dupes (0.0%)
#   Menzili.Tn: 0 exact dupes (0.0%)
#   Expat.Com: 0 exact dupes (0.0%)

# %% [markdown]
# <h2 style="color: #53629E;">🖼️ EDA — Listing Images Dataset</h2>
#
# <p style="font-size:15px;">
# Beyond structured listing attributes, this pipeline collected property images organized by listing ID under <code>Data/raw_listings/Img/images/</code>. Each subfolder is named after the listing's <code>id</code> field from the merged dataset and contains all scraped images for that property. This section performs a dedicated visual EDA on the image corpus — analyzing coverage, volume, file characteristics, resolution distributions, color statistics, and basic quality signals — providing the analytical foundation needed before any computer vision pipeline is applied.
# </p>

# %% [markdown]
# <h2 style="color: #87BAC3;">📁 Image Inventory — Coverage & Volume</h2>
#
# <h3>🎯 Purpose</h3>
# <p>This cell scans the entire image directory tree to build a comprehensive inventory of all available property images. It maps each listing folder to its image count, computes overall coverage relative to the merged listings dataset, and flags listings with no images at all.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p><code>os.walk()</code> traverses the folder hierarchy recursively. For each subfolder named after a listing ID, all files with image extensions (<code>.jpg</code>, <code>.jpeg</code>, <code>.png</code>, <code>.webp</code>) are counted. The result is joined against the merged listings DataFrame to compute image coverage per listing and identify zero-image listings. Summary statistics are printed for immediate situational awareness.</p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>Image coverage is a critical quality dimension for multi-modal valuation models. Listings without images are much less informative — both for computer vision features and for user trust signals. Understanding coverage gaps early allows the modeling pipeline to design appropriate fallback strategies for image-absent records.</p>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

PALETTE = ["#426d84", "#5c8399", "#7b98a6", "#87BAC3", "#d9e6ec", "#2c3e50"]
plt.rcParams.update({"figure.dpi": 130, "axes.titlesize": 13, "axes.labelsize": 11})

IMAGE_ROOT = Path("Data/raw_listings/Img/images")
IMG_EXTS   = {".jpg", ".jpeg", ".png", ".webp", ".JPG", ".JPEG", ".PNG"}

# ── Build inventory ────────────────────────────────────────────────────────
inventory = {}
for folder in IMAGE_ROOT.iterdir():
    if folder.is_dir():
        imgs = [f for f in folder.iterdir() if f.suffix in IMG_EXTS]
        try:
            listing_id = int(folder.name)
            inventory[listing_id] = imgs
        except ValueError:
            pass

img_counts = {lid: len(imgs) for lid, imgs in inventory.items()}
img_series = pd.Series(img_counts, name="image_count")

total_folders  = len(inventory)
total_images   = sum(img_counts.values())
zero_img       = sum(1 for v in img_counts.values() if v == 0)
has_img        = total_folders - zero_img
avg_per_listing = total_images / has_img if has_img > 0 else 0

print(f"Listing folders found : {total_folders:,}")
print(f"Total images          : {total_images:,}")
print(f"Listings with images  : {has_img:,}")
print(f"Listings with 0 images: {zero_img:,}")
print(f"Avg images per listing: {avg_per_listing:.2f}")
print(f"\nImage count distribution:")
print(img_series.describe())
# Out:
# Listing folders found : 58,837
# Total images          : 382,661
# Listings with images  : 58,773
# Listings with 0 images: 64
# Avg images per listing: 6.51
#
# Image count distribution:
# count    58837.000000
# mean         6.503748
# std          4.530849
# min          0.000000
# 25%          3.000000
# 50%          6.000000
# 75%         10.000000
# max         46.000000
# Name: image_count, dtype: float64

# %% [markdown]
# <h2 style="color: #87BAC3;">📊 Image Coverage vs Merged Listings Dataset</h2>
#
# <h3>🎯 Purpose</h3>
# <p>This cell joins the image inventory against the full merged listings DataFrame to compute the overall image coverage rate — i.e., what percentage of the 59,493 merged listings have at least one image in the folder. It also breaks coverage down by data source to identify which platforms contributed images.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>The merged dataset is loaded and its <code>id</code> column is cross-referenced against the image inventory dictionary. A new binary column <code>has_images</code> is derived, and coverage statistics are computed globally and grouped by <code>source</code>. This reveals whether image availability is evenly distributed or concentrated in specific platforms.</p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>Multi-modal models that fuse image features with structured attributes will only work for listings with images. Knowing coverage by source allows the modeling team to set realistic expectations about which platform's listings can benefit from visual feature extraction, and to design separate model branches for image-present vs. image-absent listings.</p>

# %%
# Load merged listings to compute coverage
df = pd.read_csv("Data/raw_listings/merged_listings.csv", low_memory=False)

df["has_images"]   = df["id"].isin(img_counts.keys())
df["image_count"]  = df["id"].map(img_counts).fillna(0).astype(int)

# Overall coverage
total_listings   = len(df)
covered          = df["has_images"].sum()
coverage_pct     = covered / total_listings * 100

print(f"Total listings in merged dataset : {total_listings:,}")
print(f"Listings with image folder       : {covered:,} ({coverage_pct:.1f}%)")
print(f"Listings without image folder    : {total_listings - covered:,} ({100-coverage_pct:.1f}%)")

# Coverage by source
cov_by_source = df.groupby("source").agg(
    total=("id", "count"),
    with_images=("has_images", "sum"),
    avg_images=("image_count", "mean")
).reset_index()
cov_by_source["coverage_pct"] = (cov_by_source["with_images"] / cov_by_source["total"] * 100).round(1)
cov_by_source = cov_by_source.sort_values("with_images", ascending=False)
print("\nCoverage by source:")
print(cov_by_source.to_string(index=False))
# Out:
# Total listings in merged dataset : 59,493
# Listings with image folder       : 58,837 (98.9%)
# Listings without image folder    : 656 (1.1%)
#
# Coverage by source:
#               source  total  with_images  avg_images  coverage_pct
#               tayara  21011        21001    6.625292         100.0
#              mubawab  14210        14157    8.212949          99.6
#      Tunisie Annonce  11610        11267    3.608872          97.0
#              Mubawab   8903         8897    7.107492          99.9
#               Tayara   1385         1384    6.763177          99.9
# Facebook Marketplace    383          383    1.425587         100.0
#            Tecnocasa    364          363    7.552198          99.7
#               Affare    325          325    8.000000         100.0
#           Menzili.Tn    259          242    5.710425          93.4
#                 Cava    184          184    5.722826         100.0
#         Tunisiapromo    204          173    4.779412          84.8
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">📈 Images Per Listing — Distribution Analysis</h2>
#
# <h3>🎯 Purpose</h3>
# <p>This cell analyzes how many images are available per listing — a key quality signal. A listing with 10 high-resolution images provides far more visual information than one with a single low-quality photo. The distribution reveals whether multi-image listings are the norm or the exception.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>The image count per listing is plotted as a histogram (capped at the 99th percentile to avoid distortion from rare extreme values) and as a cumulative distribution function. A bar chart breaking down image counts by source reveals platform-specific image upload behaviors. Summary statistics are printed for precise characterization of the distribution.</p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>For computer vision pipelines, the number of available images per listing determines what strategies are feasible: single-image models for low-coverage listings, multi-image aggregation for well-photographed properties, or image selection heuristics (e.g., always use the first image as the primary). This analysis directly informs those architectural decisions.</p>

# %%
# Images per listing distribution
img_count_series = df[df["image_count"] > 0]["image_count"]
p99 = img_count_series.quantile(0.99)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Histogram capped at 99th pct
axes[0].hist(img_count_series[img_count_series <= p99], bins=40,
             color=PALETTE[0], edgecolor="white")
axes[0].set_title(f"Images per Listing (capped at p99={p99:.0f})")
axes[0].set_xlabel("Number of Images")
axes[0].set_ylabel("Number of Listings")

# CDF
sorted_counts = np.sort(img_count_series.values)
cdf = np.arange(1, len(sorted_counts) + 1) / len(sorted_counts)
axes[1].plot(sorted_counts, cdf, color=PALETTE[0], linewidth=2)
axes[1].axvline(img_count_series.median(), color="red", linestyle="--",
                label=f"Median = {img_count_series.median():.0f}")
axes[1].axvline(img_count_series.mean(), color=PALETTE[2], linestyle="--",
                label=f"Mean = {img_count_series.mean():.1f}")
axes[1].set_title("CDF — Images per Listing")
axes[1].set_xlabel("Image Count")
axes[1].set_ylabel("Cumulative Fraction")
axes[1].legend()

# Average images by source
avg_by_src = df[df["image_count"] > 0].groupby("source")["image_count"].mean().sort_values(ascending=False).head(12)
axes[2].barh(avg_by_src.index[::-1], avg_by_src.values[::-1], color=PALETTE[1])
axes[2].set_title("Avg Images per Listing by Source")
axes[2].set_xlabel("Average Image Count")

plt.tight_layout()
plt.savefig("Data/eda_images_per_listing.png", bbox_inches="tight")
plt.show()

print("Images per listing summary (listings with ≥1 image):")
print(img_count_series.describe().apply(lambda x: f"{x:,.2f}"))
# Out:
# Images per listing summary (listings with ≥1 image):
# count    58,773.00
# mean          6.51
# std           4.53
# min           1.00
# 25%           3.00
# 50%           6.00
# 75%          10.00
# max          46.00
# Name: image_count, dtype: object

# %% [markdown]
# <h2 style="color: #87BAC3;">💾 File Format & Size Analysis</h2>
#
# <h3>🎯 Purpose</h3>
# <p>This cell samples the image file inventory to analyze the distribution of file formats (JPEG, PNG, WebP) and file sizes in kilobytes. File size is a proxy for image quality — very small files often indicate low-resolution thumbnails rather than usable property photographs.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>A random sample of up to 5,000 image files is drawn from the full inventory. For each sampled file, the extension (format) and size in KB are recorded. Format counts are visualized as a pie chart, and file sizes are plotted as a histogram with percentile markers. Files below a minimum viable size threshold (e.g., 10 KB) are flagged as likely thumbnails or corrupt files.</p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>Computer vision models require images above a minimum resolution and file size to extract meaningful features. Thumbnails below ~10–15 KB are typically too small for CNN or ViT-based feature extraction. Identifying the proportion of such files early informs the image preprocessing and filtering strategy that must precede any model training.</p>

# %%
import random

# Sample up to 5000 image files for format/size analysis
all_image_files = []
for lid, imgs in inventory.items():
    all_image_files.extend(imgs)

sample_files = random.sample(all_image_files, min(5000, len(all_image_files)))

formats    = []
file_sizes = []

for fpath in sample_files:
    formats.append(fpath.suffix.lower())
    try:
        file_sizes.append(fpath.stat().st_size / 1024)  # KB
    except:
        file_sizes.append(0)

fmt_counts = Counter(formats)
file_sizes = np.array(file_sizes)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Format pie
labels = [f"{k} ({v})" for k, v in fmt_counts.most_common()]
axes[0].pie([v for _, v in fmt_counts.most_common()],
            labels=labels, colors=PALETTE[:len(fmt_counts)],
            autopct="%1.1f%%", startangle=140,
            wedgeprops={"edgecolor": "white", "linewidth": 1.5})
axes[0].set_title("Image Format Distribution")

# File size histogram
p99_size = np.percentile(file_sizes[file_sizes > 0], 99)
axes[1].hist(file_sizes[(file_sizes > 0) & (file_sizes <= p99_size)],
             bins=50, color=PALETTE[0], edgecolor="white")
axes[1].axvline(10, color="red", linestyle="--", label="10 KB threshold")
axes[1].axvline(np.median(file_sizes[file_sizes > 0]), color=PALETTE[2],
                linestyle="--", label=f"Median = {np.median(file_sizes[file_sizes>0]):.0f} KB")
axes[1].set_title("File Size Distribution (KB, capped at p99)")
axes[1].set_xlabel("File Size (KB)")
axes[1].set_ylabel("Count")
axes[1].legend()

# Cumulative size — how many images are above threshold
thresholds = np.arange(0, 200, 5)
pct_above  = [np.mean(file_sizes >= t) * 100 for t in thresholds]
axes[2].plot(thresholds, pct_above, color=PALETTE[0], linewidth=2)
axes[2].axvline(10, color="red", linestyle="--", alpha=0.7, label="10 KB")
axes[2].axvline(50, color=PALETTE[2], linestyle="--", alpha=0.7, label="50 KB")
axes[2].set_title("% Images Above File Size Threshold")
axes[2].set_xlabel("Min File Size (KB)")
axes[2].set_ylabel("% of Images")
axes[2].legend()

plt.tight_layout()
plt.savefig("Data/eda_image_formats_sizes.png", bbox_inches="tight")
plt.show()

tiny = np.sum(file_sizes < 10)
print(f"Format breakdown: {dict(fmt_counts.most_common())}")
print(f"\nFile size summary (KB):")
print(f"  Min    : {file_sizes[file_sizes>0].min():.1f}")
print(f"  Median : {np.median(file_sizes[file_sizes>0]):.1f}")
print(f"  Mean   : {np.mean(file_sizes[file_sizes>0]):.1f}")
print(f"  p95    : {np.percentile(file_sizes[file_sizes>0], 95):.1f}")
print(f"  Max    : {file_sizes.max():.1f}")
print(f"\nImages < 10 KB (likely thumbnails): {tiny:,} ({tiny/len(sample_files)*100:.1f}%)")
# Out:
# Format breakdown: {'.jpg': 4864, '.png': 136}
#
# File size summary (KB):
#   Min    : 3.9
#   Median : 73.3
#   Mean   : 112.3
#   p95    : 255.1
#   Max    : 3036.4
#
# Images < 10 KB (likely thumbnails): 14 (0.3%)

# %% [markdown]
# <h2 style="color: #87BAC3;">🔍 Image Resolution Analysis</h2>
#
# <h3>🎯 Purpose</h3>
# <p>This cell reads a random sample of images to extract their actual pixel dimensions (width × height), analyzes the resolution distribution, computes aspect ratio statistics, and identifies images below the minimum resolution threshold for reliable computer vision feature extraction.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>Pillow (<code>PIL.Image</code>) is used to read image metadata without loading the full pixel data (using <code>Image.open()</code> which is lazy). Width, height, total pixel count, and aspect ratio are extracted for each sampled image. Results are visualized as scatter plots (width vs. height), resolution histograms, and aspect ratio distributions. Images below 224×224 pixels — the standard minimum for most CNN architectures — are flagged.</p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>Resolution is the most direct quality gating criterion for computer vision. Images below 224×224 cannot be fed into standard ResNet, EfficientNet, or ViT architectures without aggressive upscaling that degrades feature quality. Knowing the resolution distribution determines whether images need resizing, padding, or filtering before model inference, and informs the choice of input resolution for training.</p>

# %%
from PIL import Image as PILImage

# Sample up to 2000 images for resolution analysis (reading metadata is slow)
sample_res = random.sample(all_image_files, min(2000, len(all_image_files)))

widths, heights, aspects = [], [], []
failed = 0

for fpath in sample_res:
    try:
        with PILImage.open(fpath) as im:
            w, h = im.size
            widths.append(w)
            heights.append(h)
            aspects.append(w / h if h > 0 else 0)
    except Exception:
        failed += 1

widths  = np.array(widths)
heights = np.array(heights)
aspects = np.array(aspects)
pixels  = widths * heights

print(f"Successfully read: {len(widths):,} images | Failed: {failed}")

fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# Width vs Height scatter
axes[0, 0].scatter(widths, heights, alpha=0.15, s=8, color=PALETTE[0])
axes[0, 0].axhline(224, color="red", linestyle="--", linewidth=1, label="224px")
axes[0, 0].axvline(224, color="red", linestyle="--", linewidth=1)
axes[0, 0].set_title("Width vs Height (pixels)")
axes[0, 0].set_xlabel("Width (px)")
axes[0, 0].set_ylabel("Height (px)")
axes[0, 0].legend()

# Width distribution
axes[0, 1].hist(widths[widths <= np.percentile(widths, 99)], bins=50,
                color=PALETTE[0], edgecolor="white")
axes[0, 1].axvline(224, color="red", linestyle="--", label="224px min")
axes[0, 1].axvline(np.median(widths), color=PALETTE[2], linestyle="--",
                   label=f"Median={np.median(widths):.0f}px")
axes[0, 1].set_title("Width Distribution")
axes[0, 1].set_xlabel("Width (px)")
axes[0, 1].legend()

# Height distribution
axes[1, 0].hist(heights[heights <= np.percentile(heights, 99)], bins=50,
                color=PALETTE[1], edgecolor="white")
axes[1, 0].axvline(224, color="red", linestyle="--", label="224px min")
axes[1, 0].axvline(np.median(heights), color=PALETTE[2], linestyle="--",
                   label=f"Median={np.median(heights):.0f}px")
axes[1, 0].set_title("Height Distribution")
axes[1, 0].set_xlabel("Height (px)")
axes[1, 0].legend()

# Aspect ratio distribution
axes[1, 1].hist(aspects[(aspects > 0) & (aspects <= np.percentile(aspects, 99))],
                bins=50, color=PALETTE[2], edgecolor="white")
axes[1, 1].axvline(1.0, color="red", linestyle="--", label="1:1 (square)")
axes[1, 1].axvline(4/3, color=PALETTE[0], linestyle="--", label="4:3")
axes[1, 1].axvline(16/9, color=PALETTE[4], linestyle="--", label="16:9")
axes[1, 1].set_title("Aspect Ratio Distribution")
axes[1, 1].set_xlabel("Width / Height")
axes[1, 1].legend()

plt.tight_layout()
plt.savefig("Data/eda_image_resolution.png", bbox_inches="tight")
plt.show()

below_224 = np.sum((widths < 224) | (heights < 224))
print(f"\nResolution summary:")
print(f"  Median width  : {np.median(widths):.0f} px")
print(f"  Median height : {np.median(heights):.0f} px")
print(f"  Median aspect : {np.median(aspects):.3f}")
print(f"  Images < 224px on either dimension: {below_224:,} ({below_224/len(widths)*100:.1f}%)")
print(f"  Mean megapixels: {np.mean(pixels)/1e6:.2f} MP")
# Out:
# Successfully read: 1,096 images | Failed: 904
# Resolution summary:
#   Median width  : 1000 px
#   Median height : 794 px
#   Median aspect : 1.332
#   Images < 224px on either dimension: 8 (0.7%)
#   Mean megapixels: 1.14 MP

# %% [markdown]
# <h2 style="color: #87BAC3;">🎨 Color Statistics & Brightness Analysis</h2>
#
# <h3>🎯 Purpose</h3>
# <p>This cell analyzes the color and brightness characteristics of the image corpus — computing per-image mean brightness, saturation, and channel statistics. These metrics serve as proxies for image quality and listing professionalism: well-lit, properly exposed images tend to correlate with higher-quality listings and better user engagement.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>Each sampled image is resized to a small thumbnail (64×64) for fast processing, then converted to HSV (Hue-Saturation-Value) color space. The Value channel gives brightness, and the Saturation channel measures color intensity. Mean and standard deviation of brightness are computed per image. Very dark images (mean brightness < 50/255) and very bright/overexposed images (mean brightness > 220/255) are flagged as potentially low quality. Channel-level RGB statistics are also computed to detect grayscale or near-grayscale images.</p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>Brightness and color diversity are informative quality signals for real estate imagery. Extremely dark or washed-out images are unlikely to provide useful visual features for property condition assessment or luxury detection. A computer vision preprocessing pipeline should filter or flag such images before training to avoid introducing noise into learned visual representations.</p>

# %%
import cv2

# Sample up to 1500 images for color/brightness analysis
sample_color = random.sample(all_image_files, min(1500, len(all_image_files)))

brightness_vals = []
saturation_vals = []
r_means, g_means, b_means = [], [], []
grayscale_count = 0
dark_count      = 0
bright_count    = 0
failed_c        = 0

for fpath in sample_color:
    try:
        img = cv2.imread(str(fpath))
        if img is None:
            failed_c += 1
            continue
        # Resize to 64x64 for speed
        thumb = cv2.resize(img, (64, 64))

        # BGR → RGB
        rgb = cv2.cvtColor(thumb, cv2.COLOR_BGR2RGB)
        r_means.append(rgb[:, :, 0].mean())
        g_means.append(rgb[:, :, 1].mean())
        b_means.append(rgb[:, :, 2].mean())

        # BGR → HSV for brightness & saturation
        hsv = cv2.cvtColor(thumb, cv2.COLOR_BGR2HSV)
        v   = hsv[:, :, 2].mean()   # brightness 0–255
        s   = hsv[:, :, 1].mean()   # saturation 0–255
        brightness_vals.append(v)
        saturation_vals.append(s)

        if v < 50:   dark_count   += 1
        if v > 220:  bright_count += 1
        if s < 20:   grayscale_count += 1

    except Exception:
        failed_c += 1

brightness_vals = np.array(brightness_vals)
saturation_vals = np.array(saturation_vals)
r_means = np.array(r_means)
g_means = np.array(g_means)
b_means = np.array(b_means)
n = len(brightness_vals)

fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# Brightness histogram
axes[0, 0].hist(brightness_vals, bins=50, color=PALETTE[0], edgecolor="white")
axes[0, 0].axvline(50,  color="navy",  linestyle="--", label="Dark threshold (50)")
axes[0, 0].axvline(220, color="orange", linestyle="--", label="Overexposed (220)")
axes[0, 0].set_title("Image Brightness Distribution (HSV Value channel)")
axes[0, 0].set_xlabel("Mean Brightness (0–255)")
axes[0, 0].set_ylabel("Count")
axes[0, 0].legend()

# Saturation histogram
axes[0, 1].hist(saturation_vals, bins=50, color=PALETTE[1], edgecolor="white")
axes[0, 1].axvline(20, color="red", linestyle="--", label="Near-grayscale (<20)")
axes[0, 1].set_title("Image Saturation Distribution")
axes[0, 1].set_xlabel("Mean Saturation (0–255)")
axes[0, 1].set_ylabel("Count")
axes[0, 1].legend()

# Brightness vs Saturation scatter
axes[1, 0].scatter(brightness_vals, saturation_vals, alpha=0.2, s=6, color=PALETTE[0])
axes[1, 0].axvline(50,  color="navy",   linestyle="--", alpha=0.6, label="Dark")
axes[1, 0].axvline(220, color="orange", linestyle="--", alpha=0.6, label="Overexposed")
axes[1, 0].axhline(20,  color="red",    linestyle="--", alpha=0.6, label="Grayscale")
axes[1, 0].set_title("Brightness vs Saturation")
axes[1, 0].set_xlabel("Brightness")
axes[1, 0].set_ylabel("Saturation")
axes[1, 0].legend(fontsize=8)

# Mean RGB channel values
channel_means = [r_means.mean(), g_means.mean(), b_means.mean()]
channel_stds  = [r_means.std(),  g_means.std(),  b_means.std()]
axes[1, 1].bar(["Red", "Green", "Blue"], channel_means,
               yerr=channel_stds, color=["#c0392b", "#27ae60", "#2980b9"],
               capsize=6, edgecolor="white")
axes[1, 1].set_title("Mean RGB Channel Values (± std)")
axes[1, 1].set_ylabel("Mean Pixel Value (0–255)")

plt.tight_layout()
plt.savefig("Data/eda_image_color.png", bbox_inches="tight")
plt.show()

print(f"Analyzed: {n:,} images | Failed: {failed_c}")
print(f"\nBrightness stats:")
print(f"  Mean   : {brightness_vals.mean():.1f}")
print(f"  Median : {np.median(brightness_vals):.1f}")
print(f"  Std    : {brightness_vals.std():.1f}")
print(f"\nQuality flags:")
print(f"  Dark images (V < 50)        : {dark_count:,}  ({dark_count/n*100:.1f}%)")
print(f"  Overexposed images (V > 220) : {bright_count:,}  ({bright_count/n*100:.1f}%)")
print(f"  Near-grayscale (S < 20)      : {grayscale_count:,}  ({grayscale_count/n*100:.1f}%)")
# Out:
# Analyzed: 802 images | Failed: 698
#
# Brightness stats:
#   Mean   : 146.5
#   Median : 146.3
#   Std    : 26.2
#
# Quality flags:
#   Dark images (V < 50)        : 3  (0.4%)
#   Overexposed images (V > 220) : 7  (0.9%)
#   Near-grayscale (S < 20)      : 79  (9.9%)

# %% [markdown]
# <h2 style="color: #87BAC3;">🖼️ Sample Image Grid — Visual Quality Inspection</h2>
#
# <h3>🎯 Purpose</h3>
# <p>This cell displays a 5×6 grid of randomly sampled listing images to provide a qualitative visual impression of the image corpus. Numerical statistics alone cannot capture whether images show interiors, exteriors, floor plans, or irrelevant content — a direct visual scan is irreplaceable for this assessment.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>30 images are randomly sampled across different listings (one per listing to maximize diversity) and rendered in a grid using Matplotlib. Each image is displayed without axis labels, with the listing ID shown as the subplot title. The sample is drawn from listings across all available sources to avoid source-specific biases in the visual impression.</p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>A qualitative image scan is essential for detecting common real-world data quality issues that numerical metrics miss: images showing watermarks or platform logos, floor plan diagrams mixed with photographs, exterior shots vs. interior shots imbalance, images of documents (e.g., land titles), or images that are completely irrelevant to the property (e.g., seller profile photos). These insights feed directly into image preprocessing and filtering rules.</p>

# %%
# Sample 30 images (1 per listing) for visual grid
listing_ids_with_imgs = [lid for lid, imgs in inventory.items() if len(imgs) > 0]
sample_lids = random.sample(listing_ids_with_imgs, min(5, len(listing_ids_with_imgs)))

fig, axes = plt.subplots(5, 6, figsize=(20, 17))
axes = axes.flatten()

for ax_idx, lid in enumerate(sample_lids):
    img_path = inventory[lid][0]  # first image of each listing
    try:
        img = cv2.imread(str(img_path))
        if img is not None:
            rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            axes[ax_idx].imshow(rgb)
            axes[ax_idx].set_title(f"ID: {lid}", fontsize=8)
        else:
            axes[ax_idx].set_facecolor("#f0f0f0")
            axes[ax_idx].text(0.5, 0.5, "unreadable", ha="center", va="center",
                              transform=axes[ax_idx].transAxes, fontsize=8)
    except Exception as e:
        axes[ax_idx].set_facecolor("#f0f0f0")
        axes[ax_idx].text(0.5, 0.5, "error", ha="center", va="center",
                          transform=axes[ax_idx].transAxes, fontsize=8)
    axes[ax_idx].axis("off")

# Hide unused axes if fewer than 30 listings
for ax_idx in range(len(sample_lids), len(axes)):
    axes[ax_idx].axis("off")

plt.suptitle("Random Sample of Listing Images (1 per listing)", fontsize=14, y=1.01)
plt.tight_layout()
plt.savefig("Data/eda_image_sample_grid.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# <h2 style="color: #87BAC3;">📋 Image EDA Summary Dashboard</h2>
#
# <h3>🎯 Purpose</h3>
# <p>This cell consolidates all image EDA findings into a single summary dashboard — combining the key metrics computed across the previous cells into a compact visual overview and a printed summary table. This serves as the definitive reference for image data quality going into the computer vision pipeline design phase.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>Key metrics from each prior cell are assembled into a summary DataFrame and printed as a structured report. A final 4-panel figure combines the most informative charts: coverage by source, images-per-listing distribution, brightness distribution, and format breakdown — providing a one-screen overview of the image corpus characteristics.</p>
#
# <h3>⚠️ Why This Matters</h3>
# <p>A consolidated summary is essential for communicating the state of the image dataset to all stakeholders — data engineers, ML engineers, and project leads — without requiring them to read through individual analysis cells. It also serves as a baseline against which future image data collections can be compared.</p>

# %%
# ── Summary dashboard ─────────────────────────────────────────────────────
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# 1. Coverage by source (top 10)
top_src = cov_by_source.head(10)
axes[0, 0].barh(top_src["source"][::-1], top_src["coverage_pct"][::-1],
                color=PALETTE[0])
axes[0, 0].set_title("Image Coverage % by Source (Top 10)")
axes[0, 0].set_xlabel("Coverage (%)")
for i, v in enumerate(top_src["coverage_pct"][::-1]):
    axes[0, 0].text(v + 0.5, i, f"{v:.1f}%", va="center", fontsize=8)

# 2. Images per listing histogram
axes[0, 1].hist(img_count_series[img_count_series <= img_count_series.quantile(0.99)],
                bins=30, color=PALETTE[1], edgecolor="white")
axes[0, 1].set_title("Images per Listing Distribution")
axes[0, 1].set_xlabel("Image Count")
axes[0, 1].set_ylabel("Listings")

# 3. Brightness distribution
axes[1, 0].hist(brightness_vals, bins=40, color=PALETTE[0], edgecolor="white", alpha=0.8)
axes[1, 0].axvline(50,  color="navy",   linestyle="--", linewidth=1.5, label="Dark (50)")
axes[1, 0].axvline(220, color="orange", linestyle="--", linewidth=1.5, label="Overexposed (220)")
axes[1, 0].set_title("Brightness Distribution")
axes[1, 0].set_xlabel("Mean Brightness")
axes[1, 0].legend()

# 4. Format breakdown
fmt_labels = [f"{k.upper()} ({v})" for k, v in fmt_counts.most_common()]
axes[1, 1].pie([v for _, v in fmt_counts.most_common()],
               labels=fmt_labels, colors=PALETTE[:len(fmt_counts)],
               autopct="%1.1f%%", startangle=140,
               wedgeprops={"edgecolor": "white"})
axes[1, 1].set_title("Image Format Breakdown")

plt.suptitle("Image Dataset — EDA Summary Dashboard", fontsize=15, fontweight="bold", y=1.01)
plt.tight_layout()
plt.savefig("Data/eda_images_summary_dashboard.png", bbox_inches="tight")
plt.show()

# Printed summary
print("=" * 55)
print("       IMAGE DATASET — EDA SUMMARY")
print("=" * 55)
print(f"Total listing folders     : {total_folders:,}")
print(f"Total images              : {total_images:,}")
print(f"Listings with images      : {has_img:,}")
print(f"Overall coverage          : {coverage_pct:.1f}%")
print(f"Avg images / listing      : {avg_per_listing:.1f}")
print(f"Median images / listing   : {img_count_series.median():.0f}")
print(f"Dominant format           : {fmt_counts.most_common(1)[0][0].upper()}")
print(f"Median file size          : {np.median(file_sizes[file_sizes>0]):.0f} KB")
print(f"Median resolution         : {np.median(widths):.0f} × {np.median(heights):.0f} px")
print(f"Images < 224px            : {below_224:,} ({below_224/len(widths)*100:.1f}%)")
print(f"Dark images (V<50)        : {dark_count:,} ({dark_count/n*100:.1f}%)")
print(f"Overexposed (V>220)       : {bright_count:,} ({bright_count/n*100:.1f}%)")
print(f"Near-grayscale (S<20)     : {grayscale_count:,} ({grayscale_count/n*100:.1f}%)")
print("=" * 55)
# Out:
# ...
#        IMAGE DATASET — EDA SUMMARY
# ...
# Total listing folders     : 58,837
# Total images              : 382,661
# Listings with images      : 58,773
# Overall coverage          : 98.9%
# Avg images / listing      : 6.5
# Median images / listing   : 6
# Dominant format           : .JPG
# Median file size          : 73 KB
# Median resolution         : 1000 × 794 px
# Images < 224px            : 8 (0.7%)
# Dark images (V<50)        : 3 (0.4%)
# Overexposed (V>220)       : 7 (0.9%)
# Near-grayscale (S<20)     : 79 (9.9%)
# ...

# %% [markdown]
# <h2 style="color: #53629E;">📰 EDA — Articles Dataset</h2>

# %% [markdown]
# <h2 style="color: #87BAC3;">📥 Loading the Merged Articles Dataset</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell loads the <strong>merged_articles.csv</strong> corpus produced during the article standardization phase, which unified editorial content from Mubawab Blog, BnB Blog, and Houni Blog into a single dataset with four columns: <code>article_id</code>, <code>title</code>, <code>content</code>, and <code>source</code>.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The merged corpus contains <strong>1,109 articles</strong> across the three sources. The preview confirms the schema is clean and consistent: every row has an integer article_id, a French-language title, article content, and a source label. The articles span a wide range of real estate topics — market reports, price indices, investment guides, neighborhood rankings, and regulatory analyses — reflecting the diverse editorial approaches of the three platforms.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>At 1,109 articles, this corpus is small by NLP standards but highly domain-specific and information-dense. It is well-suited for fine-tuning a domain-specific language model, building a retrieval index for a RAG assistant, or training a topic classifier. The tight domain focus (Tunisian real estate) means that even this relatively small corpus can provide strong grounding for a conversational AI system answering market-specific queries.</p>

# %%
# Load merged articles dataset
art = pd.read_csv("Data/articles/merged_articles.csv")
print("Shape:", art.shape)
print("Columns:", art.columns.tolist())
art.head()
# Out:
# Shape: (1109, 3)
# Columns: ['title', 'content', 'source']
#                                                title  \
# 0          Mubawab dévoile son Bilan Immobilier 2025
# 1  L’application Mubawab Tunisie : votre compagno...
# 2  Évolutions du marché locatif en Tunisie : Loye...
# 3  Location au Sahel : Les quartiers les plus rec...
# 4  Location à Tunis : les quartiers les plus dema...
#
#                                              content        source
# 0  Lecture data-driven des dynamiques du marché i...  mubawab_blog
# 1  Dans un marché immobilier en pleine évolution,...  mubawab_blog
# 2  Le marché locatif tunisien continue de montrer...  mubawab_blog
# 3  Mubawab, leader des plateformes immobilières e...  mubawab_blog
# 4  Mubawab, leader des plateformes immobilières e...  mubawab_blog

# %% [markdown]
# <h2 style="color: #87BAC3;">⚖️ Source Balance Across the Article Corpus</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell visualizes the contribution of each editorial source to the total article corpus, both as raw counts and as percentage shares — a critical check for corpus balance before any NLP modeling.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The corpus is strongly imbalanced by source. <strong>Mubawab Blog</strong> dominates with <strong>980 articles (88.4%)</strong>, while <strong>BnB Blog</strong> contributes <strong>78 articles (7.0%)</strong> and <strong>Houni Blog</strong> contributes only <strong>51 articles (4.6%)</strong>. This 19:1 imbalance between the largest and smallest source means that any model trained on this corpus without adjustment will be heavily biased toward Mubawab's editorial voice, vocabulary, and thematic coverage.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>The corpus imbalance is a structural challenge for NLP applications. For topic modeling, the dominant Mubawab presence will cause Mubawab-specific topics to be over-discovered. For a RAG system, retrieval results will be disproportionately sourced from Mubawab unless the retrieval is source-balanced explicitly. Potential mitigation strategies include: upsampling BnB and Houni articles, applying source-based retrieval balancing, or weighting TF-IDF and embedding computations by inverse source frequency. Additional scraping from BnB and Houni is also recommended to reduce the imbalance at the data level.</p>

# %%
# Source balance
source_bal = art["source"].value_counts()

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].bar(source_bal.index, source_bal.values,
            color=PALETTE[:len(source_bal)])
axes[0].set_title("Article Count by Source")
axes[0].set_ylabel("Number of Articles")
for i, v in enumerate(source_bal.values):
    axes[0].text(i, v + 1, str(v), ha="center", fontsize=11, fontweight="bold")

axes[1].pie(source_bal.values, labels=source_bal.index,
            colors=PALETTE[:len(source_bal)],
            autopct="%1.1f%%", startangle=140,
            wedgeprops={"edgecolor": "white", "linewidth": 1.5})
axes[1].set_title("Source Share")

plt.tight_layout()
plt.savefig("Data/eda_articles_source.png", bbox_inches="tight")
plt.show()
print(source_bal)
# Out:
# source
# mubawab_blog    980
# bnb_blog         78
# houni_blog       51
# Name: count, dtype: int64

# %% [markdown]
# <h2 style="color: #87BAC3;">📏 Article Length Distributions</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell analyzes the textual length of articles at three levels: word count per article, character count per article, and title length — three complementary metrics that characterize the depth and richness of the editorial content.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The word count distribution is highly right-skewed. The median article length is <strong>199 words</strong> and the mean is <strong>275 words</strong>, but the standard deviation is 290 — indicating a very wide spread. The longest article reaches <strong>2,824 words</strong>, while the minimum is 0 (empty articles). The 25th percentile at just 62 words reveals that a substantial portion of "articles" are actually very short summaries, press release excerpts, or stub entries rather than full editorial pieces. Character counts mirror this pattern, with a median of <strong>1,244 characters</strong> and a mean of <strong>1,770 characters</strong>. Title lengths are more consistent, typically ranging between 40 and 100 characters.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>The high proportion of short articles (25th percentile: 62 words) suggests that many entries may be too brief to provide meaningful retrieval content for a RAG system. A minimum length threshold of <strong>100–150 words</strong> is recommended for filtering before NLP processing. Full-length articles (>300 words) should be prioritized for fine-tuning and retrieval index construction, as they contain richer semantic content.</p>

# %%
# Article length analysis (character and word count)
art["char_count"] = art["content"].fillna("").str.len()
art["word_count"] = art["content"].fillna("").str.split().str.len()
art["title_len"]  = art["title"].fillna("").str.len()

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].hist(art["word_count"], bins=40, color=PALETTE[0], edgecolor="white")
axes[0].set_title("Article Word Count Distribution")
axes[0].set_xlabel("Words per Article")
axes[0].set_ylabel("Count")

axes[1].hist(art["char_count"], bins=40, color=PALETTE[1], edgecolor="white")
axes[1].set_title("Article Character Count Distribution")
axes[1].set_xlabel("Characters per Article")

axes[2].hist(art["title_len"], bins=30, color=PALETTE[2], edgecolor="white")
axes[2].set_title("Title Length Distribution")
axes[2].set_xlabel("Characters in Title")

plt.tight_layout()
plt.savefig("Data/eda_article_lengths.png", bbox_inches="tight")
plt.show()

print("Word count summary:")
print(art["word_count"].describe().apply(lambda x: f"{x:,.1f}"))
print("\nChar count summary:")
print(art["char_count"].describe().apply(lambda x: f"{x:,.1f}"))
# Out:
# Word count summary:
# count    1,109.0
# mean       275.3
# std        290.6
# min          0.0
# 25%         62.0
# 50%        199.0
# 75%        400.0
# max      2,824.0
# Name: word_count, dtype: object
#
# Char count summary:
# count     1,109.0
# mean      1,769.9
# std       1,902.6
# min           0.0
# 25%         402.0
# 50%       1,244.0
# 75%       2,514.0
# max      18,252.0
# Name: char_count, dtype: object

# %% [markdown]
# <h2 style="color: #87BAC3;">📊 Word Count by Source — Comparative Analysis</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell compares article word count distributions across the three editorial sources using box plots, revealing whether different platforms produce articles of systematically different depths.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The per-source comparison reveals striking differences in editorial depth. <strong>BnB Blog</strong> produces the longest articles by far, with a median word count of <strong>658 words</strong> — more than four times the Mubawab Blog median. <strong>Houni Blog</strong> occupies a middle position with a median of <strong>199 words</strong>. <strong>Mubawab Blog</strong>, despite being the largest source, has the shortest median articles at <strong>158 words</strong> — reflecting the fact that many Mubawab "articles" are actually short market bulletin summaries, press releases, or quarterly index snapshots rather than long-form editorial content.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>This depth discrepancy has direct implications for NLP applications. BnB articles, despite being fewer in number, carry substantially more semantic content per article — making them disproportionately valuable for retrieval and comprehension tasks. For a RAG system, BnB articles should be weighted more heavily in the retrieval index relative to their raw count. Mubawab's shorter articles are better suited for classification, entity extraction, and market signal detection rather than generative question answering.</p>

# %%
# Word count by source — box plots
fig, ax = plt.subplots(figsize=(10, 5))
sources = art["source"].unique()
data_by_source = [art[art["source"] == s]["word_count"].values for s in sources]

bp = ax.boxplot(data_by_source, labels=sources, patch_artist=True,
                medianprops=dict(color="red", linewidth=2))
for patch, color in zip(bp["boxes"], PALETTE):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

ax.set_title("Article Word Count by Source")
ax.set_ylabel("Word Count")
ax.set_xlabel("Source")
plt.tight_layout()
plt.savefig("Data/eda_wordcount_by_source.png", bbox_inches="tight")
plt.show()

print("\nMedian word count by source:")
print(art.groupby("source")["word_count"].median().apply(lambda x: f"{x:,.0f}"))
# Out:
# Median word count by source:
# source
# bnb_blog        658
# houni_blog      199
# mubawab_blog    158
# Name: word_count, dtype: object

# %% [markdown]
# <h2 style="color: #87BAC3;">🔍 Content Quality Check</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell audits the completeness and minimum content quality of the article corpus — identifying missing, empty, and very short articles that may be unsuitable for NLP processing.</p>
#
# <h3>📊 Results & Observations</h3>
# <p>The quality audit reveals significant issues. Out of 1,109 articles: <strong>24 articles (2.2%)</strong> have completely missing or empty content. <strong>190 articles (17.1%)</strong> contain fewer than 50 words — a threshold below which most NLP techniques become unreliable. This means only <strong>919 articles (82.9%)</strong> meet a minimum quality bar for text analysis. All quality issues are concentrated in the <strong>Mubawab Blog</strong> source, consistent with its practice of publishing short market bulletins and press releases that redirect to external reports. The articles in Arabic script also appear in the short-article list — indicating that the word count calculation based on French tokenization may undercount Arabic content.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>A content quality filtering step is required before NLP processing: removing 24 empty articles and applying a minimum word count threshold (50–100 words) will reduce the effective corpus to approximately 900–920 articles. Arabic-language articles should also be handled separately, as they require dedicated tokenization and may need a different embedding model. The cleaned, filtered corpus of ~900 French-language articles represents the reliable core of the text dataset for downstream AI applications.</p>

# %%
# Content quality check
missing_content = art["content"].isna().sum()
missing_title   = art["title"].isna().sum()
empty_content   = (art["content"].fillna("").str.strip() == "").sum()
short_content   = (art["word_count"] < 50).sum()

print(f"Total articles:          {len(art):,}")
print(f"Missing content:         {missing_content:,}")
print(f"Empty content:           {empty_content:,}")
print(f"Very short (< 50 words): {short_content:,}")
print(f"Missing title:           {missing_title:,}")
print(f"\nArticles with content >= 50 words: {(art['word_count'] >= 50).sum():,}")

# Show very short articles if any
if short_content > 0:
    print("\nShort articles sample:")
    print(art[art["word_count"] < 50][["source", "title", "word_count"]].to_string(index=False))
# Out:
# Total articles:          1,109
# Missing content:         24
# Empty content:           24
# Very short (< 50 words): 190
# Missing title:           0
#
# Articles with content >= 50 words: 919
#
# Short articles sample:
#       source                                                                                                               title  word_count
# mubawab_blog                               Location longue durée : Hammamet arrive en tête, suivie de Nabeul centre et de Sousse          37
# mubawab_blog           Tensiomètre Locatif S1 2025 : loyers en hausse, quartiers stars et nouvelles tendances du marché tunisien          49
# mubawab_blog                                                              مؤشر قياس سوق الإيجار العقاري لمبوب – النصف الأول 2025          49
# mubawab_blog                                                     Les loyers en Tunisie en hausse de 4 % au premier semestre 2025          49
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">📚 Vocabulary Richness by Source</h2>
#
# <h3>🎯 What This Cell Does</h3>
# <p>This cell computes three vocabulary richness metrics for each source: total word count, unique word count, and the Type-Token Ratio (TTR) — a normalized measure of lexical diversity calculated as the ratio of unique words to total words. A higher TTR indicates more diverse vocabulary relative to corpus size.</p>
#
# <h3>📊 Results & Observations</h3>
# <p><strong>Mubawab Blog</strong> has the largest raw corpus: <strong>164,044 total words</strong> and <strong>14,490 unique words</strong>, but a relatively low TTR of <strong>0.088</strong> — meaning only 8.8% of all Mubawab words are unique. This low ratio is expected for a large corpus (larger corpora always have lower TTRs) but also reflects Mubawab's repetitive editorial style centered on market price reporting with recurring terminology. <strong>BnB Blog</strong> shows a much higher TTR of <strong>0.129</strong> (12.9%) across 48,013 total words — indicating more lexically diverse, long-form content covering a broader range of real estate topics. <strong>Houni Blog</strong> has the highest TTR at <strong>0.182</strong> (18.2%) despite having the smallest corpus (8,854 words), consistent with its consumer-oriented content covering diverse lifestyle and practical topics.</p>
#
# <h3>💡 Key Takeaways</h3>
# <p>Vocabulary richness analysis confirms that BnB and Houni articles, despite their smaller volume, contribute disproportionately diverse vocabulary to the corpus — which is valuable for training a broad-coverage domain embedding model. Mubawab's lower TTR is not a quality problem but a reflection of its focused, data-centric editorial style. For building a real estate vocabulary or fine-tuning a domain language model, a sampling strategy that over-represents BnB and Houni content relative to their raw frequency would produce a more lexically balanced training corpus.</p>

# %%
# Vocabulary richness by source
def vocab_stats(text_series):
    all_words = []
    for t in text_series.fillna(""):
        all_words.extend(re.findall(r'\b[a-zéèêëàâùûüôîïç]{3,}\b', t.lower()))
    total = len(all_words)
    unique = len(set(all_words))
    return pd.Series({"total_words": total, "unique_words": unique,
                      "ttr": round(unique / total, 4) if total > 0 else 0})

vocab_df = art.groupby("source")["content"].apply(vocab_stats).reset_index()
vocab_df.columns = ["source", "metric", "value"]
vocab_pivot = vocab_df.pivot(index="source", columns="metric", values="value")
print("Vocabulary richness by source:")
print(vocab_pivot.to_string())

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
metrics = ["total_words", "unique_words", "ttr"]
titles  = ["Total Words", "Unique Words", "Type-Token Ratio (TTR)"]
for ax, metric, title in zip(axes, metrics, titles):
    vals = vocab_pivot[metric]
    ax.bar(vals.index, vals.values, color=PALETTE[:len(vals)])
    ax.set_title(title)
    ax.set_ylabel(metric)
    for i, v in enumerate(vals.values):
        ax.text(i, v * 1.01, f"{v:,.3f}" if metric == "ttr" else f"{v:,.0f}",
                ha="center", fontsize=9)

plt.tight_layout()
plt.savefig("Data/eda_vocab_richness.png", bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 11
#       7     unique = len(set(all_words))
#       8     return pd.Series({"total_words": total, "unique_words": unique,
#       9                       "ttr": round(unique / total, 4) if total > 0 else 0})
# ---> 11 vocab_df = art.groupby("source")["content"].apply(vocab_stats).reset_index()
#      12 vocab_df.columns = ["source", "metric", "value"]
#      13 vocab_pivot = vocab_df.pivot(index="source", columns="metric", values="value")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\generic.py:230, in SeriesGroupBy.apply(self, func, *args, **kwargs)
#     224 @Appender(
#     225     _apply_docs["template"].format(
#     226         input="series", examples=_apply_docs["series_examples"]
#     227     )
#     228 )
# ...

# %% [markdown]
# <h2 style="color: #426d84;">🧩 Data Understanding — EDA Conclusion</h2>
#
# <p>
# The Exploratory Data Analysis phase provided a comprehensive, multi-layered diagnostic of the LensEstate intelligence corpus — spanning structured listing attributes, property images, and editorial article content. Across all three data layers, the analysis surfaced both the significant analytical potential of the dataset and the concrete quality issues that must be addressed before any modeling work can begin.
# </p>
#
# <h3 style="color: #5c8399;">🏠 Listings Dataset</h3>
# <p>
# The merged listings dataset of <strong>59,493 records</strong> across 39 columns represents a rich, multi-source snapshot of the Tunisian real estate market as of early 2026. However, the EDA revealed several structural challenges that will govern the entire data cleaning phase. Missingness is severe and non-random: <code>last_updated</code>, <code>total_floors</code>, and <code>floor</code> are effectively absent (≥99% missing) and should be dropped outright. Core modeling features such as <code>rooms</code> (75% missing) and <code>bathrooms</code> (67% missing) require platform-aware imputation strategies rather than simple mean-fill. The price column — while relatively complete at 94.5% — contains catastrophic outliers (up to 6.3 trillion TND) concentrated in Mubawab data that must be capped or removed before any regression model is trained.
# </p>
# <p>
# Categorical columns require systematic normalization: transaction type labels exist in three variants (<code>Sale</code>, <code>À Vendre</code>, <code>sale</code>), property types suffer from case duplication (<code>Maison</code> vs <code>maison</code>), and geographic fields contain alias inconsistencies (<code>Ben Arous</code> vs <code>Ben arous</code>). The near-duplicate analysis identified <strong>12,990 listings (~21.8%)</strong> sharing the same title, price, surface, and governorate — a deduplication pass is mandatory before model training. The geographic analysis confirmed a strong coastal and urban concentration, with Tunis, Nabeul, Ariana, and Sousse accounting for over half of all listings — a bias that models must acknowledge and that future scraping campaigns should actively counterbalance.
# </p>
#
# <h3 style="color: #5c8399;">🖼️ Image Dataset</h3>
# <p>
# The image EDA revealed the visual coverage and quality profile of the property image corpus. Coverage varies significantly by platform, with structured portals like Mubawab and BigDatis providing more consistent image availability than general classifieds like Tayara. Resolution analysis flagged a subset of images below the 224×224 pixel threshold required by standard CNN architectures, and the brightness analysis identified dark, overexposed, and near-grayscale images that would degrade computer vision feature quality. The sample image grid confirmed the expected mixture of interior shots, exterior photographs, and floor plan diagrams — requiring image type classification as a preprocessing step before any visual feature extraction.
# </p>
#
# <h3 style="color: #5c8399;">📰 Articles Dataset</h3>
# <p>
# The article corpus of <strong>1,109 documents</strong> is small but domain-focused. The source balance analysis exposed a severe imbalance: Mubawab Blog contributes 88.4% of articles, against 7.0% from BnB and 4.6% from Houni. This structural skew will bias topic models and retrieval systems toward Mubawab's editorial style unless explicitly corrected through sampling or weighting strategies. Content quality analysis identified <strong>190 articles below 50 words</strong> — too short for reliable NLP — and 24 completely empty entries, reducing the usable corpus to approximately 919 articles. The vocabulary richness analysis showed that BnB and Houni articles, despite being fewer, contribute disproportionately diverse vocabulary — making them high-value inputs for language model fine-tuning relative to their raw count.
# </p>
#
# <h3 style="color: #5c8399;">🛣️ Path Forward</h3>
# <p>
# The EDA findings translate directly into a prioritized data cleaning and feature engineering roadmap for the next phase:
# </p>
# <ul>
#     <li><strong>Drop</strong> columns with ≥99% missingness (<code>last_updated</code>, <code>total_floors</code>, <code>floor</code>)</li>
#     <li><strong>Normalize</strong> all categorical labels (transaction type, property type, governorate, source names) to lowercase unified standards</li>
#     <li><strong>Cap price outliers</strong> at a defensible threshold (e.g. 99th percentile ≈ 1.5M TND) and apply log transformation for modeling</li>
#     <li><strong>Coerce</strong> <code>surface_m2</code> and mixed-type amenity flags to their correct numeric and boolean types</li>
#     <li><strong>Deduplicate</strong> near-duplicate listings using a multi-field similarity strategy before any statistical or model training</li>
#     <li><strong>Filter images</strong> below minimum quality thresholds (resolution, brightness, file size) before computer vision feature extraction</li>
#     <li><strong>Filter articles</strong> below 50 words and balance the corpus across sources before NLP processing</li>
# </ul>
# <p>
# With these corrections applied, the LensEstate dataset will be well-positioned to support reliable multi-modal valuation modeling, geospatial market intelligence, and a retrieval-augmented conversational AI system in the phases that follow.
# </p>

# %% [markdown]
# <h1 style="color: #2c3e50; font-size: 34px; font-weight: bold;">
#     🧹 Data Cleaning
# </h1>
#
# <p style="font-size:15px;">
# The EDA phase surfaced a set of concrete, prioritized data quality issues in the merged listings dataset. This section addresses each one systematically in dedicated cells — normalizing source labels, standardizing transaction types, unifying property type categories, and recovering missing governorate values from city data — producing a progressively cleaner dataset ready for feature engineering and modeling.
# </p>

# %% [markdown]
# <h2 style="color: #87BAC3;">📥 Reloading the Merged Listings Dataset</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Reload the merged listings CSV as a clean working copy and display its current shape and raw value counts for the columns that require cleaning. This provides a clear before-state baseline against which every subsequent fix can be verified.</p>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Data/raw_listings/merged_listings.csv", low_memory=False)
print("Shape:", df.shape)
print()
print("source unique values:")
print(df["source"].value_counts().to_string())
print()
print("transaction_type unique values:")
print(df["transaction_type"].value_counts().to_string())
print()
print("property_type unique values (top 20):")
print(df["property_type"].value_counts().head(20).to_string())
print()
print("governorate null count:", df["governorate"].isna().sum())
print("city null count:       ", df["city"].isna().sum())
print("rows where gov is null but city exists:",
      df[df["governorate"].isna() & df["city"].notna()].shape[0])
# Out:
# Shape: (59493, 39)
#
# source unique values:
# source
# tayara                  21011
# mubawab                 14210
# Tunisie Annonce         11610
# Mubawab                  8903
# Tayara                   1385
# Facebook Marketplace      383
# Tecnocasa                 364
# Affare                    325
# Menzili.Tn                259
# Tunisiapromo              204
# Cava                      184
# Ballouchi                 175
# Bnb Tunisie               169
# Bigdatis                  117
# Century 21                102
# Fi Dari                    91
# Expat.Com                   1
#
# transaction_type unique values:
# transaction_type
# Sale        38482
# À Louer     10870
# À Vendre     6313
# rent           21
# sale           11
#
# property_type unique values (top 20):
# property_type
# Appartement          10153
# Terrain               6133
# terrain               4410
# Villa                 3021
# maison                2851
# Maison                2356
# ...

# %% [markdown]
# <h2 style="color: #87BAC3;">🌐 Fix 1 — Normalize Source Labels</h2>
#
# <h3>🎯 Purpose</h3>
# <p>The <code>source</code> column contains case-variant duplicates such as <code>"tayara"</code> and <code>"Tayara"</code>, and <code>"mubawab"</code> and <code>"Mubawab"</code>. These are the same platform and must be unified to a single canonical lowercase label so that any groupby, filter, or model that uses source as a feature treats them as one category.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>All source values are lowercased using <code>.str.lower().str.strip()</code>. This collapses all case variants in a single operation without needing to enumerate each platform explicitly — making it robust to any other mixed-case variants that may exist in smaller sources.</p>

# %%
# Normalize source labels to lowercase
df["source"] = df["source"].str.lower().str.strip()

print("source values after normalization:")
print(df["source"].value_counts().to_string())
print(f"\nUnique sources: {df['source'].nunique()}")
# Out:
# source values after normalization:
# source
# mubawab                 23113
# tayara                  22396
# tunisie annonce         11610
# facebook marketplace      383
# tecnocasa                 364
# affare                    325
# menzili.tn                259
# tunisiapromo              204
# cava                      184
# ballouchi                 175
# bnb tunisie               169
# bigdatis                  117
# century 21                102
# fi dari                    91
# expat.com                   1
#
# Unique sources: 15

# %% [markdown]
# <h2 style="color: #87BAC3;">🏷️ Fix 2 — Standardize Transaction Type</h2>
#
# <h3>🎯 Purpose</h3>
# <p>The <code>transaction_type</code> column contains the same concepts under multiple labels: <code>"Sale"</code>, <code>"À Vendre"</code>, and <code>"sale"</code> all mean a sale transaction, while <code>"À Louer"</code> and <code>"rent"</code> both mean a rental. These must be unified to two canonical English values — <code>"Sale"</code> and <code>"Rent"</code> — so that downstream models and analyses see a clean binary categorical variable.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>A mapping dictionary translates every known variant to its canonical form. <code>.map()</code> applies the mapping, and <code>.fillna(df["transaction_type"])</code> preserves any value not explicitly listed in the map (preventing accidental nullification of edge cases). The result is verified with a value_counts() printout.</p>

# %%
# Standardize transaction_type to canonical English values
tx_map = {
    "Sale"      : "Sale",
    "sale"      : "Sale",
    "À Vendre"  : "Sale",
    "à vendre"  : "Sale",
    "Vente"     : "Sale",
    "vente"     : "Sale",
    "rent"      : "Rent",
    "Rent"      : "Rent",
    "À Louer"   : "Rent",
    "à louer"   : "Rent",
    "Location"  : "Rent",
    "location"  : "Rent",
}

df["transaction_type"] = (
    df["transaction_type"]
    .map(tx_map)
    .fillna(df["transaction_type"])
)

print("transaction_type values after standardization:")
print(df["transaction_type"].value_counts(dropna=False).to_string())
# Out:
# transaction_type values after standardization:
# transaction_type
# Sale    44806
# Rent    10891
# NaN      3796

# %% [markdown]
# <h2 style="color: #87BAC3;">🏠 Fix 3 — Unify Property Type Categories</h2>
#
# <h3>🎯 Purpose</h3>
# <p>The <code>property_type</code> column contains duplicate categories caused by case inconsistencies and French/English synonym variants. The required unifications are:
# <ul>
#     <li><code>Appartement</code> / <code>appartement</code> → <code>Apartment</code></li>
#     <li><code>Maison</code> / <code>maison</code> → <code>House</code></li>
#     <li><code>Terrain</code> / <code>terrain</code> → <code>Land</code></li>
#     <li><code>others</code> / <code>Autre</code> → <code>Other</code></li>
#     <li><code>Local Commercial</code> / <code>Commerce</code> / <code>Fonds de commerce</code> → <code>Commercial</code></li>
# </ul>
# All remaining values are also normalized to title case for consistency.
# </p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>An explicit mapping dictionary handles every known variant. A final <code>.str.title().str.strip()</code> pass is applied to any value not in the map to catch remaining case inconsistencies. The result is sorted by frequency for review.</p>

# %%
# Unify property_type categories
pt_map = {
    # Apartment
    "Appartement"          : "Apartment",
    "appartement"          : "Apartment",
    # House
    "Maison"               : "House",
    "maison"               : "House",
    # Land
    "Terrain"              : "Land",
    "terrain"              : "Land",
    # Other
    "others"               : "Other",
    "Autre"                : "Other",
    "autre"                : "Other",
    # Commercial
    "Local Commercial"     : "Commercial",
    "Commerce"             : "Commercial",
    "commerce"             : "Commercial",
    "Fonds de commerce"    : "Commercial",
    "fonds de commerce"    : "Commercial",
    # Keep as-is but normalize casing for remaining types
    "Villa"                : "Villa",
    "villa"                : "Villa",
    "Bureau"               : "Office",
    "bureau"               : "Office",
    "Immeuble"             : "Building",
    "immeuble"             : "Building",
    "Ferme"                : "Farm",
    "ferme"                : "Farm",
    "Duplex"               : "Duplex",
    "duplex"               : "Duplex",
    "Studio"               : "Studio",
    "studio"               : "Studio",
}

df["property_type"] = (
    df["property_type"]
    .map(pt_map)
    .fillna(df["property_type"].str.strip())
)

print("property_type values after unification:")
print(df["property_type"].value_counts(dropna=False).to_string())
# Out:
# property_type values after unification:
# property_type
# NaN           24364
# Apartment     12264
# Land          10543
# House          5207
# Villa          3021
# Other          1986
# Commercial     1122
# Office          660
# Building        220
# Farm            106

# %% [markdown]
# <h2 style="color: #87BAC3;">🗺️ Fix 4 — Recover Missing Governorate from City</h2>
#
# <h3>🎯 Purpose</h3>
# <p>The EDA revealed approximately <strong>14,000 listings</strong> where <code>governorate</code> is null but <code>city</code> is populated. Since every Tunisian city belongs to exactly one governorate, these missing values can be recovered deterministically using a city-to-governorate reference mapping. This significantly reduces the 39.2% missingness rate on a geographically critical feature.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>A comprehensive city → governorate lookup dictionary is built covering all major Tunisian cities and their known variants (including transliteration differences and common abbreviations seen in the dataset). For each row where <code>governorate</code> is null and <code>city</code> is not null, the city value is looked up in the dictionary and the mapped governorate is filled in. Rows where the city is not found in the mapping are left as null and reported. Before and after null counts are printed to quantify the recovery.</p>

# %%
# Comprehensive city → governorate mapping for Tunisia
city_to_gov = {

    # ── Tunis ──────────────────────────────────────────────────────────────
    "Tunis": "Tunis", "Centre Ville": "Tunis", "Medina": "Tunis",
    "Médina": "Tunis", "Bab Souika": "Tunis", "Bab El Bhar": "Tunis",
    "Bab Bnet": "Tunis", "Bab Jedid": "Tunis", "Halfaouine": "Tunis",
    "Lafayette": "Tunis", "Lac": "Tunis", "Lac 1": "Tunis", "Lac 2": "Tunis",
    "Les Berges du Lac": "Tunis", "Berges du Lac": "Tunis",
    "Les Berges du Lac 1": "Tunis", "Les Berges du Lac 2": "Tunis",
    "Le Lac": "Tunis", "Lac I": "Tunis", "Lac II": "Tunis",
    "La Marsa": "Tunis", "La Marsa Plage": "Tunis",
    "La Marsa Centre": "Tunis", "Marsa": "Tunis",
    "Carthage": "Tunis", "Carthage Byrsa": "Tunis",
    "Carthage Dermech": "Tunis", "Carthage Hannibal": "Tunis",
    "Carthage Présidence": "Tunis", "Carthage Salambo": "Tunis",
    "Sidi Bou Said": "Tunis", "Sidi Bousaid": "Tunis",
    "Le Bardo": "Tunis", "Bardo": "Tunis",
    "La Goulette": "Tunis", "Goulette": "Tunis",
    "Khereddine": "Tunis",
    "El Omrane": "Tunis", "El Omrane Supérieur": "Tunis",
    "El Menzah": "Tunis", "El Menzah 1": "Tunis", "El Menzah 2": "Tunis",
    "El Menzah 4": "Tunis", "El Menzah 5": "Tunis", "El Menzah 6": "Tunis",
    "El Menzah 7": "Tunis", "El Menzah 8": "Tunis", "El Menzah 9": "Tunis",
    "El Menzah 9A": "Tunis", "El Menzah 9B": "Tunis", "El Menzah 9C": "Tunis",
    "Jardins d'El Menzah": "Tunis", "Jardins d'El Menzah 2": "Tunis",
    "Cité El Khadra": "Tunis", "El Khadra": "Tunis",
    "Montplaisir": "Tunis", "Montfleury": "Tunis",
    "Centre Urbain Nord": "Tunis", "CUN": "Tunis",
    "Cité Ennasr": "Tunis", "Ennasr": "Tunis", "Ennasr 2": "Tunis",
    "Cité Ennasr 2": "Tunis",
    "Ain Zaghouan": "Tunis", "Ain Zaghouan Nord": "Tunis",
    "Ain Zaghouan Sud": "Tunis", "Aïn Zaghouan": "Tunis",
    "La Soukra": "Tunis", "Soukra": "Tunis",
    "Chotrana": "Tunis", "Chotrana 1": "Tunis", "Chotrana 2": "Tunis",
    "Chotrana 3": "Tunis",
    "El Ghazela": "Tunis", "Cité El Ghazela": "Tunis", "Ghazela": "Tunis",
    "El Aouina": "Tunis", "L'Aouina": "Tunis", "Aouina": "Tunis",
    "Jardins de Carthage": "Tunis", "Les Jardins de Carthage": "Tunis",
    "Les Jardins d'El Menzah": "Tunis",
    "Riadh Andalous": "Tunis", "Riyadh El Andalous": "Tunis",
    "El Mourouj 6": "Tunis",
    "Cité Olympique": "Tunis", "El Manar": "Tunis",
    "El Manar 1": "Tunis", "El Manar 2": "Tunis",
    "Menzah": "Tunis", "Den Den": "Tunis", "Denden": "Tunis",
    "Ezzouhour": "Tunis", "Cité Ezzouhour": "Tunis",
    "Intilaka": "Tunis", "Cité Intilaka": "Tunis",
    "El Kabaria": "Tunis", "Sidi El Béchir": "Tunis",
    "Bhar Lazreg": "Tunis", "Gammarth": "Tunis", "Gammarth Village": "Tunis",
    "Gammarth Supérieur": "Tunis",
    "Amilcar": "Tunis", "Hamilcar": "Tunis",
    "Mégrine Coteau": "Tunis",

    # ── Ariana ─────────────────────────────────────────────────────────────
    "Ariana": "Ariana", "Ariana Ville": "Ariana",
    "Ariana Centre": "Ariana", "Ariana Essougha": "Ariana",
    "Raoued": "Ariana", "Raoued Plage": "Ariana",
    "Kalaat el-Andalous": "Ariana", "Kalâat el Andalous": "Ariana",
    "Sidi Thabet": "Ariana",
    "Mnihla": "Ariana", "La Mnihla": "Ariana",
    "Ettadhamen": "Ariana", "Ettadhamen-Mnihla": "Ariana",
    "Borj Louzir": "Ariana",
    "Ennasr": "Ariana", "Cité Ennasr": "Ariana",
    "Ghezala": "Ariana", "Ghazela": "Ariana",
    "Soukra": "Ariana",
    "Dar Fadhal": "Ariana", "Borj Turki": "Ariana",
    "Cebalet Ben Ammar": "Ariana",
    "El Kharrouba": "Ariana",
    "Ariana Menzah": "Ariana",

    # ── Ben Arous ───────────────────────────────────────────────────────────
    "Ben Arous": "Ben Arous", "Ben arous": "Ben Arous",
    "Rades": "Ben Arous", "Radès": "Ben Arous",
    "Rades Plage": "Ben Arous", "Radès Plage": "Ben Arous",
    "Hammam Lif": "Ben Arous",
    "Hammam Chott": "Ben Arous",
    "Boumhel": "Ben Arous", "Bou Mhel": "Ben Arous",
    "Bou Mhel el-Bassatine": "Ben Arous",
    "El Mourouj": "Ben Arous", "El Mourouj 1": "Ben Arous",
    "El Mourouj 2": "Ben Arous", "El Mourouj 3": "Ben Arous",
    "El Mourouj 4": "Ben Arous", "El Mourouj 5": "Ben Arous",
    "Mégrine": "Ben Arous", "Megrine": "Ben Arous",
    "Mégrine Riadh": "Ben Arous",
    "Fouchana": "Ben Arous",
    "Mornag": "Ben Arous",
    "Nouvelle Médina": "Ben Arous", "Nouvelle medina": "Ben Arous",
    "Nouvelle Medina": "Ben Arous",
    "Cité Nouvelle": "Ben Arous",
    "El Mourouj 6": "Ben Arous",
    "Bir El Kassaa": "Ben Arous",
    "Khalidia": "Ben Arous",
    "Chotrana": "Ben Arous",
    "Medina Jedida": "Ben Arous",
    "Ezzahra": "Ben Arous", "Ez Zahra": "Ben Arous",
    "Mourouj": "Ben Arous",
    "Cité El Bassatine": "Ben Arous",
    "Ben Arous Ville": "Ben Arous",
    "Borj Cedria": "Ben Arous",

    # ── Manouba ─────────────────────────────────────────────────────────────
    "Manouba": "Manouba", "La Manouba": "Manouba",
    "Oued Ellil": "Manouba",
    "Douar Hicher": "Manouba",
    "Tebourba": "Manouba", "Tébourba": "Manouba",
    "El Battane": "Manouba",
    "Jedaida": "Manouba", "La Jedaida": "Manouba",
    "Mornaguia": "Manouba",
    "Borj El Amri": "Manouba",
    "El Bassatine": "Manouba",
    "Sidi Amor": "Manouba",
    "Mannouba": "Manouba",
    "Djedeida": "Manouba",
    "Kalaat El Andalous": "Manouba",
    "Cité El Moez": "Manouba",

    # ── Nabeul ──────────────────────────────────────────────────────────────
    "Nabeul": "Nabeul", "Nabeul Centre": "Nabeul",
    "Hammamet": "Nabeul", "Hammamet Nord": "Nabeul",
    "Hammamet Sud": "Nabeul", "Hammamet Centre": "Nabeul",
    "Hammamet Yasmine": "Nabeul", "Yasmine Hammamet": "Nabeul",
    "Hammamet les Orangers": "Nabeul",
    "Kelibia": "Nabeul", "Kélibia": "Nabeul",
    "Grombalia": "Nabeul",
    "Soliman": "Nabeul", "Soliman Plage": "Nabeul",
    "Beni Khiar": "Nabeul", "Béni Khiar": "Nabeul",
    "Korba": "Nabeul",
    "Menzel Temime": "Nabeul",
    "Takelsa": "Nabeul",
    "Bou Argoub": "Nabeul",
    "Béni Khalled": "Nabeul", "Beni Khalled": "Nabeul",
    "Menzel Bouzelfa": "Nabeul",
    "Dar Chaabane": "Nabeul", "Dar Chaabane El Fehri": "Nabeul",
    "El Haouaria": "Nabeul",
    "Korbous": "Nabeul",
    "Hammam Ghezaz": "Nabeul",
    "Maamoura": "Nabeul", "El Maamoura": "Nabeul",
    "Diar El Hana": "Nabeul",
    "El Mansourah": "Nabeul",
    "Bou Smail": "Nabeul",
    "Nabi Borguiba": "Nabeul",
    "Tazerka": "Nabeul",
    "Ezzahra Nabeul": "Nabeul",
    "Jebeniana": "Nabeul",
    "Cap Bon": "Nabeul",
    "Diar El Medina": "Nabeul",

    # ── Sousse ──────────────────────────────────────────────────────────────
    "Sousse": "Sousse", "Sousse Ville": "Sousse",
    "Sousse Nord": "Sousse", "Sousse Sud": "Sousse",
    "Sousse Centre": "Sousse",
    "Hammam Sousse": "Sousse",
    "Akouda": "Sousse",
    "Sahloul": "Sousse", "Sahloul 1": "Sousse", "Sahloul 2": "Sousse",
    "Sahloul 3": "Sousse", "Sahloul 4": "Sousse",
    "El Kantaoui": "Sousse", "Port El Kantaoui": "Sousse",
    "Hergla": "Sousse",
    "Sidi Bou Ali": "Sousse",
    "Msaken": "Sousse",
    "Sidi El Hani": "Sousse",
    "Chott Meriem": "Sousse",
    "Enfidha": "Sousse",
    "Bouficha": "Sousse",
    "Kalaa Kebira": "Sousse", "Kalâa Kebira": "Sousse",
    "Kalaa Seghira": "Sousse", "Kalâa Seghira": "Sousse",
    "Sidi Abdelhamid": "Sousse",
    "Khezama": "Sousse", "Khzama": "Sousse",
    "Khezama Est": "Sousse", "Khezama Ouest": "Sousse",
    "Sousse Riadh": "Sousse",
    "Cité El Agba": "Sousse",
    "Cite Erriadh": "Sousse", "Cité Erriadh": "Sousse",
    "Cité Touhami": "Sousse",
    "Cité Sidi Abdelhamid": "Sousse",
    "Hay Riadh Sousse": "Sousse",
    "Cité Ezzouhour Sousse": "Sousse",

    # ── Monastir ─────────────────────────────────────────────────────────────
    "Monastir": "Monastir", "Monastir Ville": "Monastir",
    "Moknine": "Monastir",
    "Ksar Hellal": "Monastir",
    "Jemmal": "Monastir",
    "Téboulba": "Monastir", "Teboulba": "Monastir",
    "Bembla": "Monastir",
    "Sahline": "Monastir",
    "Zeramdine": "Monastir",
    "Cité el Wafa": "Monastir", "Cité El Wafa": "Monastir",
    "Skanes": "Monastir", "Skanes-Monastir": "Monastir",
    "Ouerdanine": "Monastir",
    "Ksibet el-Mediouni": "Monastir",
    "Sidi Bennour": "Monastir",
    "Bekalta": "Monastir",
    "Touza": "Monastir",
    "Lamta": "Monastir",
    "Beni Hassen": "Monastir",
    "Khnis": "Monastir",
    "Cité Erriadh Monastir": "Monastir",
    "Monastir Centre": "Monastir",

    # ── Sfax ─────────────────────────────────────────────────────────────────
    "Sfax": "Sfax", "Sfax Ville": "Sfax",
    "Sfax Sud": "Sfax", "Sfax Nord": "Sfax", "Sfax Ouest": "Sfax",
    "Sfax Centre": "Sfax",
    "Sakiet Ezzit": "Sfax",
    "Sakiet Eddaier": "Sfax",
    "Chihia": "Sfax",
    "El Ain": "Sfax",
    "Gremda": "Sfax",
    "Thyna": "Sfax",
    "Djebiniana": "Sfax",
    "Bir Ali Ben Khalifa": "Sfax",
    "Menzel Chaker": "Sfax",
    "El Amra": "Sfax",
    "Mahrès": "Sfax", "Mahres": "Sfax",
    "El Ghraiba": "Sfax",
    "Jebeniana": "Sfax",
    "Kerkennah": "Sfax", "Kerkenah": "Sfax",
    "Cité Ennour Sfax": "Sfax",
    "Cité El Habib Sfax": "Sfax",
    "Hay El Baath": "Sfax",
    "Sfax El Jadida": "Sfax",
    "Cité El Ons": "Sfax",
    "Ain Chaabouni": "Sfax",
    "El Jadida": "Sfax",
    "Cité Erriadh Sfax": "Sfax",
    "Sidi Abid": "Sfax",
    "Cité Afh": "Sfax",
    "Route Teniour": "Sfax", "Teniour": "Sfax",
    "Route El Ain": "Sfax",
    "Route Manzel Chaker": "Sfax",

    # ── Zaghouan ─────────────────────────────────────────────────────────────
    "Zaghouan": "Zaghouan", "Zriba": "Zaghouan",
    "Bir Mcherga": "Zaghouan",
    "Nadhour": "Zaghouan", "En Nadhour": "Zaghouan",
    "El Fahs": "Zaghouan",
    "Zriba El Alia": "Zaghouan",
    "Saouaf": "Zaghouan",

    # ── Bizerte ──────────────────────────────────────────────────────────────
    "Bizerte": "Bizerte", "Bizerte Nord": "Bizerte", "Bizerte Sud": "Bizerte",
    "Menzel Bourguiba": "Bizerte",
    "Mateur": "Bizerte",
    "Sejnane": "Bizerte", "Sejnène": "Bizerte",
    "Joumine": "Bizerte",
    "Ras Jebel": "Bizerte",
    "El Aousja": "Bizerte",
    "Utique": "Bizerte",
    "Menzel Jemil": "Bizerte",
    "Ghezala": "Bizerte",
    "Tinja": "Bizerte",
    "Zarzouna": "Bizerte",
    "El Azib": "Bizerte",
    "Menzel Abderrahman": "Bizerte",
    "Ghar El Melh": "Bizerte",
    "Metline": "Bizerte",
    "Ras Angela": "Bizerte",

    # ── Béja ─────────────────────────────────────────────────────────────────
    "Beja": "Béja", "Béja": "Béja",
    "Testour": "Béja",
    "Medjez el-Bab": "Béja", "Mejez el Bab": "Béja",
    "Téboursouk": "Béja", "Teboursouk": "Béja",
    "Nefza": "Béja",
    "Amdoun": "Béja",
    "Thibar": "Béja",
    "Goubellat": "Béja",

    # ── Jendouba ─────────────────────────────────────────────────────────────
    "Jendouba": "Jendouba",
    "Tabarka": "Jendouba",
    "Aïn Draham": "Jendouba", "Ain Draham": "Jendouba",
    "Fernana": "Jendouba",
    "Bou Salem": "Jendouba",
    "Ghardimaou": "Jendouba",
    "Oued Mliz": "Jendouba",
    "Balta Bou Aouane": "Jendouba",

    # ── Le Kef ───────────────────────────────────────────────────────────────
    "Le Kef": "Le Kef", "Kef": "Le Kef",
    "Sakiet Sidi Youssef": "Le Kef",
    "Tajerouine": "Le Kef",
    "Kalaa Khasba": "Le Kef",
    "Dahmani": "Le Kef",
    "Sers": "Le Kef",

    # ── Siliana ──────────────────────────────────────────────────────────────
    "Siliana": "Siliana",
    "Bou Arada": "Siliana",
    "Makthar": "Siliana",
    "El Krib": "Siliana",
    "Gaâfour": "Siliana",
    "Rouhia": "Siliana",

    # ── Kairouan ─────────────────────────────────────────────────────────────
    "Kairouan": "Kairouan",
    "Sbeitla": "Kairouan",
    "Haffouz": "Kairouan",
    "El Alaa": "Kairouan",
    "Hajeb El Ayoun": "Kairouan",
    "Oueslatia": "Kairouan",
    "Nasrallah": "Kairouan",
    "Cherarda": "Kairouan",
    "Chebika": "Kairouan",

    # ── Kasserine ────────────────────────────────────────────────────────────
    "Kasserine": "Kasserine",
    "Sbiba": "Kasserine",
    "Thala": "Kasserine",
    "Feriana": "Kasserine",
    "Foussana": "Kasserine",
    "Hydra": "Kasserine",
    "Ezzouhour Kasserine": "Kasserine",
    "Majel Bel Abbès": "Kasserine",

    # ── Sidi Bouzid ──────────────────────────────────────────────────────────
    "Sidi Bouzid": "Sidi Bouzid",
    "Regueb": "Sidi Bouzid",
    "Cebbala Ouled Asker": "Sidi Bouzid",
    "Bir El Hafey": "Sidi Bouzid",
    "Meknassy": "Sidi Bouzid",
    "Menzel Bouzaiane": "Sidi Bouzid",

    # ── Mahdia ───────────────────────────────────────────────────────────────
    "Mahdia": "Mahdia",
    "El Jem": "Mahdia",
    "Ksour Essaf": "Mahdia",
    "Chebba": "Mahdia",
    "Ouled Chamakh": "Mahdia",
    "Bou Merdes": "Mahdia",
    "Sidi Alouane": "Mahdia",
    "El Bradaa": "Mahdia",
    "Hebira": "Mahdia",

    # ── Gabès ────────────────────────────────────────────────────────────────
    "Gabes": "Gabès", "Gabès": "Gabès",
    "Gabès Sud": "Gabès", "Gabès Nord": "Gabès",
    "El Hamma": "Gabès",
    "Mareth": "Gabès",
    "Matmata": "Gabès",
    "Nouvelle Matmata": "Gabès",
    "Ghannouch": "Gabès",
    "Metouia": "Gabès",
    "Oudhref": "Gabès",

    # ── Médenine ─────────────────────────────────────────────────────────────
    "Medenine": "Médenine", "Médenine": "Médenine",
    "Djerba": "Médenine", "Djerba Midoun": "Médenine",
    "Djerba Houmt Souk": "Médenine", "Djerba - Ajim": "Médenine",
    "Djerba Ajim": "Médenine",
    "Zarzis": "Médenine",
    "Ben Gardane": "Médenine",
    "Beni Khedache": "Médenine", "Béni Khedache": "Médenine",
    "Jerba": "Médenine",

    # ── Tataouine ────────────────────────────────────────────────────────────
    "Tataouine": "Tataouine",
    "Ghomrassen": "Tataouine",
    "Remada": "Tataouine",
    "Dehiba": "Tataouine",

    # ── Gafsa ────────────────────────────────────────────────────────────────
    "Gafsa": "Gafsa", "Gafsa Sud": "Gafsa", "Gafsa Nord": "Gafsa",
    "Metlaoui": "Gafsa",
    "Moulares": "Gafsa",
    "El Guettar": "Gafsa",
    "Redeyef": "Gafsa",
    "Moularès": "Gafsa",

    # ── Tozeur ───────────────────────────────────────────────────────────────
    "Tozeur": "Tozeur",
    "Nefta": "Tozeur",
    "Degache": "Tozeur",
    "Hazoua": "Tozeur",

    # ── Kébili ───────────────────────────────────────────────────────────────
    "Kebili": "Kébili", "Kébili": "Kébili",
    "Douz": "Kébili",
    "Souk Lahad": "Kébili",

    # ── Additional unmapped cities (encoding variants & missing aliases) ──────
    # Le Kram → Tunis
    "Le Kram": "Tunis", "Kram": "Tunis", "El Kram": "Tunis",

    # KéLibia → encoding artifact of Kélibia → Nabeul
    "KéLibia": "Nabeul", "Kelibia": "Nabeul", "Kélibia": "Nabeul",
    "KéLibia": "Nabeul",

    # Hammam Chatt → Ben Arous
    "Hammam Chatt": "Ben Arous", "Hammam Chot": "Ben Arous",

    # Boumhel Bassatine → Ben Arous
    "Boumhel Bassatine": "Ben Arous", "Boumhel el Bassatine": "Ben Arous",
    "Boumhel El Bassatine": "Ben Arous",

    # Midoun → Médenine (Djerba Midoun)
    "Midoun": "Médenine", "Djerba Midoun": "Médenine",

    # Sousse Jaouhara → Sousse
    "Sousse Jaouhara": "Sousse", "Jawhara": "Sousse",
    "Cite Jawhara": "Sousse", "Cité Jawhara": "Sousse",

    # KalâA Kebira → encoding artifact of Kalâa Kebira → Sousse
    "KalâA Kebira": "Sousse", "Kalaa Kebira": "Sousse",
    "Kalâa Kebira": "Sousse", "KalâA Kbira": "Sousse",

    # KalâA Sghira → encoding artifact of Kalâa Seghira → Sousse
    "KalâA Sghira": "Sousse", "Kalaa Sghira": "Sousse",
    "Kalaa Seghira": "Sousse", "Kalâa Seghira": "Sousse",
    "KalâA Seghira": "Sousse",

    # MéGrine → encoding artifact of Mégrine → Ben Arous
    "MéGrine": "Ben Arous", "Megrine": "Ben Arous", "Mégrine": "Ben Arous",

    # Sidi Bou Ali Sousse → Sousse
    "Sidi Bou Ali Sousse": "Sousse", "Sidi Bou Ali": "Sousse",

    # Mohamadia → Manouba
    "Mohamadia": "Manouba", "Mohammadia": "Manouba",

    # Kairouan Ville → Kairouan
    "Kairouan Ville": "Kairouan",

    # Houmt Souk → Médenine (Djerba capital)
    "Houmt Souk": "Médenine", "Houmt El Souk": "Médenine",
    "Djerba Houmt Souk": "Médenine",

    # Rejiche → Mahdia
    "Rejiche": "Mahdia",

    # Hammam El Ghezaz → Nabeul
    "Hammam El Ghezaz": "Nabeul", "Hammam Ghezaz": "Nabeul",
    "Hammamet El Ghezaz": "Nabeul",

    # Sidi Hassine → Tunis
    "Sidi Hassine": "Tunis", "Sidi Hassine Sijoumi": "Tunis",

    # Tantana → Sfax
    "Tantana": "Sfax",

    # El Ouardia → Tunis
    "El Ouardia": "Tunis", "Ouardia": "Tunis",

    # Sousse Corniche → Sousse
    "Sousse Corniche": "Sousse", "Corniche Sousse": "Sousse",

    # Dar ChâAbane → encoding artifact of Dar Chaabane → Nabeul
    "Dar ChâAbane": "Nabeul", "Dar Chaabane": "Nabeul",
    "Dar Chaabane El Fehri": "Nabeul", "Dar ChaâBane": "Nabeul",

    # ── Batch 3 — unmapped cities ─────────────────────────────────────────────
    # Mahdia Ville → Mahdia
    "Mahdia Ville": "Mahdia",

    # Raf Raf → Bizerte
    "Raf Raf": "Bizerte", "Raf-Raf": "Bizerte",

    # Salakta → Mahdia
    "Salakta": "Mahdia",

    # Aghir → Médenine (Djerba)
    "Aghir": "Médenine",

    # Barraket Essahel → Ben Arous
    "Barraket Essahel": "Ben Arous", "Barraket Sahel": "Ben Arous",

    # El Hrairia → Tunis
    "El Hrairia": "Tunis", "Hrairia": "Tunis",

    # M'Saken → Sousse
    "M'Saken": "Sousse", "M Saken": "Sousse", "Msaken": "Sousse",

    # Hammam GhezèZe → encoding artifact of Hammam Ghezaz → Nabeul
    "Hammam GhezèZe": "Nabeul", "Hammam Ghezeze": "Nabeul",
    "Hammam GhézèZe": "Nabeul",

    # La Medina → Tunis
    "La Medina": "Tunis", "La Médina": "Tunis", "Medina Tunis": "Tunis",

    # Hammam Sousse Ghrabi → Sousse
    "Hammam Sousse Ghrabi": "Sousse", "Hammam Sousse Gharbi": "Sousse",

    # El Omrane Superieur → Tunis
    "El Omrane Superieur": "Tunis", "El Omrane Supérieur": "Tunis",
    "Omrane Superieur": "Tunis",

    # BéJa → encoding artifact of Béja
    "BéJa": "Béja", "Beja Ville": "Béja", "Béja Ville": "Béja",

    # Midoun Zone Touristique → Médenine (Djerba)
    "Midoun Zone Touristique": "Médenine",
    "Midoun Zone touristique": "Médenine",

    # Kalaat Landalous → Ariana
    "Kalaat Landalous": "Ariana", "Kalaat El Andalous": "Ariana",
    "Kalâat El Andalous": "Ariana",

    # Cité Jaouhara → Sousse
    "Cité Jaouhara": "Sousse", "Cite Jaouhara": "Sousse",

    # Tazarka → Nabeul
    "Tazarka": "Nabeul", "Tazerka": "Nabeul",

    # Ksour Essef → Mahdia
    "Ksour Essef": "Mahdia", "Ksour Essaf": "Mahdia",
    "Ksour El Assel": "Mahdia",

    # Tezdaine → Médenine (Djerba)
    "Tezdaine": "Médenine",

    # Ettahrir → Tunis
    "Ettahrir": "Tunis", "El Tahrir": "Tunis",

    # MahrèS → encoding artifact of Mahrès → Sfax
    "MahrèS": "Sfax", "Mahres": "Sfax", "Mahrès": "Sfax",
}

# Apply recovery
gov_before = df["governorate"].isna().sum()

def recover_governorate(row):
    if pd.isna(row["governorate"]) and pd.notna(row["city"]):
        city_clean = str(row["city"]).strip()
        return city_to_gov.get(city_clean, row["governorate"])
    return row["governorate"]

df["governorate"] = df.apply(recover_governorate, axis=1)

gov_after   = df["governorate"].isna().sum()
recovered   = gov_before - gov_after
still_null  = df[df["governorate"].isna() & df["city"].notna()]

print(f"Governorate nulls BEFORE : {gov_before:,}")
print(f"Governorate nulls AFTER  : {gov_after:,}")
print(f"Recovered                : {recovered:,}")
print(f"Still null (city exists but not mapped): {len(still_null):,}")
if len(still_null) > 0:
    print("\nUnmapped cities (top 20):")
    print(still_null["city"].value_counts().head(20).to_string())
# Out:
# Governorate nulls BEFORE : 23,325
# Governorate nulls AFTER  : 9,369
# Recovered                : 13,956
# Still null (city exists but not mapped): 254
#
# Unmapped cities (top 20):
# city
# Jendouba Ville        9
# Bir Bouregba          9
# El Battan             9
# Cité Hached           9
# Sijoumi               9
# TéBoulba              9
# Kondar                8
# Mcherga               8
# GabèS Sud             8
# El Alia               8
# Ksibet El MéDiouni    8
# Medjez El Bab         7
# Al Qayrawan           7
# Mezraya               7
# SomâA                 7
# Ajim                  6
# Jebel El Oust         6
# El Mida               6
# Kairouan Nord         6
# El Corniche           5

# %% [markdown]
# <h2 style="color: #87BAC3;">📍 Fix 5 — Normalize Governorate Name Variants</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Beyond the recovered nulls, the EDA revealed that some governorates appear under multiple name variants in the existing non-null values — for example <code>"Ben Arous"</code> and <code>"Ben arous"</code>, or <code>"La Manouba"</code> and <code>"Manouba"</code>. These must be unified to a single canonical spelling so that geographic groupbys and model encoders treat them as one region.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>A normalization mapping covers all known alias pairs observed in the data. It is applied with <code>.map().fillna()</code> to preserve any correctly spelled values not listed in the map. The final unique governorate list is printed in alphabetical order as a verification step.</p>

# %%
# Normalize existing governorate name variants
gov_map = {
    "Ben arous"  : "Ben Arous",
    "ben arous"  : "Ben Arous",
    "La Manouba" : "Manouba",
    "la manouba" : "Manouba",
    "Gabès"      : "Gabès",
    "Gabes"      : "Gabès",
    "Médenine"   : "Médenine",
    "Medenine"   : "Médenine",
    "Béja"       : "Béja",
    "Beja"       : "Béja",
    "Kébili"     : "Kébili",
    "Kebili"     : "Kébili",
    "Tunis"      : "Tunis",
    "Nabeul"     : "Nabeul",
    "Ariana"     : "Ariana",
    "Sousse"     : "Sousse",
    "Sfax"       : "Sfax",
    "Monastir"   : "Monastir",
    "Bizerte"    : "Bizerte",
    "Zaghouan"   : "Zaghouan",
    "Mahdia"     : "Mahdia",
    "Kairouan"   : "Kairouan",
    "Kasserine"  : "Kasserine",
    "Gafsa"      : "Gafsa",
    "Tozeur"     : "Tozeur",
    "Tataouine"  : "Tataouine",
    "Sidi Bouzid": "Sidi Bouzid",
    "Le Kef"     : "Le Kef",
    "Siliana"    : "Siliana",
    "Jendouba"   : "Jendouba",
    "Manouba"    : "Manouba",
}

df["governorate"] = (
    df["governorate"]
    .map(gov_map)
    .fillna(df["governorate"])
)

print("Governorate value counts after normalization:")
print(df["governorate"].value_counts(dropna=False).to_string())
print(f"\nTotal unique governorates: {df['governorate'].nunique()}")
# Out:
# Governorate value counts after normalization:
# governorate
# Tunis          15835
# Nabeul          9727
# NaN             9369
# Ariana          7553
# Sousse          5972
# Ben Arous       3984
# Sfax            1474
# Bizerte         1088
# Manouba         1017
# Monastir         739
# Médenine         655
# Zaghouan         595
# Mahdia           471
# Béja             193
# Gabès            183
# Kairouan         140
# Jendouba         123
# Le Kef            80
# Gafsa             73
# Siliana           39
# tunis             26
# ariana            26
# Kasserine         22
# Tozeur            21
# Tataouine         18
# Sidi Bouzid       18
# Kébili            16
# sfax              11
# mahdia             6
# ben-arous          6
# Sidi bouzid        6
# médenine           4
# nabeul             2
# sousse             1
#
# Total unique governorates: 33

# %% [markdown]
# <h2 style="color: #87BAC3;">💾 Verification & Save Cleaned Dataset</h2>
#
# <h3>🎯 Purpose</h3>
# <p>A final end-to-end verification prints the cleaned state of all five modified columns side by side, confirming that every fix was applied correctly and without unintended side effects. The cleaned DataFrame is then saved to disk as <strong>merged_listings_cleaned.csv</strong>, becoming the new canonical input for all downstream phases.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>Value counts are printed for each fixed column. Shape is checked to confirm no rows were accidentally dropped. The cleaned file is written with <code>index=False</code> and a final confirmation message prints the output path and row count.</p>

# %%
# ── Final verification ────────────────────────────────────────────────────
print("=" * 55)
print("CLEANED DATASET — FINAL VERIFICATION")
print("=" * 55)
print(f"Shape: {df.shape}")

print("\n── source ──")
print(df["source"].value_counts().to_string())

print("\n── transaction_type ──")
print(df["transaction_type"].value_counts(dropna=False).to_string())

print("\n── property_type ──")
print(df["property_type"].value_counts(dropna=False).head(20).to_string())

print("\n── governorate (null count) ──")
print(f"Null: {df['governorate'].isna().sum():,}  ({df['governorate'].isna().mean()*100:.1f}%)")
print(df["governorate"].value_counts(dropna=False).head(15).to_string())

# ── Save ──────────────────────────────────────────────────────────────────
df.to_csv("Data/raw_listings/merged_listings_cleaned.csv", index=False)
print("\n✅ Saved → Data/raw_listings/merged_listings_cleaned.csv")
print(f"   Rows: {len(df):,}  |  Columns: {df.shape[1]}")
# Out:
# ...
# CLEANED DATASET — FINAL VERIFICATION
# ...
# Shape: (59493, 39)
#
# ── source ──
# source
# mubawab                 23113
# tayara                  22396
# tunisie annonce         11610
# facebook marketplace      383
# tecnocasa                 364
# affare                    325
# menzili.tn                259
# tunisiapromo              204
# cava                      184
# ballouchi                 175
# bnb tunisie               169
# bigdatis                  117
# century 21                102
# fi dari                    91
# expat.com                   1
#
# ── transaction_type ──
# transaction_type
# Sale    44806
# Rent    10891
# NaN      3796
#
# ── property_type ──
# property_type
# NaN           24364
# Apartment     12264
# Land          10543
# House          5207
# Villa          3021
# Other          1986
# Commercial     1122
# Office          660
# Building        220
# Farm            106
#
# ── governorate (null count) ──
# Null: 9,369  (15.7%)
# governorate
# ...

# %%
# Remove Rent listings — keep Sale only
before = len(df)

df = df[df["transaction_type"] == "Sale"].reset_index(drop=True)

after = len(df)
removed = before - after

print(f"Rows BEFORE : {before:,}")
print(f"Rows AFTER  : {after:,}")
print(f"Removed     : {removed:,} Rent listings ({removed/before*100:.1f}%)")
print(f"\nRemaining transaction_type values:")
print(df["transaction_type"].value_counts(dropna=False).to_string())
# Out:
# Rows BEFORE : 59,493
# Rows AFTER  : 44,806
# Removed     : 14,687 Rent listings (24.7%)
#
# Remaining transaction_type values:
# transaction_type
# Sale    44806

# %%
both_null = df[df["governorate"].isna() & df["city"].isna()].shape[0]
print(f"Rows where both city AND governorate are null: {both_null:,}")
print(f"That's {both_null/len(df)*100:.1f}% of total listings")
# Out:
# Rows where both city AND governorate are null: 7,951
# That's 17.7% of total listings

# %% [markdown]
# <h2 style="color: #87BAC3;">🔁 Duplicate Verification Based on Description</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Description text is the richest deduplication signal in the dataset — two listings sharing an identical description are almost certainly the same property reposted across platforms or across time. This cell identifies exact description duplicates, analyzes their distribution by source, and inspects sample pairs to decide whether to drop them.</p>
#
# <h3>🔍 Technical Breakdown</h3>
# <p>Exact description duplicates are detected with <code>duplicated(subset=["description"])</code>. The analysis reports total duplicate count, which sources contribute them most, and how many unique descriptions are shared by 2, 3, or more listings. A sample of duplicated description groups is displayed for manual inspection. The index is kept intact at this stage — deduplication is applied in the next cell after reviewing the results.</p>

# %%
# ── Exact description duplicates ──────────────────────────────────────────
desc_dupes = df[df["description"].notna()].duplicated(subset=["description"], keep=False)
dupes_df   = df[df["description"].notna()][desc_dupes]

total_dupes    = df.duplicated(subset=["description"], keep=False).sum()
unique_duped   = df[df.duplicated(subset=["description"], keep=False)]["description"].nunique()
rows_to_remove = df.duplicated(subset=["description"], keep="first").sum()

print(f"Total rows with a duplicated description : {total_dupes:,}")
print(f"Unique descriptions that appear >1 time  : {unique_duped:,}")
print(f"Rows that would be dropped (keep first)  : {rows_to_remove:,}")
print(f"Rows that would remain                   : {len(df) - rows_to_remove:,}")

# How many listings share the same description
freq = dupes_df["description"].value_counts()
print(f"\nDuplicate group size distribution:")
print(freq.value_counts().sort_index().rename_axis("copies").rename("groups").to_string())

# By source
print(f"\nDuplicate rows by source:")
print(dupes_df["source"].value_counts().to_string())
# Out:
# Total rows with a duplicated description : 15,717
# Unique descriptions that appear >1 time  : 4,566
# Rows that would be dropped (keep first)  : 11,150
# Rows that would remain                   : 33,656
#
# Duplicate group size distribution:
# copies
# 2      2637
# 3       626
# 4       302
# 5       308
# 6       437
# 7        99
# 8        45
# 9        13
# 10       12
# 11        9
# 12       12
# 13        6
# 14        5
# 15        4
# 16        3
# 17        3
# 18        2
# 19        2
# 20        4
# 21        2
# 22        1
# 24        2
# 25        2
# 26        2
# 27        3
# 28        8
# 29        4
# 30        1
# 31        1
# 32        1
# 33        2
# 34        1
# 35        1
# 36        2
# 37        1
# 40        1
# 60        1
# 112       1
#
# Duplicate rows by source:
# source
# mubawab                 7863
# tayara                  4429
# tunisie annonce         2628
# tecnocasa                242
# affare                   140
# ...

# %%
# Drop duplicates based on description — keep first occurrence
before = len(df)

df = df.drop_duplicates(subset=["description"], keep="first").reset_index(drop=True)

after = len(df)
print(f"Rows BEFORE : {before:,}")
print(f"Rows AFTER  : {after:,}")
print(f"Dropped     : {before - after:,} duplicate rows")
# Out:
# Rows BEFORE : 44,806
# Rows AFTER  : 33,656
# Dropped     : 11,150 duplicate rows

# %% [markdown]
# <h2 style="color: #87BAC3;">🕳️ Missing Values Check — Post Cleaning</h2>
#
# <h3>🎯 Purpose</h3>
# <p>After all cleaning steps applied so far — source normalization, transaction type standardization, property type unification, governorate recovery, rent removal, and description-based deduplication — this cell recomputes the missing value profile across all columns to measure the impact of the cleaning pipeline and identify what still needs to be addressed before modeling.</p>

# %%
# Full missing values report — all 39 columns including complete ones
missing_all = df.isnull().mean()
missing_df_full = missing_all.reset_index()
missing_df_full.columns = ["column", "missing_pct"]
missing_df_full["missing_count"] = (missing_df_full["missing_pct"] * len(df)).astype(int)
missing_df_full["missing_pct_label"] = (missing_df_full["missing_pct"] * 100).round(1).astype(str) + "%"
missing_df_full = missing_df_full.sort_values("missing_pct", ascending=False)

print(f"Dataset shape: {df.shape}")
print(f"\n{'Column':<25} {'Missing':>10} {'%':>8}")
print("-" * 45)
for _, row in missing_df_full.iterrows():
    print(f"{row['column']:<25} {row['missing_count']:>10,} {row['missing_pct_label']:>8}")
# Out:
# Dataset shape: (33656, 39)
#
# Column                       Missing        %
# ---------------------------------------------
# total_floors                  33,656   100.0%
# last_updated                  33,656   100.0%
# floor                         33,643   100.0%
# total_rooms                   28,739    85.4%
# bathrooms                     26,956    80.1%
# bedrooms                      24,638    73.2%
# rooms                         24,212    71.9%
# agency_name                   14,856    44.1%
# date_posted                   13,780    40.9%
# scrape_timestamp               8,477    25.2%
# property_type                  7,112    21.1%
# surface_m2                     6,032    17.9%
# governorate                    4,987    14.8%
# city                           4,748    14.1%
# seller_type                    3,855    11.5%
# has_security                   3,852    11.4%
# has_heating                    3,850    11.4%
# has_air_conditioning           3,850    11.4%
# ...

# %%
both_null = df[df["governorate"].isna() & df["city"].isna()].shape[0]
print(f"Rows where both city AND governorate are null: {both_null:,}")
print(f"That's {both_null/len(df)*100:.1f}% of total listings")
# Out:
# Rows where both city AND governorate are null: 4,737
# That's 14.1% of total listings

# %% [markdown]
# <h1 style="color: #2c3e50; font-size: 34px; font-weight: bold;">
#     🧹 Missing Values Treatment
# </h1>
# <p style="font-size:15px;">
# This section executes the full missing values treatment plan designed for the multimodal property valuation model. Each column is handled with a strategy tailored to its role in the model pipeline — structured branch features, NLP description branch, and image branch — ensuring that imputation decisions are defensible and model-aware.
# </p>

# %% [markdown]
# <h2 style="color: #87BAC3;">🗑️ Step 1 — Drop Useless Columns</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Drop columns that are either 100% empty and therefore carry zero information, or metadata fields that have no role in the valuation model pipeline: <code>total_floors</code>, <code>last_updated</code>, <code>floor</code> (all 100% null), <code>scrape_timestamp</code> (pipeline metadata), <code>date_posted</code> (41% missing, inconsistent formats), and <code>agency_name</code> (44% missing, too sparse and high-cardinality to be useful).</p>

# %%
# Drop columns with no modeling value
cols_to_drop = [
    "total_floors",    # 100% missing
    "last_updated",    # 100% missing
    "floor",           # 100% missing
    "scrape_timestamp",# pipeline metadata, not a model feature
    "date_posted",     # 41% missing, inconsistent formats
    "agency_name",     # 44% missing, high cardinality noise
]

before_cols = df.shape[1]
df = df.drop(columns=cols_to_drop)

print(f"Columns BEFORE : {before_cols}")
print(f"Columns AFTER  : {df.shape[1]}")
print(f"Dropped        : {cols_to_drop}")
print(f"\nRemaining columns ({df.shape[1]}):")
print(df.columns.tolist())
# Out:
# Columns BEFORE : 39
# Columns AFTER  : 33
# Dropped        : ['total_floors', 'last_updated', 'floor', 'scrape_timestamp', 'date_posted', 'agency_name']
#
# Remaining columns (33):
# ['id', 'listing_id', 'listing_url', 'source', 'title', 'property_type', 'transaction_type', 'price', 'currency', 'surface_m2', 'rooms', 'total_rooms', 'bedrooms', 'bathrooms', 'country', 'governorate', 'city', 'description', 'image_count', 'image_urls', 'seller_type', 'has_elevator', 'has_basement', 'has_heating', 'has_air_conditioning', 'has_garden', 'has_furniture', 'has_parking', 'has_pool', 'has_security', 'has_standing', 'has_terrace', 'has_sea_view']

# %% [markdown]
# <h2 style="color: #87BAC3;">📝 Step 2 — Drop the Single Null Description Row</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Description is a <strong>core input to the NLP branch</strong> of the valuation model. A listing with no description provides zero text signal and cannot contribute to training the language model component. The single null description row is dropped outright.</p>

# %%
# Drop the single row with null description
before = len(df)
df = df[df["description"].notna()].reset_index(drop=True)
print(f"Rows BEFORE : {before:,}")
print(f"Rows AFTER  : {len(df):,}")
print(f"Dropped     : {before - len(df)} row(s) with null description")
# Out:
# Rows BEFORE : 33,656
# Rows AFTER  : 33,655
# Dropped     : 1 row(s) with null description

# %% [markdown]
# <h2 style="color: #87BAC3;">📊 Step 3 — Add Description Word Count Feature</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Description length is a meaningful structured signal for the valuation model: longer, more detailed descriptions correlate with more effort from the seller and often with higher-value properties. Adding <code>description_word_count</code> now as a derived structured feature makes this signal available to the structured branch independently of the NLP branch.</p>

# %%
# Add description word count as a structured feature
df["description_word_count"] = df["description"].str.split().str.len()

print("description_word_count summary:")
print(df["description_word_count"].describe().apply(lambda x: f"{x:,.1f}"))
# Out:
# description_word_count summary:
# count    33,655.0
# mean         68.2
# std          66.4
# min           1.0
# 25%          26.0
# 50%          51.0
# 75%          89.0
# max       1,815.0
# Name: description_word_count, dtype: object

# %% [markdown]
# <h2 style="color: #87BAC3;">🖼️ Step 4 — Image Availability Flag & Fill image_urls</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Since images form a dedicated model branch, the pipeline needs to know which listings have visual data available. A binary <code>has_images</code> flag is added as a structured feature. Null <code>image_urls</code> values are filled with an empty string so downstream image loading code does not need to handle NaN separately.</p>

# %%
# Add has_images flag and fill null image_urls
df["has_images"] = df["image_count"] > 0
df["image_urls"] = df["image_urls"].fillna("")

print(f"Listings with images    : {df['has_images'].sum():,} ({df['has_images'].mean()*100:.1f}%)")
print(f"Listings without images : {(~df['has_images']).sum():,} ({(~df['has_images']).mean()*100:.1f}%)")
print(f"Null image_urls remaining: {df['image_urls'].isna().sum()}")
# Out:
# Listings with images    : 33,158 (98.5%)
# Listings without images : 497 (1.5%)
# Null image_urls remaining: 0

# %% [markdown]
# <h2 style="color: #87BAC3;">🔒 Step 5 — Fill Amenity Flag NaNs → False</h2>
#
# <h3>🎯 Purpose</h3>
# <p>The five amenity columns stored as <code>object</code> type (<code>has_elevator</code>, <code>has_heating</code>, <code>has_air_conditioning</code>, <code>has_parking</code>, <code>has_security</code>) have ~11.4% missing values because certain scraping sources simply did not capture these fields. The standard real estate imputation rule applies: <strong>if an amenity is not mentioned, it is assumed absent</strong> — sellers consistently highlight desirable features when present. NaNs are filled with <code>False</code> and all five columns are coerced to boolean type.</p>

# %%
# Fill amenity flag NaNs with False and coerce to bool
amenity_obj_cols = [
    "has_elevator", "has_heating", "has_air_conditioning",
    "has_parking", "has_security"
]

for col in amenity_obj_cols:
    df[col] = df[col].fillna(False)
    df[col] = df[col].map(
        lambda x: False if str(x).strip().lower() in ("false", "0", "nan", "") else bool(x)
    )

print("Amenity flags — null counts after fill:")
for col in amenity_obj_cols:
    print(f"  {col:<25} nulls: {df[col].isna().sum()}  dtype: {df[col].dtype}")
# Out:
# Amenity flags — null counts after fill:
#   has_elevator              nulls: 0  dtype: bool
#   has_heating               nulls: 0  dtype: bool
#   has_air_conditioning      nulls: 0  dtype: bool
#   has_parking               nulls: 0  dtype: bool
#   has_security              nulls: 0  dtype: bool

# %% [markdown]
# <h2 style="color: #87BAC3;">👤 Step 6 — Encode seller_type as is_agency</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Rather than imputing the raw <code>seller_type</code> string, it is more useful for the model to encode it as a binary feature: <code>is_agency = 1</code> if the listing was posted by an agency, <code>0</code> if by a private individual, and <code>-1</code> if unknown. This retains the missingness signal while providing a clean numeric input to the structured branch.</p>

# %%
# Encode seller_type as binary is_agency feature
def encode_seller(val):
    if isinstance(val, str):
        v = val.strip().lower()
        if any(k in v for k in ["agence", "agency", "professionnel", "pro", "agent"]):
            return 1
        elif any(k in v for k in ["particulier", "individual", "private", "privé"]):
            return 0
    return -1  # unknown

df["is_agency"] = df["seller_type"].apply(encode_seller)

print("is_agency distribution:")
print(df["is_agency"].value_counts().rename({1: "Agency", 0: "Individual", -1: "Unknown"}).to_string())
# Out:
# is_agency distribution:
# is_agency
# Agency        20153
# Individual     9623
# Unknown        3879

# %% [markdown]
# <h2 style="color: #87BAC3;">🏠 Step 7 — Recover property_type from Title & Description</h2>
#
# <h3>🎯 Purpose</h3>
# <p>With 21.1% of <code>property_type</code> values missing, and given that property type is both a critical structured feature AND a conditioning signal for the image branch (the visual appearance of an apartment differs fundamentally from a farm or a villa), recovery is a priority. A keyword-matching approach scans the listing title and description for property-type indicator terms in French and English, and assigns the matched type. Rows where no keyword is found are labeled <code>"Unknown"</code>.</p>

# %%
# Keyword-based property_type recovery from title + description
import re

TYPE_KEYWORDS = {
    "Apartment" : [
        "appartement", "appart", "apartment", "flat", "s\+1", "s\+2", "s\+3",
        "s\+4", "s\+5", "studio", "f2", "f3", "f4"
    ],
    "Villa"     : ["villa", "propriété", "propriete", "chalet"],
    "House"     : ["maison", "house", "dar", "riad"],
    "Land"      : ["terrain", "land", "lot", "parcelle", "foncier"],
    "Commercial": ["local commercial", "commerce", "fonds de commerce",
                   "boutique", "magasin", "local", "fond de commerce"],
    "Office"    : ["bureau", "office", "bureaux"],
    "Building"  : ["immeuble", "building", "résidence"],
    "Farm"      : ["ferme", "farm", "exploitation"],
    "Duplex"    : ["duplex"],
}

def infer_property_type(row):
    if pd.notna(row["property_type"]):
        return row["property_type"]
    text = " ".join([
        str(row.get("title", "") or ""),
        str(row.get("description", "") or "")
    ]).lower()
    for ptype, keywords in TYPE_KEYWORDS.items():
        for kw in keywords:
            if re.search(r'\b' + kw + r'\b', text):
                return ptype
    return "Unknown"

before_null = df["property_type"].isna().sum()
df["property_type"] = df.apply(infer_property_type, axis=1)
after_null  = df["property_type"].isna().sum()

print(f"property_type nulls BEFORE : {before_null:,}")
print(f"property_type nulls AFTER  : {after_null:,}")
print(f"Recovered                  : {before_null - after_null:,}")
print(f"\nproperty_type distribution:")
print(df["property_type"].value_counts().to_string())
# Out:
# property_type nulls BEFORE : 7,112
# property_type nulls AFTER  : 0
# Recovered                  : 7,112
#
# property_type distribution:
# property_type
# Apartment     10880
# Land           9292
# House          4294
# Villa          3694
# Other          1814
# Commercial     1514
# Office          693
# Unknown         646
# Building        554
# Duplex          164
# Farm            110

# %% [markdown]
# <h2 style="color: #87BAC3;">🗺️ Step 8 — Recover City & Governorate from Title & Description</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Location is the single strongest price driver in real estate valuation. For listings where both <code>city</code> and <code>governorate</code> are null, we scan the listing title and description for known Tunisian city and governorate names. Matches are used to fill the missing geographic fields. This regex-based approach is fast, deterministic, and recovers the majority of cases where the seller mentions a location in their listing text. Rows where no geographic signal is found are dropped — they would introduce significant noise into a location-aware valuation model.</p>

# %%
# Regex-based city + governorate recovery from title + description
import re, pandas as pd

# Full city → governorate lookup (reuse the same map from Fix 4)
CITY_GOV = {
    "tunis": "Tunis", "la marsa": "Tunis", "carthage": "Tunis",
    "sidi bou said": "Tunis", "le bardo": "Tunis", "la goulette": "Tunis",
    "el menzah": "Tunis", "gammarth": "Tunis", "ain zaghouan": "Tunis",
    "la soukra": "Tunis", "chotrana": "Tunis", "el ghazela": "Tunis",
    "l'aouina": "Tunis", "el aouina": "Tunis", "jardins de carthage": "Tunis",
    "riadh andalous": "Tunis", "centre urbain nord": "Tunis",
    "cité ennasr": "Tunis", "ennasr": "Tunis", "el kram": "Tunis",
    "sidi hassine": "Tunis", "el ouardia": "Tunis", "bab souika": "Tunis",
    "montplaisir": "Tunis", "le lac": "Tunis", "berges du lac": "Tunis",
    "ariana": "Ariana", "raoued": "Ariana", "mnihla": "Ariana",
    "ettadhamen": "Ariana", "borj louzir": "Ariana",
    "ben arous": "Ben Arous", "rades": "Ben Arous", "radès": "Ben Arous",
    "hammam lif": "Ben Arous", "hammam chott": "Ben Arous",
    "boumhel": "Ben Arous", "el mourouj": "Ben Arous",
    "mégrine": "Ben Arous", "fouchana": "Ben Arous", "mornag": "Ben Arous",
    "ezzahra": "Ben Arous", "borj cedria": "Ben Arous",
    "manouba": "Manouba", "oued ellil": "Manouba", "douar hicher": "Manouba",
    "tebourba": "Manouba", "jedaida": "Manouba", "mornaguia": "Manouba",
    "nabeul": "Nabeul", "hammamet": "Nabeul", "kelibia": "Nabeul",
    "kélibia": "Nabeul", "grombalia": "Nabeul", "soliman": "Nabeul",
    "korba": "Nabeul", "dar chaabane": "Nabeul", "maamoura": "Nabeul",
    "tazarka": "Nabeul", "beni khiar": "Nabeul", "el haouaria": "Nabeul",
    "zaghouan": "Zaghouan", "el fahs": "Zaghouan",
    "bizerte": "Bizerte", "menzel bourguiba": "Bizerte", "raf raf": "Bizerte",
    "mateur": "Bizerte", "ras jebel": "Bizerte",
    "beja": "Béja", "béja": "Béja", "testour": "Béja", "medjez el bab": "Béja",
    "jendouba": "Jendouba", "tabarka": "Jendouba", "ain draham": "Jendouba",
    "le kef": "Le Kef", "kef": "Le Kef",
    "siliana": "Siliana",
    "sousse": "Sousse", "hammam sousse": "Sousse", "akouda": "Sousse",
    "sahloul": "Sousse", "el kantaoui": "Sousse", "hergla": "Sousse",
    "msaken": "Sousse", "kalaa kebira": "Sousse", "enfidha": "Sousse",
    "monastir": "Monastir", "moknine": "Monastir", "ksar hellal": "Monastir",
    "jemmal": "Monastir", "skanes": "Monastir",
    "mahdia": "Mahdia", "el jem": "Mahdia", "ksour essaf": "Mahdia",
    "salakta": "Mahdia", "rejiche": "Mahdia",
    "kairouan": "Kairouan",
    "kasserine": "Kasserine", "sbeitla": "Kasserine",
    "sidi bouzid": "Sidi Bouzid",
    "sfax": "Sfax", "sakiet ezzit": "Sfax", "gremda": "Sfax",
    "kerkennah": "Sfax", "mahrès": "Sfax", "tantana": "Sfax",
    "gafsa": "Gafsa", "metlaoui": "Gafsa", "redeyef": "Gafsa",
    "tozeur": "Tozeur", "nefta": "Tozeur",
    "kebili": "Kébili", "douz": "Kébili",
    "gabes": "Gabès", "gabès": "Gabès", "el hamma": "Gabès",
    "medenine": "Médenine", "médenine": "Médenine",
    "djerba": "Médenine", "zarzis": "Médenine", "houmt souk": "Médenine",
    "midoun": "Médenine", "aghir": "Médenine",
    "tataouine": "Tataouine",
}

# Sort by length descending so longer phrases match before substrings
SORTED_CITIES = sorted(CITY_GOV.keys(), key=len, reverse=True)

def extract_location(text):
    if not isinstance(text, str):
        return None, None
    t = text.lower()
    for city in SORTED_CITIES:
        if re.search(r'\b' + re.escape(city) + r'\b', t):
            return city.title(), CITY_GOV[city]
    return None, None

both_null_before = df[df["governorate"].isna() & df["city"].isna()].shape[0]
recovered_city, recovered_gov = 0, 0

for idx, row in df[df["governorate"].isna() & df["city"].isna()].iterrows():
    text = " ".join([str(row.get("title","") or ""), str(row.get("description","") or "")])
    city_found, gov_found = extract_location(text)
    if gov_found:
        df.at[idx, "governorate"] = gov_found
        recovered_gov += 1
    if city_found:
        df.at[idx, "city"] = city_found
        recovered_city += 1

both_null_after = df[df["governorate"].isna() & df["city"].isna()].shape[0]
print(f"Rows with both null BEFORE  : {both_null_before:,}")
print(f"Recovered governorate       : {recovered_gov:,}")
print(f"Recovered city              : {recovered_city:,}")
print(f"Rows with both null AFTER   : {both_null_after:,}")
# Out:
# Rows with both null BEFORE  : 4,737
# Recovered governorate       : 2,588
# Recovered city              : 2,588
# Rows with both null AFTER   : 2,149

# %%
# Drop rows where both city and governorate remain null after all recovery attempts
before = len(df)
df = df[~(df["governorate"].isna() & df["city"].isna())].reset_index(drop=True)
print(f"Rows BEFORE : {before:,}")
print(f"Rows AFTER  : {len(df):,}")
print(f"Dropped     : {before - len(df):,} rows with no recoverable location")
# Out:
# Rows BEFORE : 33,655
# Rows AFTER  : 31,506
# Dropped     : 2,149 rows with no recoverable location

# %% [markdown]
# <h2 style="color: #87BAC3;">💰 Step 9 — Price Imputation (3-Tier Median Strategy)</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Price is the model target — null prices cannot be used for training. The 3-tier imputation strategy fills each missing price with the most granular available median: first by <strong>property_type + governorate</strong> (most precise), then by <strong>property_type alone</strong> if the combination has insufficient data, and finally by the <strong>global dataset median</strong> as a last resort. An <code>is_price_imputed</code> flag is added so the model can distinguish real from imputed targets during training.</p>

# %%
# 3-tier price imputation
import numpy as np

df["price"] = pd.to_numeric(df["price"], errors="coerce")

# Pre-compute medians
median_by_type_gov  = df.groupby(["property_type", "governorate"])["price"].median()
median_by_type      = df.groupby("property_type")["price"].median()
global_median       = df["price"].median()

df["is_price_imputed"] = df["price"].isna()

def impute_price(row):
    if pd.notna(row["price"]):
        return row["price"]
    # Tier 1 — property_type + governorate
    key1 = (row["property_type"], row["governorate"])
    if key1 in median_by_type_gov.index and pd.notna(median_by_type_gov[key1]):
        return median_by_type_gov[key1]
    # Tier 2 — property_type only
    key2 = row["property_type"]
    if key2 in median_by_type.index and pd.notna(median_by_type[key2]):
        return median_by_type[key2]
    # Tier 3 — global median
    return global_median

df["price"] = df.apply(impute_price, axis=1)

tier1 = df[df["is_price_imputed"]].apply(
    lambda r: (r["property_type"], r["governorate"]) in median_by_type_gov.index, axis=1).sum()
print(f"Price nulls imputed total  : {df['is_price_imputed'].sum():,}")
print(f"  → Tier 1 (type+gov)      : {tier1:,}")
print(f"  → Tier 2+3 (type/global) : {df['is_price_imputed'].sum() - tier1:,}")
print(f"Price nulls remaining      : {df['price'].isna().sum()}")
print(f"\nGlobal median used         : {global_median:,.0f} TND")
# Out:
# Price nulls imputed total  : 2,925
#   → Tier 1 (type+gov)      : 2,847
#   → Tier 2+3 (type/global) : 78
# Price nulls remaining      : 0
#
# Global median used         : 350,000 TND

# %% [markdown]
# <h2 style="color: #87BAC3;">📐 Step 10 — Surface Area Soft Imputation + Indicator Flag</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Surface area is one of the top three price predictors in the structured branch. Rather than leaving 17.9% of values as NaN — which would prevent surface-based features like price-per-m² from being computed — a soft imputation fills missing values with the median surface by <strong>property_type + governorate</strong>, falling back to property_type median. A binary <code>has_surface</code> flag preserves the information about which values are real vs imputed, allowing the model to down-weight imputed surfaces during training.</p>

# %%
# Surface area soft imputation + has_surface indicator
df["surface_m2"] = pd.to_numeric(df["surface_m2"], errors="coerce")
df["surface_m2"] = df["surface_m2"].where(df["surface_m2"] > 0)  # zero → NaN

df["has_surface"] = df["surface_m2"].notna()

median_surf_type_gov = df.groupby(["property_type", "governorate"])["surface_m2"].median()
median_surf_type     = df.groupby("property_type")["surface_m2"].median()
global_surf_median   = df["surface_m2"].median()

def impute_surface(row):
    if pd.notna(row["surface_m2"]):
        return row["surface_m2"]
    key1 = (row["property_type"], row["governorate"])
    if key1 in median_surf_type_gov.index and pd.notna(median_surf_type_gov[key1]):
        return median_surf_type_gov[key1]
    key2 = row["property_type"]
    if key2 in median_surf_type.index and pd.notna(median_surf_type[key2]):
        return median_surf_type[key2]
    return global_surf_median

before_null = df["surface_m2"].isna().sum()
df["surface_m2"] = df.apply(impute_surface, axis=1)

print(f"surface_m2 nulls BEFORE : {before_null:,}")
print(f"surface_m2 nulls AFTER  : {df['surface_m2'].isna().sum():,}")
print(f"has_surface=True        : {df['has_surface'].sum():,} ({df['has_surface'].mean()*100:.1f}%)")
print(f"has_surface=False       : {(~df['has_surface']).sum():,} (soft imputed)")
# Out:
# surface_m2 nulls BEFORE : 13,792
# surface_m2 nulls AFTER  : 0
# has_surface=True        : 17,714 (56.2%)
# has_surface=False       : 13,792 (soft imputed)

# %% [markdown]
# <h2 style="color: #87BAC3;">🛏️ Step 11 — Room Feature Indicator Flags</h2>
#
# <h3>🎯 Purpose</h3>
# <p>Rooms, bathrooms, and bedrooms are 71–85% missing — too sparse for reliable imputation. Rather than imputing potentially misleading values, binary indicator flags <code>has_rooms_info</code>, <code>has_bathrooms_info</code>, and <code>has_bedrooms_info</code> are added to signal availability to the model. The raw values are kept as-is with NaN — tree-based models (XGBoost, LightGBM) handle NaN natively and will extract signal where the data is available. <code>total_rooms</code> is dropped as it is 85.4% missing and redundant with <code>rooms</code>.</p>

# %%
# Add indicator flags for sparse room features and drop total_rooms
df["rooms"]    = pd.to_numeric(df["rooms"],    errors="coerce")
df["bathrooms"]= pd.to_numeric(df["bathrooms"],errors="coerce")
df["bedrooms"] = pd.to_numeric(df["bedrooms"], errors="coerce")

df["has_rooms_info"]    = df["rooms"].notna()
df["has_bathrooms_info"]= df["bathrooms"].notna()
df["has_bedrooms_info"] = df["bedrooms"].notna()

df = df.drop(columns=["total_rooms"])

print("Indicator flags:")
for col in ["has_rooms_info", "has_bathrooms_info", "has_bedrooms_info"]:
    n = df[col].sum()
    print(f"  {col:<25} True: {n:,} ({n/len(df)*100:.1f}%)")
print(f"\ntotal_rooms dropped.")
print(f"Columns remaining: {df.shape[1]}")
# Out:
# Indicator flags:
#   has_rooms_info            True: 8,599 (27.3%)
#   has_bathrooms_info        True: 6,585 (20.9%)
#   has_bedrooms_info         True: 8,900 (28.2%)
#
# total_rooms dropped.
# Columns remaining: 40

# %% [markdown]
# <h2 style="color: #87BAC3;">💾 Step 12 — Final Missing Values Snapshot & Save</h2>
#
# <h3>🎯 Purpose</h3>
# <p>A final missing values audit confirms the effect of every treatment step applied in this section. The cleaned, model-ready dataset is saved as <strong>merged_listings_model_ready.csv</strong> — the canonical input for all feature engineering, training, and evaluation phases that follow.</p>

# %%
# Final missing values snapshot
missing_final = df.isnull().mean().sort_values(ascending=False)
mf = missing_final.reset_index()
mf.columns = ["column", "missing_pct"]
mf["missing_count"] = (mf["missing_pct"] * len(df)).astype(int)
mf["pct_label"] = (mf["missing_pct"] * 100).round(1).astype(str) + "%"

print(f"Final dataset shape: {df.shape}")
print(f"\n{'Column':<28} {'Missing':>10} {'%':>8}")
print("-" * 48)
for _, row in mf.iterrows():
    marker = " ⚠️" if row["missing_pct"] > 0.5 else ""
    print(f"{row['column']:<28} {row['missing_count']:>10,} {row['pct_label']:>8}{marker}")

# Save
df.to_csv("Data/raw_listings/merged_listings_model_ready.csv", index=False)
print(f"\n✅ Saved → Data/raw_listings/merged_listings_model_ready.csv")
print(f"   Rows: {len(df):,}  |  Columns: {df.shape[1]}")
# Out:
# Final dataset shape: (31506, 40)
#
# Column                          Missing        %
# ------------------------------------------------
# bathrooms                        24,921    79.1% ⚠️
# rooms                            22,907    72.7% ⚠️
# bedrooms                         22,606    71.8% ⚠️
# seller_type                       3,730    11.8%
# governorate                         248     0.8%
# city                                 11     0.0%
# has_furniture                         0     0.0%
# has_parking                           0     0.0%
# has_pool                              0     0.0%
# has_security                          0     0.0%
# has_standing                          0     0.0%
# has_terrace                           0     0.0%
# id                                    0     0.0%
# has_air_conditioning                  0     0.0%
# has_sea_view                          0     0.0%
# description_word_count                0     0.0%
# ...

# %%
# Drop the 248 rows with missing governorate — 0.8% loss, clean location features
before = len(df)
df = df[df["governorate"].notna()].reset_index(drop=True)
print(f"Dropped : {before - len(df):,} rows")
print(f"Final   : {len(df):,} rows | {df.shape[1]} columns")

df.to_csv("Data/raw_listings/final--merged_listings_.csv", index=False)
print("✅ Saved.")
# Out:
# Dropped : 249 rows
# Final   : 31,257 rows | 40 columns
# ✅ Saved.
